# %%
import os
from pathlib import Path

def get_svg_files(directory):
    svg_files = []
    for root, _, files in os.walk(directory):
        svg_files_directory = [f"{root}/{file}" for file in files if file.lower().endswith('.svg')]
        svg_files = svg_files + svg_files_directory
    return svg_files

if __name__ == "__main__":
    # directory = input("Enter the directory path to search: ").strip()
    black_white_directory = './black/white'
    black_color = "rgb(27,27,29)"
    white_color = "rgb(255,255,255)"
    red_dark_color = "rgb(149,6,6)"
    red_burgundy_color = "rgb(102,0,51)"
    red_maroon_color = "rgb(85,0,0)"
    red_supreme_color = "rgb(237,29,36)"
    red_blood_color = "rgb(237,29,36)"
    yellow_gold_color = "rgb(239,191,4)"
    yellow_dark_color = "rgb(186,142,35)"
    green_dark_color = "rgb(6,64,43)"
    green_emerald_color = "rgb(0,103,79)"
    blue_dark_color = "rgb(17,17,132)"
    blue_navy_color = "rgb(0,0,128)"
    neutral_brown_color = "rgb(137,81,41)"
    neutral_silver_color = "rgb(196,196,196)"
    if os.path.isdir(black_white_directory):
        black_white_svg_files = get_svg_files(black_white_directory)
        print(f"Total number of .svg files: {len(black_white_svg_files)}")
        for black_white_svg_file in black_white_svg_files:
            black_white_svg_io = open(black_white_svg_file, 'r')
            black_white_svg_string = black_white_svg_io.read()
            black_count = black_white_svg_string.count(black_color)
            if black_count >= 1:
                for dest in [{
                    "primary_src_color": white_color,
                    "primary_dest_color": green_emerald_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/emerald"                    
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": yellow_gold_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/gold"                    
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": blue_navy_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/navy"                    
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": red_burgundy_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/burgundy"                    
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": red_maroon_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/maroon"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": red_blood_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": black_color,
                    "folder": "black/blood"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": blue_dark_color,
                    "folder": "blue/dark/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": blue_navy_color,
                    "folder": "blue/navy/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": green_dark_color,
                    "folder": "green/dark/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": green_emerald_color,
                    "folder": "green/emerald/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": yellow_gold_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": red_blood_color,
                    "folder": "red/blood/gold"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": red_blood_color,
                    "folder": "red/blood/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": red_burgundy_color,
                    "folder": "red/burgundy/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": red_dark_color,
                    "folder": "red/dark/white"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": neutral_silver_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": green_emerald_color,
                    "folder": "green/emerald/silver"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": red_blood_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": yellow_gold_color,
                    "folder": "yellow/gold/blood"
                }, {
                    "primary_src_color": white_color,
                    "primary_dest_color": white_color,
                    "secondary_src_color": black_color,
                    "secondary_dest_color": yellow_gold_color,
                    "folder": "yellow/gold/white"
                }]:
                    primary_src_color = dest.get("primary_src_color")
                    primary_dest_color = dest.get("primary_dest_color")
                    secondary_src_color = dest.get("secondary_src_color")
                    secondary_dest_color = dest.get("secondary_dest_color")
                    dest_folder = dest.get("folder")
                    colored_svg_string = black_white_svg_string.replace(primary_src_color, primary_dest_color)
                    colored_svg_string = colored_svg_string.replace(secondary_src_color, secondary_dest_color)
                    colored_svg_file : str = black_white_svg_file.replace("black/white", dest_folder)
                    colored_svg_path = Path("/".join(colored_svg_file.split("/")[:-1]))
                    colored_svg_path.mkdir(parents=True, exist_ok=True)
                    colored_svg_filename = Path(colored_svg_file)
                    colored_svg_filename.touch(exist_ok=True)
                    colored_svg_io = open(colored_svg_file, "w+")
                    colored_svg_io.write(colored_svg_string)
                    colored_svg_io.close()
            else:
                print(black_white_svg_file, black_count)
    else:
        print("The provided path is not a valid directory.")
# Out:
# Total number of .svg files: 230
