# %%
import pandas as pd

# %%
champion_data_frame = pd.read_csv("./champions.csv")
sorted_champion_data_frame = champion_data_frame.sort_values(by=["competition_tour", "competition", "year"])
sorted_champion_data_frame.to_csv("./champions.csv", index=False)
sorted_champion_data_frame
# Out:
#     time_class  competition_tour            competition  year host_city  \
# 0    classical  Grand Chess Tour   London Chess Classic  2009    London
# 1    classical  Grand Chess Tour   London Chess Classic  2010    London
# 2    classical  Grand Chess Tour   London Chess Classic  2011    London
# 3    classical  Grand Chess Tour   London Chess Classic  2012    London
# 4    classical  Grand Chess Tour   London Chess Classic  2013    London
# ..         ...               ...                    ...   ...       ...
# 232  classical               NaN  US Chess Championship  2019       NaN
# 233  classical               NaN  US Chess Championship  2020       NaN
# 234  classical               NaN  US Chess Championship  2021       NaN
# 235  classical               NaN  US Chess Championship  2022       NaN
# 236  classical               NaN  US Chess Championship  2023       NaN
#
#     host_state    host_country          champion champion_country runner_up  \
# 0          NaN  United Kingdom    Magnus Carlsen           Norway       NaN
# 1          NaN  United Kingdom    Magnus Carlsen           Norway       NaN
# 2          NaN  United Kingdom  Vladimir Kramnik           Russia       NaN
# 3          NaN  United Kingdom    Magnus Carlsen           Norway       NaN
# 4          NaN  United Kingdom   Hikaru Nakamura    United States       NaN
# ..         ...             ...               ...              ...       ...
# 232        NaN   United States   Hikaru Nakamura    United States       NaN
# 233        NaN   United States         Wesley So    United States       NaN
# 234        NaN   United States         Wesley So    United States       NaN
# 235        NaN   United States   Fabiano Caruana    United States       NaN
# 236        NaN   United States   Fabiano Caruana    United States       NaN
#
#     runner_up_country third_place third_place_country  Unnamed: 13  \
# 0                 NaN         NaN                 NaN          NaN
# 1                 NaN         NaN                 NaN          NaN
# 2                 NaN         NaN                 NaN          NaN
# 3                 NaN         NaN                 NaN          NaN
# 4                 NaN         NaN                 NaN          NaN
# ..                ...         ...                 ...          ...
# 232               NaN         NaN                 NaN          NaN
# 233               NaN         NaN                 NaN          NaN
# 234               NaN         NaN                 NaN          NaN
# 235               NaN         NaN                 NaN          NaN
# 236               NaN         NaN                 NaN          NaN
#
#      Unnamed: 14
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 232          NaN
# 233          NaN
# 234          NaN
# 235          NaN
# 236          NaN
#
# [237 rows x 15 columns]

# %%
host_countries = sorted_champion_data_frame['host_country'].value_counts()
host_countries
# Out:
# host_country
# United States                  98
# Russia                         23
# Netherlands                    13
# United Kingdom                 12
# India                          11
# Soviet Union                   10
# Kazakhstan                      6
# Germany                         4
# United Arab Emirates            3
# Philippines                     2
# Saudi Arabia                    2
# Qatar                           2
# Poland                          2
# Spain                           2
# Isle of Man                     2
# Iceland                         1
# Italy                           1
# England                         1
# Israel                          1
# Georgia                         1
# Azerbaijan                      1
# Norway                          1
# Latvia                          1
# Bulgaria                        1
# Mexico                          1
# Argentina                       1
# Libya                           1
# India;Iran                      1
# Netherlands;Switzerland         1
# Netherlands;Indonesia           1
# Netherlands;Soviet Union        1
# United Kingdom;Soviet Union     1
# United States;France            1
# Name: count, dtype: int64

# %%
host_cities = sorted_champion_data_frame['host_city'].value_counts()
host_cities
# Out:
# host_city
# Moscow                             18
# London                             13
# Wijk aan Zee                       13
# St. Louis                          11
# Kolkata                            10
# Magnus Carlsen                      8
# Khanty-Mansiysk                     8
# Berlin                              3
# Dubai                               3
# Sergey Karjakin                     3
# Astana                              3
# Almaty                              3
# Sochi                               2
# Doha                                2
# Riyadh                              2
# Saint Petersburg                    2
# Elista                              2
# Warsaw                              2
# Maxime Vachier-Lagrave              2
# Wesley So                           2
# Santon                              1
# Levon Aronian                       1
# Sofia                               1
# Chennai                             1
# Hikaru Nakamura                     1
# New York City                       1
# Fabiano Caruana                     1
# Baku                                1
# Tromsø                              1
# Mexico City                         1
# Tbilisi                             1
# Rishon Lezion                       1
# Veselin Topalov                     1
# Nodirbek Abdusattorov               1
# Bonn                                1
# Potrero de los Funes;San Luis       1
# Riga                                1
# Madrid                              1
# Douglas                             1
# The Hague;Moscow                    1
# Reykjavík                           1
# Manila                              1
# Baguio                              1
# Merano                              1
# Seville                             1
# Tripoli                             1
# New York City;Lyon                  1
# Zwolle;Arnhem;Amsterdam;Jakarta     1
# Yekaterinburg                       1
# Groningen;Lausanne                  1
# Las Vegas                           1
# New Delhi;Tehran                    1
# London;Leningrad                    1
# Name: count, dtype: int64

# %%
champions = sorted_champion_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Magnus Carlsen           30
# Hikaru Nakamura          10
# Viswanathan Anand         9
# Fabiano Caruana           9
# Levon Aronian             9
#                          ..
# Leinier Domínguez         1
# Lê Quang Liêm             1
# Daniil Dubov              1
# Nodirbek Abdusattorov     1
# Samuel Shankland          1
# Name: count, Length: 69, dtype: int64

# %%
runners_up = sorted_champion_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Ian Nepomniachtchi        7
# Viswanathan Anand         6
# Anatoly Karpov            4
# Hikaru Nakamura           4
# Alexander Grischuk        4
# Fabiano Caruana           4
# Mikhail Botvinnik         3
# Magnus Carlsen            3
# Sergey Karjakin           3
# Ding Liren                3
# Vasily Smyslov            3
# Vasyl Ivanchuk            2
# Alexei Shirov             2
# Peter Svidler             2
# Ruslan Ponomariov         2
# Veselin Topalov           2
# Teimour Radjabov          2
# Vladimir Kramnik          2
# Viktor Korchnoi           2
# Boris Spassky             2
# Jan-Krzysztof Duda        2
# Shakhriyar Mamedyarov     2
# Dmitry Andreikin          1
# Vladimir Fedoseev         1
# Alireza Firouzja          1
# Maxime Vachier-Lagrave    1
# Gata Kamsky               1
# Boris Gelfand             1
# Michael Adams             1
# Vladimir Akopian          1
# Jan Timman                1
# Bobby Fischer             1
# Tigran Petrosian          1
# Mikhail Tal               1
# David Bronstein           1
# Richárd Rapport           1
# Vincent Keymer            1
# Name: count, dtype: int64
