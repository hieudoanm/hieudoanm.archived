# %%
import pandas as pd

# %%
champion_data_frame = pd.read_csv("./champions.csv")
sorted_champion_data_frame = champion_data_frame.sort_values(by=["competition_tour", "competition", "year"])
sorted_champion_data_frame.to_csv("./champions.csv", index=False)
sorted_champion_data_frame
# Out:
#         competition_tour           competition  year         host_city  \
# 0       Grand Chess Tour  London Chess Classic  2009            London
# 1       Grand Chess Tour  London Chess Classic  2010            London
# 2       Grand Chess Tour  London Chess Classic  2011            London
# 3       Grand Chess Tour  London Chess Classic  2012            London
# 4       Grand Chess Tour  London Chess Classic  2013            London
# ..                   ...                   ...   ...               ...
# 140  World Rapid & Blitz           World Rapid  2017            Riyadh
# 141  World Rapid & Blitz           World Rapid  2018  Saint Petersburg
# 142  World Rapid & Blitz           World Rapid  2019            Moscow
# 143  World Rapid & Blitz           World Rapid  2021            Warsaw
# 144  World Rapid & Blitz           World Rapid  2022            Almaty
#
#     host_state    host_country               champion champion_country  \
# ...

# %%
host_countries = sorted_champion_data_frame['host_country'].value_counts()
host_countries
# Out:
# host_country
# Russia                         20
# Netherlands                    13
# United States                  13
# United Kingdom                 12
# India                          11
# Soviet Union                   10
# Kazakhstan                      6
# United Arab Emirates            3
# Germany                         3
# Saudi Arabia                    2
# Qatar                           2
# Poland                          2
# Isle of Man                     2
# Philippines                     2
# Spain                           1
# Iceland                         1
# Latvia                          1
# Israel                          1
# Georgia                         1
# Azerbaijan                      1
# Norway                          1
# Netherlands;Soviet Union        1
# Bulgaria                        1
# United States;France            1
# Mexico                          1
# Argentina                       1
# Libya                           1
# ...

# %%
host_cities = sorted_champion_data_frame['host_city'].value_counts()
host_cities
# Out:
# host_city
# Moscow                             17
# Wijk aan Zee                       13
# London                             12
# St. Louis                          11
# Kolkata                            10
# Magnus Carlsen                      8
# Khanty-Mansiysk                     7
# Almaty                              3
# Astana                              3
# Dubai                               3
# Sergey Karjakin                     3
# Berlin                              2
# Doha                                2
# Riyadh                              2
# Saint Petersburg                    2
# Sochi                               2
# Elista                              2
# Warsaw                              2
# Maxime Vachier-Lagrave              2
# Wesley So                           2
# Reykjavík                           1
# Chennai                             1
# Nodirbek Abdusattorov               1
# Veselin Topalov                     1
# ...

# %%
champions = sorted_champion_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Magnus Carlsen            29
# Levon Aronian              9
# Viswanathan Anand          8
# Anatoly Karpov             6
# Alexander Grischuk         5
# Hikaru Nakamura            5
# Mikhail Botvinnik          5
# Fabiano Caruana            5
# Garry Kasparov             4
# Maxime Vachier-Lagrave     4
# Ding Liren                 3
# Wesley So                  3
# Sergey Karjakin            3
# Vladimir Kramnik           3
# Alireza Firouzja           2
# Arjun Erigaisi             2
# Veselin Topalov            2
# Shakhriyar Mamedyarov      2
# Vasyl Ivanchuk             2
# Tigran Petrosian           2
# Peter Svidler              1
# Teimour Radjabov           1
# Leinier Domínguez          1
# Jan-Krzysztof Duda         1
# Gata Kamsky                1
# Lê Quang Liêm              1
# Daniil Dubov               1
# Boris Gelfand              1
# Mikhail Tal                1
# Rustam Kasimdzhanov        1
# Ruslan Ponomariov          1
# ...

# %%
runners_up = sorted_champion_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Ian Nepomniachtchi        7
# Viswanathan Anand         6
# Anatoly Karpov            4
# Alexander Grischuk        4
# Fabiano Caruana           4
# Magnus Carlsen            3
# Sergey Karjakin           3
# Mikhail Botvinnik         3
# Vasily Smyslov            3
# Hikaru Nakamura           3
# Alexei Shirov             2
# Ding Liren                2
# Peter Svidler             2
# Ruslan Ponomariov         2
# Jan-Krzysztof Duda        2
# Vladimir Kramnik          2
# Veselin Topalov           2
# Vasyl Ivanchuk            2
# Teimour Radjabov          2
# Boris Spassky             2
# Viktor Korchnoi           2
# Shakhriyar Mamedyarov     2
# Vladimir Akopian          1
# Alireza Firouzja          1
# Vladimir Fedoseev         1
# Richárd Rapport           1
# Maxime Vachier-Lagrave    1
# David Bronstein           1
# Mikhail Tal               1
# Dmitry Andreikin          1
# Tigran Petrosian          1
# Bobby Fischer             1
# ...
