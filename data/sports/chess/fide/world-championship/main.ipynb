# %%
import pandas

# %%
world_championship_data_frame = pandas.read_csv("./champions.csv")
world_championship_data_frame
# Out:
#     year                        host_city                 host_country  \
# 0   1948                 The Hague;Moscow     Netherlands;Soviet Union
# 1   1951                           Moscow                 Soviet Union
# 2   1954                           Moscow                 Soviet Union
# 3   1957                           Moscow                 Soviet Union
# 4   1958                           Moscow                 Soviet Union
# 5   1960                           Moscow                 Soviet Union
# 6   1961                           Moscow                 Soviet Union
# 7   1963                           Moscow                 Soviet Union
# 8   1966                           Moscow                 Soviet Union
# 9   1969                           Moscow                 Soviet Union
# 10  1972                        Reykjavík                      Iceland
# 11  1975                           Manila                  Philippines
# ...

# %%
host_countries = world_championship_data_frame['host_country'].value_counts()
host_countries
# Out:
# host_country
# Soviet Union                   10
# Russia                          5
# United States                   2
# Philippines                     2
# Libya                           1
# United Arab Emirates            1
# United Kingdom                  1
# India                           1
# Bulgaria                        1
# Germany                         1
# Mexico                          1
# Argentina                       1
# Netherlands;Soviet Union        1
# India;Iran                      1
# Netherlands;Switzerland         1
# Netherlands;Indonesia           1
# United States;France            1
# Spain                           1
# United Kingdom;Soviet Union     1
# Italy                           1
# Iceland                         1
# Kazakhstan                      1
# Name: count, dtype: int64

# %%
host_cities = world_championship_data_frame['host_city'].value_counts()
host_cities
# Out:
# host_city
# Moscow                             12
# Elista                              2
# The Hague;Moscow                    1
# Tripoli                             1
# Dubai                               1
# London                              1
# New York City                       1
# Sochi                               1
# Chennai                             1
# Sofia                               1
# Bonn                                1
# Mexico City                         1
# Potrero de los Funes;San Luis       1
# Las Vegas                           1
# New Delhi;Tehran                    1
# Groningen;Lausanne                  1
# Zwolle;Arnhem;Amsterdam;Jakarta     1
# New York City;Lyon                  1
# Seville                             1
# London;Leningrad                    1
# Merano                              1
# Baguio                              1
# Manila                              1
# Reykjavík                           1
# ...

# %%
champions = world_championship_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Anatoly Karpov         6
# Mikhail Botvinnik      5
# Viswanathan Anand      5
# Magnus Carlsen         5
# Garry Kasparov         4
# Tigran Petrosian       2
# Vasily Smyslov         1
# Mikhail Tal            1
# Boris Spassky          1
# Bobby Fischer          1
# Alexander Khalifman    1
# Ruslan Ponomariov      1
# Rustam Kasimdzhanov    1
# Veselin Topalov        1
# Vladimir Kramnik       1
# Ding Liren             1
# Name: count, dtype: int64

# %%
runners_up = world_championship_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Viswanathan Anand     4
# Anatoly Karpov        4
# Vasily Smyslov        3
# Mikhail Botvinnik     3
# Ian Nepomniachtchi    2
# Viktor Korchnoi       2
# Vladimir Kramnik      2
# Veselin Topalov       2
# Boris Spassky         2
# Vasyl Ivanchuk        1
# Fabiano Caruana       1
# Sergey Karjakin       1
# Boris Gelfand         1
# Michael Adams         1
# Mikhail Tal           1
# Alexei Shirov         1
# David Bronstein       1
# Gata Kamsky           1
# Jan Timman            1
# Bobby Fischer         1
# Tigran Petrosian      1
# Vladimir Akopian      1
# Name: count, dtype: int64
