# %%
import chess
import json
import math
from os import listdir
from os.path import isfile, join
import pandas
from stockfish import Stockfish
from tqdm.notebook import tqdm

# %%
USERNAMES = ["magnuscarlsen", "thedarkknighttrilogy", "hikaru", "wonderfultime", "danielnaroditsky"]
USERNAME = "thedarkknighttrilogy"
FILE_PATH = f"./{USERNAME}/games"

BLUNDER_CENTIPAWN = 300
MISTAKE_CENTIPAWN = 100
INACCURACY_CENTIPAWN = 50

BLUNDER_SYMBOL = "??"
MISTAKE_SYMBOL = "?"
INACCURACY_SYMBOL = "?!"
INTERESTING_SYMBOL = "!?"
GOOD_SYMBOL = "!"
BRILLIANT_SYMBOL = "!!"

# %%
pgn_file_names = [f for f in listdir(FILE_PATH) if isfile(join(FILE_PATH, f))]
pgn_file_names.sort()
pgn_file_names
# Out:
# ['2021-10.pgn',
#  '2021-11.pgn',
#  '2021-12.pgn',
#  '2022-01.pgn',
#  '2022-02.pgn',
#  '2022-03.pgn',
#  '2022-04.pgn',
#  '2022-05.pgn',
#  '2022-06.pgn',
#  '2022-07.pgn',
#  '2022-08.pgn',
#  '2022-09.pgn',
#  '2022-10.pgn',
#  '2022-11.pgn',
#  '2022-12.pgn',
#  '2023-01.pgn',
#  '2023-02.pgn',
#  '2023-03.pgn',
#  '2023-04.pgn',
#  '2023-05.pgn',
#  '2023-06.pgn',
#  '2023-07.pgn']

# %%
games = []

for pgn_file_name in tqdm(pgn_file_names):
    pgn_file = open(f"{FILE_PATH}/{pgn_file_name}", "r")
    pgn_file_content : str = pgn_file.read()
    pgn_file.close()
    games_by_file = pgn_file_content.split("\n\n\n")
    games += games_by_file
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
metadata = {}
metadata["total"] = len(games)
metadata_string = json.dumps(metadata, indent=2)
metadata_file = open(f"./{USERNAME}/metadata.json", "w")
metadata_file.write(metadata_string)
metadata_file.close()

# %%
def chunk(list : list, number : int):
    # looping till length l
    for i in range(0, len(list), number): 
        yield list[i:i + number]

# %%
stockfish = Stockfish()

# %%
def evaluate_move(loss : int):
    if loss >= BLUNDER_CENTIPAWN:
        return BLUNDER_SYMBOL
    if loss >= MISTAKE_CENTIPAWN:
        return MISTAKE_SYMBOL
    if loss >= INACCURACY_CENTIPAWN:
        return INACCURACY_SYMBOL
    return ''

# %%
def get_pgn_moves(pgn : str) -> list[str]:
    lines : list[str] = pgn.split("\n")
    lines : list[str] = list(filter(lambda line: line != "", lines))
    moves_string : str = lines[-1]
    moves : list[str] = moves_string.split(" ")
    moves.pop() # Remove result (1-0 or 0-1)
    moves : list[str] = list(filter(lambda move: "{" not in move and "}" not in move and "..." not in move, moves))
    moves : list[str] = [item for index, item in enumerate(moves) if index % 3 != 0]
    return moves

# %%
def get_fen_moves(moves : list[str]) -> list[dict]:
    fen_moves = []
    board : chess.Board = chess.Board()
    for index, move in enumerate(moves):
        move_number : int = math.floor(index / 2) + 1
        side : str = 'white' if index % 2 == 0 else 'black'
        board.push_san(move)
        fen : str = board.fen()
        fen_moves.append({
            "move_number": move_number,
            "side": side,
            "move": move,
            "fen": fen
        })
    board.reset()
    return fen_moves

# %%
def get_top_move(fen : str) -> dict:
    if not stockfish.is_fen_valid(fen):
        return { "centipawn": 0, "pawn": 0, "mate_in": 0, "evaluated": False }
    try:
        stockfish.set_fen_position(fen)
        top_moves : list[dict] = stockfish.get_top_moves(5)
        top_move : dict = top_moves[0]
        top_move_centipawn = top_move.get("Centipawn")
        print("get_top_move top_move_centipawn", top_move_centipawn)
        if top_move_centipawn == None:
            return { "centipawn": 0, "pawn": 0, "mate_in": 0, "evaluated": False }
        if "M" in str(top_move_centipawn):
            print("get_top_move mate_in", mate_in)
            mate_in = int(top_move_centipawn.replace("M", ""))
            return { "centipawn": 0, "pawn": 0, "mate_in": mate_in, "evaluated": True }
        top_move_pawn : float = top_move_centipawn / 100
        return { "centipawn": top_move_centipawn, "pawn": top_move_pawn, "mate_in": 0, "evaluated": True }
    except:
        print("get_top_move error")
        return { "centipawn": 0, "pawn": 0, "mate_in": 0, "evaluated": False }

# %%
def analyse_pgn(pgn : str):
    moves = get_pgn_moves(pgn)
    fen_moves = get_fen_moves(moves)
    game_details = [{
        "move_number": 0,
        "side": "",
        "move": "",
        "fen": "",
        "pawn": 0,
        "centipawn": 0,
        "mate_in": 0,
        "evaluation": ""
    }]
    for index, move_with_fen in enumerate(fen_moves):
        move_number : int = move_with_fen.get("move_number", 0)
        side : str = move_with_fen.get("side", "")
        move : str = move_with_fen.get("move", "")
        fen : str = move_with_fen.get("fen", "")
        top_move : dict = get_top_move(fen)
        top_move_evaluated : bool = top_move.get("evaluated", False)
        top_move_centipawn : int = top_move.get("centipawn", 0)
        top_move_pawn : float = top_move.get("pawn", 0)
        top_move_mate_in : int = top_move.get("mate_in", 0)
        print(move_number, side, move, top_move_pawn, top_move_centipawn, top_move_mate_in)
        if not top_move_evaluated:
            game_details.append({
                "move_number": move_number,
                "side": side,
                "move": move,
                "fen": fen,
                "pawn": 0,
                "centipawn": 0,
                "mate_in": 0,
                "evaluation": ""
            })
            continue
        previous : dict = game_details[index]
        previous_centipawn : int = previous.get("centipawn", 0)
        centipawn_loss : int = top_move_centipawn - previous_centipawn
        evaluation : str = evaluate_move(centipawn_loss)
        game_details.append({
            "move_number": move_number,
            "side": side,
            "move": move,
            "fen": fen,
            "pawn": top_move_pawn,
            "centipawn": top_move_centipawn,
            "mate_in": top_move_mate_in,
            "evaluation": evaluation
        })
    return game_details

# %%
game = games[0]
game_details = analyse_pgn(game)
game_details_data_frame = pandas.DataFrame(game_details)
game_details_data_frame
# Out:
# get_top_move top_move_centipawn 37
# 1 white e4 0.37 37 0
# get_top_move top_move_centipawn 28
# 1 black e5 0.28 28 0
# get_top_move top_move_centipawn 19
# 2 white Nf3 0.19 19 0
# get_top_move top_move_centipawn 39
# 2 black Nc6 0.39 39 0
# get_top_move top_move_centipawn 28
# 3 white d4 0.28 28 0
# get_top_move top_move_centipawn 42
# 3 black exd4 0.42 42 0
# get_top_move top_move_centipawn 6
# 4 white Nxd4 0.06 6 0
# get_top_move top_move_centipawn 64
# 4 black Nxd4 0.64 64 0
# get_top_move top_move_centipawn 76
# 5 white Qxd4 0.76 76 0
# get_top_move top_move_centipawn 69
# 5 black Qf6 0.69 69 0
# get_top_move top_move_centipawn 74
# 6 white e5 0.74 74 0
# get_top_move top_move_centipawn 57
# 6 black Qb6 0.57 57 0
# get_top_move top_move_centipawn 44
# 7 white Qxb6 0.44 44 0
# get_top_move top_move_centipawn 54
# 7 black axb6 0.54 54 0
# get_top_move top_move_centipawn 20
# 8 white Bc4 0.2 20 0
# get_top_move top_move_centipawn 55
# 8 black d6 0.55 55 0
# get_top_move top_move_centipawn 66
# 9 white Bf4 0.66 66 0
# get_top_move top_move_centipawn 46
# 9 black Be6 0.46 46 0
# get_top_move top_move_centipawn 59
# 10 white Bxe6 0.59 59 0
# get_top_move top_move_centipawn 42
# 10 black fxe6 0.42 42 0
# get_top_move top_move_centipawn -75
# 11 white O-O -0.75 -75 0
# get_top_move top_move_centipawn 31
# 11 black O-O-O 0.31 31 0
# get_top_move top_move_centipawn -15
# 12 white Nc3 -0.15 -15 0
# get_top_move top_move_centipawn -10
# 12 black d5 -0.1 -10 0
# get_top_move top_move_centipawn -53
# 13 white Rfd1 -0.53 -53 0
# get_top_move top_move_centipawn -65
# 13 black Bc5 -0.65 -65 0
# get_top_move top_move_centipawn -72
# 14 white Na4 -0.72 -72 0
# get_top_move top_move_centipawn -52
# 14 black h6 -0.52 -52 0
# get_top_move top_move_centipawn -49
# 15 white c3 -0.49 -49 0
# get_top_move top_move_centipawn -53
# 15 black g5 -0.53 -53 0
# get_top_move top_move_centipawn -116
# 16 white Bg3 -1.16 -116 0
# get_top_move top_move_centipawn -62
# 16 black h5 -0.62 -62 0
# get_top_move top_move_centipawn -161
# 17 white h4 -1.61 -161 0
# get_top_move top_move_centipawn -150
# 17 black Be7 -1.5 -150 0
# get_top_move top_move_centipawn -147
# 18 white c4 -1.47 -147 0
# get_top_move top_move_centipawn 0
# 18 black Nh6 0.0 0 0
# get_top_move top_move_centipawn -8
# 19 white cxd5 -0.08 -8 0
# get_top_move top_move_centipawn -5
# 19 black Rxd5 -0.05 -5 0
# get_top_move top_move_centipawn -77
# 20 white Nc3 -0.77 -77 0
# get_top_move top_move_centipawn -93
# 20 black Rxd1+ -0.93 -93 0
# get_top_move top_move_centipawn -112
# 21 white Rxd1 -1.12 -112 0
# get_top_move top_move_centipawn -17
# 21 black Nf5 -0.17 -17 0
# get_top_move top_move_centipawn -16
# 22 white hxg5 -0.16 -16 0
# get_top_move top_move_centipawn -2
# 22 black Bxg5 -0.02 -2 0
# get_top_move top_move_centipawn -23
# 23 white Ne4 -0.23 -23 0
# get_top_move top_move_centipawn 33
# 23 black Be7 0.33 33 0
# get_top_move top_move_centipawn 28
# 24 white Bf4 0.28 28 0
# get_top_move top_move_centipawn 75
# 24 black Rg8 0.75 75 0
# get_top_move top_move_centipawn -4
# 25 white Kh2 -0.04 -4 0
# get_top_move top_move_centipawn 78
# 25 black Rd8 0.78 78 0
# get_top_move top_move_centipawn 88
# 26 white Rxd8+ 0.88 88 0
# get_top_move top_move_centipawn 89
# 26 black Kxd8 0.89 89 0
# get_top_move top_move_centipawn 57
# 27 white Kh3 0.57 57 0
# get_top_move top_move_centipawn 117
# 27 black Kd7 1.17 117 0
# get_top_move top_move_centipawn 82
# 28 white Bg5 0.82 82 0
# get_top_move top_move_centipawn 109
# 28 black Bxg5 1.09 109 0
# get_top_move top_move_centipawn 92
# 29 white Nxg5 0.92 92 0
# get_top_move top_move_centipawn 255
# 29 black h4 2.55 255 0
# get_top_move top_move_centipawn 238
# 30 white Nf3 2.38 238 0
# get_top_move top_move_centipawn 243
# 30 black c5 2.43 243 0
# get_top_move top_move_centipawn 212
# 31 white Nxh4 2.12 212 0
# get_top_move top_move_centipawn 397
# 31 black Nxh4 3.97 397 0
# get_top_move top_move_centipawn 428
# 32 white Kxh4 4.28 428 0
# get_top_move top_move_centipawn 436
# 32 black b5 4.36 436 0
# get_top_move top_move_centipawn 238
# 33 white Kg4 2.38 238 0
# get_top_move top_move_centipawn 419
# 33 black c4 4.19 419 0
# get_top_move top_move_centipawn 348
# 34 white Kf4 3.48 348 0
# get_top_move top_move_centipawn 328
# 34 black b4 3.28 328 0
# get_top_move top_move_centipawn 458
# 35 white Ke3 4.58 458 0
# get_top_move top_move_centipawn 345
# 35 black b5 3.45 345 0
# get_top_move top_move_centipawn 278
# 36 white Kd4 2.78 278 0
# get_top_move top_move_centipawn 284
# 36 black Ke7 2.84 284 0
# get_top_move top_move_centipawn 447
# 37 white g4 4.47 447 0
# get_top_move top_move_centipawn 399
# 37 black Kf7 3.99 399 0
# get_top_move top_move_centipawn 464
# 38 white f4 4.64 464 0
# get_top_move top_move_centipawn 370
# 38 black Kg6 3.7 370 0
# get_top_move top_move_centipawn 463
# 39 white Ke4 4.63 463 0
# get_top_move top_move_centipawn 437
# 39 black Kf7 4.37 437 0
# get_top_move top_move_centipawn 403
# 40 white f5 4.03 403 0
# get_top_move top_move_centipawn 446
# 40 black Ke7 4.46 446 0
# get_top_move top_move_centipawn 500
# 41 white Kd4 5.0 500 0
# get_top_move top_move_centipawn 353
# 41 black Kf7 3.53 353 0
# get_top_move top_move_centipawn 515
# 42 white f6 5.15 515 0
# get_top_move top_move_centipawn 435
# 42 black Kg6 4.35 435 0
# get_top_move top_move_centipawn 339
# 43 white g5 3.39 339 0
# get_top_move top_move_centipawn 441
# 43 black Kf7 4.41 441 0
# get_top_move top_move_centipawn 517
# 44 white Ke4 5.17 517 0
# get_top_move top_move_centipawn 390
# 44 black Kg6 3.9 390 0
# get_top_move top_move_centipawn 436
# 45 white Kd4 4.36 436 0
# get_top_move top_move_centipawn 463
# 45 black Kf7 4.63 463 0
# get_top_move top_move_centipawn 496
# 46 white Ke3 4.96 496 0
# get_top_move top_move_centipawn 505
# 46 black Kg6 5.05 505 0
# get_top_move top_move_centipawn 375
# 47 white Kd2 3.75 375 0
# get_top_move top_move_centipawn 522
# 47 black Kf7 5.22 522 0
# get_top_move top_move_centipawn 485
# 48 white Kc2 4.85 485 0
# get_top_move top_move_centipawn 536
# 48 black Kg6 5.36 536 0
# get_top_move top_move_centipawn 558
# 49 white a3 5.58 558 0
# get_top_move top_move_centipawn 538
# 49 black bxa3 5.38 538 0
# get_top_move top_move_centipawn 596
# 50 white bxa3 5.96 596 0
# get_top_move top_move_centipawn 573
# 50 black Kf7 5.73 573 0
# get_top_move top_move_centipawn 586
# 51 white Kc3 5.86 586 0
# get_top_move top_move_centipawn 614
# 51 black Kg6 6.14 614 0
# get_top_move top_move_centipawn 558
# 52 white a4 5.58 558 0
# get_top_move top_move_centipawn 558
# 52 black bxa4 5.58 558 0
# get_top_move top_move_centipawn 662
# 53 white Kxc4 6.62 662 0
# get_top_move top_move_centipawn 644
# 53 black a3 6.44 644 0
# get_top_move top_move_centipawn 691
# 54 white Kb3 6.91 691 0
# get_top_move top_move_centipawn 718
# 54 black a2 7.18 718 0
# get_top_move top_move_centipawn 694
# 55 white Kxa2 6.94 694 0
# get_top_move top_move_centipawn 3587
# 55 black Kxg5 35.87 3587 0
# get_top_move top_move_centipawn 3517
# 56 white f7 35.17 3517 0
# get_top_move top_move_centipawn 3518
# 56 black Kf5 35.18 3518 0
# get_top_move top_move_centipawn 3536
# 57 white f8=Q+ 35.36 3536 0
# get_top_move top_move_centipawn 3518
# 57 black Kxe5 35.18 3518 0
# get_top_move top_move_centipawn 3448
# 58 white Qe7 34.48 3448 0
# get_top_move top_move_centipawn None
# 58 black Kd4 0 0 0
# get_top_move top_move_centipawn 3420
# 59 white Kb3 34.2 3420 0
# get_top_move top_move_centipawn 3508
# 59 black e5 35.08 3508 0
# get_top_move top_move_centipawn 3448
# 60 white Qd6+ 34.48 3448 0
# get_top_move top_move_centipawn 3530
# 60 black Ke4 35.3 3530 0
# get_top_move top_move_centipawn 3503
# 61 white Kc3 35.03 3503 0
# get_top_move top_move_centipawn None
# 61 black Kf4 0 0 0
# get_top_move top_move_centipawn 3559
# 62 white Kd2 35.59 3559 0
# get_top_move top_move_centipawn 3556
# 62 black Ke4 35.56 3556 0
# get_top_move top_move_centipawn 3495
# 63 white Ke2 34.95 3495 0
# get_top_move top_move_centipawn None
# 63 black Kf5 0 0 0
# get_top_move top_move_centipawn 3387
# 64 white Qd5 33.87 3387 0
# get_top_move top_move_centipawn None
# 64 black Kf4 0 0 0
# get_top_move top_move_centipawn 3517
# 65 white Qc4+ 35.17 3517 0
# get_top_move top_move_centipawn 9605
# 65 black e4 96.05 9605 0
# get_top_move top_move_centipawn 3457
# 66 white Qd4 34.57 3457 0
# get_top_move top_move_centipawn None
# 66 black Kf5 0 0 0
# get_top_move top_move_centipawn None
# 67 white Ke3 0 0 0
#      move_number   side  move  \
# 0              0
# 1              1  white    e4
# 2              1  black    e5
# 3              2  white   Nf3
# 4              2  black   Nc6
# ..           ...    ...   ...
# 129           65  white  Qc4+
# 130           65  black    e4
# 131           66  white   Qd4
# 132           66  black   Kf5
# 133           67  white   Ke3
#
#                                                    fen   pawn  centipawn  \
# 0                                                        0.00          0
# 1    rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...   0.37         37
# 2    rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...   0.28         28
# 3    rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...   0.19         19
# 4    r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...   0.39         39
# ..                                                 ...    ...        ...
# 129                8/8/8/4p3/2Q2k2/8/4K3/8 b - - 11 65  35.17       3517
# 130                  8/8/8/8/2Q1pk2/8/4K3/8 w - - 0 66  96.05       9605
# 131                   8/8/8/8/3Qpk2/8/4K3/8 b - - 1 66  34.57       3457
# 132                  8/8/8/5k2/3Qp3/8/4K3/8 w - - 2 67   0.00          0
# 133                  8/8/8/5k2/3Qp3/4K3/8/8 b - - 3 67   0.00          0
#
#      mate_in evaluation
# 0          0        N/A
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...        ...
# 129        0         ??
# 130        0         ??
# 131        0
# 132        0
# 133        0
#
# [134 rows x 8 columns]
