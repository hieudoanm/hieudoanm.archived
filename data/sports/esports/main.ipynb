# %%
import pandas as pd

# %%
champions_data_frame = pd.read_csv("./champions.csv")
champions_data_frame = champions_data_frame.sort_values(by=['sport', 'competition', 'season'])
champions_data_frame.to_csv("./champions.csv", index=False)
champions_data_frame
# Out:
#        sport          competition_tour competition_type  \
# 0      Chess  Speed Chess Championship           bullet
# 1      Chess  Speed Chess Championship           bullet
# 2      Chess  Speed Chess Championship           bullet
# 3      Chess        World Championship        classical
# 4      Chess        World Championship        classical
# ...      ...                       ...              ...
# 1149  Tennis                Grand Slam            grass
# 1150  Tennis                Grand Slam            grass
# 1151  Tennis                Grand Slam            grass
# 1152  Tennis                Grand Slam            grass
# 1153  Tennis                Grand Slam            grass
#
#                     competition season  month        host_city host_state  \
# 0     Bullet Chess Championship   2021    NaN              NaN        NaN
# 1     Bullet Chess Championship   2022    NaN              NaN        NaN
# 2     Bullet Chess Championship   2023    NaN              NaN        NaN
# 3         Candidates Tournament   2013    NaN           London        NaN
# 4         Candidates Tournament   2014    NaN  Khanty-Mansiysk        NaN
# ...                         ...    ...    ...              ...        ...
# 1149                  Wimbledon   2017    0.0              NaN        NaN
# 1150                  Wimbledon   2018    0.0              NaN        NaN
# 1151                  Wimbledon   2019    0.0              NaN        NaN
# 1152                  Wimbledon   2021    0.0              NaN        NaN
# 1153                  Wimbledon   2022    0.0              NaN        NaN
#
#         host_country           champion champion_country score runner_up  \
# 0                NaN   Alireza Firouzja           France   NaN       NaN
# 1                NaN    Hikaru Nakamura    United States   NaN       NaN
# 2                NaN    Hikaru Nakamura    United States   NaN       NaN
# 3            England     Magnus Carlsen           Norway   NaN       NaN
# 4             Russia  Viswanathan Anand            India   NaN       NaN
# ...              ...                ...              ...   ...       ...
# 1149  United Kingdom      Roger Federer      Switzerland   NaN       NaN
# 1150  United Kingdom     Novak Djokovic           Serbia   NaN       NaN
# 1151  United Kingdom     Novak Djokovic           Serbia   NaN       NaN
# 1152  United Kingdom     Novak Djokovic           Serbia   NaN       NaN
# 1153  United Kingdom     Novak Djokovic           Serbia   NaN       NaN
#
#      runner_up_country host_venue attendance third_place third_place_country
# 0                  NaN        NaN        NaN         NaN                 NaN
# 1                  NaN        NaN        NaN         NaN                 NaN
# 2                  NaN        NaN        NaN         NaN                 NaN
# 3                  NaN        NaN        NaN         NaN                 NaN
# 4                  NaN        NaN        NaN         NaN                 NaN
# ...                ...        ...        ...         ...                 ...
# 1149               NaN        NaN        NaN         NaN                 NaN
# 1150               NaN        NaN        NaN         NaN                 NaN
# 1151               NaN        NaN        NaN         NaN                 NaN
# 1152               NaN        NaN        NaN         NaN                 NaN
# 1153               NaN        NaN        NaN         NaN                 NaN
#
# [1157 rows x 18 columns]

# %% [markdown]
# ## Worlds

# %%
worlds_data_frame = champions_data_frame[champions_data_frame['competition'] == "Worlds"]
worlds_data_frame
# Out:
#                  sport    competition_tour competition_type competition  \
# 791  League of Legends  World Championship              NaN      Worlds
# 792  League of Legends  World Championship              NaN      Worlds
# 793  League of Legends  World Championship              NaN      Worlds
# 794  League of Legends  World Championship              NaN      Worlds
# 795  League of Legends  World Championship              NaN      Worlds
# 796  League of Legends  World Championship              NaN      Worlds
# 797  League of Legends  World Championship              NaN      Worlds
# 798  League of Legends  World Championship              NaN      Worlds
# 799  League of Legends  World Championship              NaN      Worlds
# 800  League of Legends  World Championship              NaN      Worlds
# 801  League of Legends  World Championship              NaN      Worlds
# 802  League of Legends  World Championship              NaN      Worlds
# 803  League of Legends  World Championship              NaN      Worlds
#
#     season  month host_city host_state host_country         champion  \
# 791   2011    NaN       NaN        NaN          NaN           Fnatic
# 792   2012    NaN       NaN        NaN          NaN           J Team
# 793   2013    NaN       NaN        NaN          NaN               T1
# 794   2014    NaN       NaN        NaN          NaN   Samsung Galaxy
# 795   2015    NaN       NaN        NaN          NaN               T1
# 796   2016    NaN       NaN        NaN          NaN               T1
# 797   2017    NaN       NaN        NaN          NaN   Samsung Galaxy
# 798   2018    NaN       NaN        NaN          NaN  Invictus Gaming
# 799   2019    NaN       NaN        NaN          NaN  FunPlus Phoenix
# 800   2020    NaN       NaN        NaN          NaN        Dplus KIA
# 801   2021    NaN       NaN        NaN          NaN    Edward Gaming
# 802   2022    NaN       NaN        NaN          NaN              DRX
# 803   2023    NaN       NaN        NaN          NaN               T1
#
#     champion_country score              runner_up runner_up_country  \
# 791   United Kingdom   NaN  against All authority            France
# 792           Taiwan   NaN              OGN Entus       South Korea
# 793      South Korea   NaN             Royal Club             China
# 794      South Korea   NaN             Royal Club             China
# 795      South Korea   NaN    Hanwha Life Esports       South Korea
# 796      South Korea   NaN         Samsung Galaxy       South Korea
# 797      South Korea   NaN                     T1       South Korea
# 798            China   NaN                 Fnatic    United Kingdom
# 799            China   NaN             G2 Esports           Germany
# 800      South Korea   NaN           Weibo Gaming             China
# 801            China   NaN                DWG KIA       South Korea
# 802      South Korea   NaN                     T1       South Korea
# 803      South Korea   NaN           Weibo Gaming             China
#
#     host_venue attendance third_place third_place_country
# 791        NaN        NaN         NaN                 NaN
# 792        NaN        NaN         NaN                 NaN
# 793        NaN        NaN         NaN                 NaN
# 794        NaN        NaN         NaN                 NaN
# 795        NaN        NaN         NaN                 NaN
# 796        NaN        NaN         NaN                 NaN
# 797        NaN        NaN         NaN                 NaN
# 798        NaN        NaN         NaN                 NaN
# 799        NaN        NaN         NaN                 NaN
# 800        NaN        NaN         NaN                 NaN
# 801        NaN        NaN         NaN                 NaN
# 802        NaN        NaN         NaN                 NaN
# 803        NaN        NaN         NaN                 NaN

# %%
champions = worlds_data_frame[['champion', 'champion_country']].value_counts()
champions
# Out:
# champion         champion_country
# T1               South Korea         4
# Samsung Galaxy   South Korea         2
# DRX              South Korea         1
# Dplus KIA        South Korea         1
# Edward Gaming    China               1
# Fnatic           United Kingdom      1
# FunPlus Phoenix  China               1
# Invictus Gaming  China               1
# J Team           Taiwan              1
# Name: count, dtype: int64

# %%
runners_up = worlds_data_frame[['runner_up', 'runner_up_country']].value_counts()
runners_up
# Out:
# runner_up              runner_up_country
# Royal Club             China                2
# T1                     South Korea          2
# Weibo Gaming           China                2
# DWG KIA                South Korea          1
# Fnatic                 United Kingdom       1
# G2 Esports             Germany              1
# Hanwha Life Esports    South Korea          1
# OGN Entus              South Korea          1
# Samsung Galaxy         South Korea          1
# against All authority  France               1
# Name: count, dtype: int64

# %%
finals = worlds_data_frame[['champion', 'runner_up']].value_counts()
finals
# Out:
# champion         runner_up
# DRX              T1                       1
# Dplus KIA        Weibo Gaming             1
# Edward Gaming    DWG KIA                  1
# Fnatic           against All authority    1
# FunPlus Phoenix  G2 Esports               1
# Invictus Gaming  Fnatic                   1
# J Team           OGN Entus                1
# Samsung Galaxy   Royal Club               1
#                  T1                       1
# T1               Hanwha Life Esports      1
#                  Royal Club               1
#                  Samsung Galaxy           1
#                  Weibo Gaming             1
# Name: count, dtype: int64

# %% [markdown]
# ## The International

# %%
international_data_frame = champions_data_frame[champions_data_frame['competition'] == "The International"]
international_data_frame
# Out:
#                                   sport    competition_tour competition_type  \
# 302  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 303  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 304  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 305  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 306  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 307  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 308  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 309  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 310  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 311  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 312  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
# 313  Defense of the Ancients 2 (DotA 2)  World Championship              NaN
#
#            competition season  month host_city host_state host_country  \
# 302  The International   2011    NaN       NaN        NaN          NaN
# 303  The International   2012    NaN       NaN        NaN          NaN
# 304  The International   2013    NaN       NaN        NaN          NaN
# 305  The International   2014    NaN       NaN        NaN          NaN
# 306  The International   2015    NaN       NaN        NaN          NaN
# 307  The International   2016    NaN       NaN        NaN          NaN
# 308  The International   2017    NaN       NaN        NaN          NaN
# 309  The International   2018    NaN       NaN        NaN          NaN
# 310  The International   2019    NaN       NaN        NaN          NaN
# 311  The International   2021    NaN       NaN        NaN          NaN
# 312  The International   2022    NaN       NaN        NaN          NaN
# 313  The International   2023    NaN       NaN        NaN          NaN
#
#             champion champion_country score runner_up runner_up_country  \
# 302    Natus Vincere         Ukrainia   NaN       NaN               NaN
# 303  Invictus Gaming            China   NaN       NaN               NaN
# 304         Alliance           Sweden   NaN       NaN               NaN
# 305           Newbee            China   NaN       NaN               NaN
# 306    Evil Geniuses    United States   NaN       NaN               NaN
# 307     Wings Gaming            China   NaN       NaN               NaN
# 308      Team Liquid      Netherlands   NaN       NaN               NaN
# 309               OG           Europe   NaN       NaN               NaN
# 310               OG           Europe   NaN       NaN               NaN
# 311      Team Spirit           Russia   NaN       NaN               NaN
# 312   Tundra Esports    United Kingom   NaN       NaN               NaN
# 313      Team Spirit           Russia   NaN       NaN               NaN
#
#     host_venue attendance third_place third_place_country
# 302        NaN        NaN         NaN                 NaN
# 303        NaN        NaN         NaN                 NaN
# 304        NaN        NaN         NaN                 NaN
# 305        NaN        NaN         NaN                 NaN
# 306        NaN        NaN         NaN                 NaN
# 307        NaN        NaN         NaN                 NaN
# 308        NaN        NaN         NaN                 NaN
# 309        NaN        NaN         NaN                 NaN
# 310        NaN        NaN         NaN                 NaN
# 311        NaN        NaN         NaN                 NaN
# 312        NaN        NaN         NaN                 NaN
# 313        NaN        NaN         NaN                 NaN

# %% [markdown]
# ## FIFAe World Cup

# %%
fifa_data_frame = champions_data_frame[champions_data_frame['competition'] == "FIFAe World Cup"]
fifa_data_frame
# Out:
#     sport    competition_tour competition_type      competition season  month  \
# 314  FIFA  World Championship              NaN  FIFAe World Cup   2004    NaN
# 315  FIFA  World Championship              NaN  FIFAe World Cup   2005    NaN
# 316  FIFA  World Championship              NaN  FIFAe World Cup   2006    NaN
# 317  FIFA  World Championship              NaN  FIFAe World Cup   2008    NaN
# 318  FIFA  World Championship              NaN  FIFAe World Cup   2009    NaN
# 319  FIFA  World Championship              NaN  FIFAe World Cup   2010    NaN
# 320  FIFA  World Championship              NaN  FIFAe World Cup   2011    NaN
# 321  FIFA  World Championship              NaN  FIFAe World Cup   2012    NaN
# 322  FIFA  World Championship              NaN  FIFAe World Cup   2013    NaN
# 323  FIFA  World Championship              NaN  FIFAe World Cup   2014    NaN
# 324  FIFA  World Championship              NaN  FIFAe World Cup   2015    NaN
# 325  FIFA  World Championship              NaN  FIFAe World Cup   2016    NaN
# 326  FIFA  World Championship              NaN  FIFAe World Cup   2017    NaN
# 327  FIFA  World Championship              NaN  FIFAe World Cup   2018    NaN
# 328  FIFA  World Championship              NaN  FIFAe World Cup   2019    NaN
# 329  FIFA  World Championship              NaN  FIFAe World Cup   2020    NaN
# 330  FIFA  World Championship              NaN  FIFAe World Cup   2021    NaN
# 331  FIFA  World Championship              NaN  FIFAe World Cup   2022    NaN
# 332  FIFA  World Championship              NaN  FIFAe World Cup   2023    NaN
# 333  FIFA  World Championship              NaN  FIFAe World Cup   2024    NaN
# 334  FIFA  World Championship              NaN  FIFAe World Cup   2025    NaN
#
#           host_city host_state          host_country  \
# 314          Zurich        NaN           Switzerland
# 315          London        NaN               England
# 316       Amsterdam        NaN           Netherlands
# 317          Berlin        NaN               Germany
# 318       Barcelona        NaN                 Spain
# 319       Barcelona        NaN                 Spain
# 320     Los Angeles        NaN         United States
# 321           Dubai        NaN  United Arab Emirates
# 322          Madrid        NaN                 Spain
# 323  Rio de Janeiro        NaN                Brazil
# 324          Munich        NaN               Germany
# 325   New York City        NaN         United States
# 326          London        NaN               England
# 327          London        NaN               England
# 328          London        NaN               England
# 329           Seoul        NaN           South Korea
# 330       Melbourne        NaN             Australia
# 331      Copenhagen        NaN               Denmark
# 332          Riyadh        NaN          Saudi Arabia
# 333       Singapore        NaN             Singapore
# 334           Tokyo        NaN                 Japan
#
#                       champion champion_country score               runner_up  \
# 314  Thiago Carrico de Azevedo           Brazil   NaN      Matija Biljeskovic
# 315              Chris Bullard          England   NaN             Gábor Mokos
# 316               Andries Smit      Netherlands   NaN          Wolfgang Meier
# 317              Alfonso Ramos            Spain   NaN         Michael Ribeiro
# 318              Bruce Grannec           France   NaN  Ruben Morales Zerecero
# 319            Nenad Stojkovic           Serbia   NaN          Ayhan Altundag
# 320             Francisco Cruz         Portugal   NaN            Javier Munoz
# 321              Alfonso Ramos            Spain   NaN           Bruce Grannec
# 322              Bruce Grannec           France   NaN    Andrei Torres Vivero
# 323          August Rosenmeier          Denmark   NaN          David Bytheway
# 324         Abdulaziz Alshehri     Saudi Arabia   NaN      Julien Dassonville
# 325           Mohamad Al-Bacha          Denmark   NaN              Sean Allen
# 326             Spencer Ealing          England   NaN              Kai Wollin
# 327          Mosaad Al Dossary     Saudi Arabia   NaN           Stefano Pinna
# 328           Mohammed Harkous          Germany   NaN        Mosaad Aldossary
# 329          Mosaad Al Dossary     Saudi Arabia   NaN        Nicolas Villalba
# 330           Nicolas Villalba        Argentina   NaN        Mohammed Harkous
# 331              Umut Gültekin          Germany   NaN        Nicolas Villalba
# 332            Manuel Bachoore      Netherlands   NaN            Mark Zakhary
# 333                        NaN              NaN   NaN                     NaN
# 334                        NaN              NaN   NaN                     NaN
#
#     runner_up_country host_venue attendance third_place third_place_country
# 314     United States        NaN        NaN         NaN                 NaN
# 315           Hungary        NaN        NaN         NaN                 NaN
# 316           Austria        NaN        NaN         NaN                 NaN
# 317     United States        NaN        NaN         NaN                 NaN
# 318            Mexico        NaN        NaN         NaN                 NaN
# 319           Germany        NaN        NaN         NaN                 NaN
# 320          Columbia        NaN        NaN         NaN                 NaN
# 321            France        NaN        NaN         NaN                 NaN
# 322            Mexico        NaN        NaN         NaN                 NaN
# 323           England        NaN        NaN         NaN                 NaN
# 324            France        NaN        NaN         NaN                 NaN
# 325           England        NaN        NaN         NaN                 NaN
# 326           Germany        NaN        NaN         NaN                 NaN
# 327           Belgium        NaN        NaN         NaN                 NaN
# 328      Saudi Arabia        NaN        NaN         NaN                 NaN
# 329         Argentina        NaN        NaN         NaN                 NaN
# 330           Germany        NaN        NaN         NaN                 NaN
# 331         Argentina        NaN        NaN         NaN                 NaN
# 332         Australia        NaN        NaN         NaN                 NaN
# 333               NaN        NaN        NaN         NaN                 NaN
# 334               NaN        NaN        NaN         NaN                 NaN

# %%
champions = fifa_data_frame[['champion', 'champion_country']].value_counts()
champions
# Out:
# champion                   champion_country
# Alfonso Ramos              Spain               2
# Bruce Grannec              France              2
# Mosaad Al Dossary          Saudi Arabia        2
# Abdulaziz Alshehri         Saudi Arabia        1
# Andries Smit               Netherlands         1
# August Rosenmeier          Denmark             1
# Chris Bullard              England             1
# Francisco Cruz             Portugal            1
# Manuel Bachoore            Netherlands         1
# Mohamad Al-Bacha           Denmark             1
# Mohammed Harkous           Germany             1
# Nenad Stojkovic            Serbia              1
# Nicolas Villalba           Argentina           1
# Spencer Ealing             England             1
# Thiago Carrico de Azevedo  Brazil              1
# Umut Gültekin              Germany             1
# Name: count, dtype: int64

# %%
runners_up = fifa_data_frame[['runner_up', 'runner_up_country']].value_counts()
runners_up
# Out:
# runner_up               runner_up_country
# Nicolas Villalba        Argentina            2
# Andrei Torres Vivero    Mexico               1
# Ayhan Altundag          Germany              1
# Stefano Pinna           Belgium              1
# Sean Allen              England              1
# Ruben Morales Zerecero  Mexico               1
# Mosaad Aldossary        Saudi Arabia         1
# Mohammed Harkous        Germany              1
# Michael Ribeiro         United States        1
# Matija Biljeskovic      United States        1
# Mark Zakhary            Australia            1
# Kai Wollin              Germany              1
# Julien Dassonville      France               1
# Javier Munoz            Columbia             1
# Gábor Mokos             Hungary              1
# David Bytheway          England              1
# Bruce Grannec           France               1
# Wolfgang Meier          Austria              1
# Name: count, dtype: int64
