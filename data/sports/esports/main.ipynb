# %%
import pandas as pd

# %%
champions_data_frame = pd.read_csv("./champions.csv")
champions_data_frame = champions_data_frame.sort_values(by=['sport', 'competition', 'year'])
champions_data_frame.to_csv("./champions.csv", index=False)
champions_data_frame
# Out:
#                  sport time_class          competition_tour  \
# 0                Chess     bullet  Speed Chess Championship
# 1                Chess     bullet  Speed Chess Championship
# 2                Chess     bullet  Speed Chess Championship
# 3                Chess  classical        World Championship
# 4                Chess  classical        World Championship
# ..                 ...        ...                       ...
# 343  League of Legends        NaN        World Championship
# 344  League of Legends        NaN        World Championship
# 345  League of Legends        NaN        World Championship
# 346  League of Legends        NaN        World Championship
# 347  League of Legends        NaN        World Championship
#
#                    competition  year        host_city host_state host_country  \
# 0    Bullet Chess Championship  2021              NaN        NaN          NaN
# 1    Bullet Chess Championship  2022              NaN        NaN          NaN
# ...

# %% [markdown]
# ## Worlds

# %%
worlds_data_frame = champions_data_frame[champions_data_frame['competition'] == "Worlds"]
worlds_data_frame
# Out:
#                  sport time_class    competition_tour competition  year  \
# 335  League of Legends        NaN  World Championship      Worlds  2011
# 336  League of Legends        NaN  World Championship      Worlds  2012
# 337  League of Legends        NaN  World Championship      Worlds  2013
# 338  League of Legends        NaN  World Championship      Worlds  2014
# 339  League of Legends        NaN  World Championship      Worlds  2015
# 340  League of Legends        NaN  World Championship      Worlds  2016
# 341  League of Legends        NaN  World Championship      Worlds  2017
# 342  League of Legends        NaN  World Championship      Worlds  2018
# 343  League of Legends        NaN  World Championship      Worlds  2019
# 344  League of Legends        NaN  World Championship      Worlds  2020
# 345  League of Legends        NaN  World Championship      Worlds  2021
# 346  League of Legends        NaN  World Championship      Worlds  2022
# ...

# %%
champions = worlds_data_frame[['champion', 'champion_country']].value_counts()
champions
# Out:
# champion         champion_country
# T1               South Korea         4
# Samsung Galaxy   South Korea         2
# DRX              South Korea         1
# Dplus KIA        South Korea         1
# Edward Gaming    China               1
# Fnatic           United Kingdom      1
# FunPlus Phoenix  China               1
# Invictus Gaming  China               1
# J Team           Taiwan              1
# Name: count, dtype: int64

# %%
runners_up = worlds_data_frame[['runner_up', 'runner_up_country']].value_counts()
runners_up
# Out:
# runner_up              runner_up_country
# Royal Club             China                2
# T1                     South Korea          2
# Weibo Gaming           China                2
# DWG KIA                South Korea          1
# Fnatic                 United Kingdom       1
# G2 Esports             Germany              1
# Hanwha Life Esports    South Korea          1
# OGN Entus              South Korea          1
# Samsung Galaxy         South Korea          1
# against All authority  France               1
# Name: count, dtype: int64

# %%
finals = worlds_data_frame[['champion', 'runner_up']].value_counts()
finals
# Out:
# champion         runner_up
# DRX              T1                       1
# Dplus KIA        Weibo Gaming             1
# Edward Gaming    DWG KIA                  1
# Fnatic           against All authority    1
# FunPlus Phoenix  G2 Esports               1
# Invictus Gaming  Fnatic                   1
# J Team           OGN Entus                1
# Samsung Galaxy   Royal Club               1
#                  T1                       1
# T1               Hanwha Life Esports      1
#                  Royal Club               1
#                  Samsung Galaxy           1
#                  Weibo Gaming             1
# Name: count, dtype: int64

# %% [markdown]
# ## The International

# %%
international_data_frame = champions_data_frame[champions_data_frame['competition'] == "The International"]
international_data_frame
# Out:
#                                   sport time_class    competition_tour  \
# 302  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 303  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 304  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 305  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 306  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 307  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 308  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 309  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 310  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 311  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 312  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
# 313  Defense of the Ancients 2 (DotA 2)        NaN  World Championship
#
# ...

# %% [markdown]
# ## FIFAe World Cup

# %%
fifa_data_frame = champions_data_frame[champions_data_frame['competition'] == "FIFAe World Cup"]
fifa_data_frame
# Out:
#     sport time_class    competition_tour      competition  year  \
# 314  FIFA        NaN  World Championship  FIFAe World Cup  2004
# 315  FIFA        NaN  World Championship  FIFAe World Cup  2005
# 316  FIFA        NaN  World Championship  FIFAe World Cup  2006
# 317  FIFA        NaN  World Championship  FIFAe World Cup  2008
# 318  FIFA        NaN  World Championship  FIFAe World Cup  2009
# 319  FIFA        NaN  World Championship  FIFAe World Cup  2010
# 320  FIFA        NaN  World Championship  FIFAe World Cup  2011
# 321  FIFA        NaN  World Championship  FIFAe World Cup  2012
# 322  FIFA        NaN  World Championship  FIFAe World Cup  2013
# 323  FIFA        NaN  World Championship  FIFAe World Cup  2014
# 324  FIFA        NaN  World Championship  FIFAe World Cup  2015
# 325  FIFA        NaN  World Championship  FIFAe World Cup  2016
# 326  FIFA        NaN  World Championship  FIFAe World Cup  2017
# 327  FIFA        NaN  World Championship  FIFAe World Cup  2018
# ...

# %%
champions = fifa_data_frame[['champion', 'champion_country']].value_counts()
champions
# Out:
# champion                   champion_country
# Alfonso Ramos              Spain               2
# Bruce Grannec              France              2
# Mosaad Al Dossary          Saudi Arabia        2
# Abdulaziz Alshehri         Saudi Arabia        1
# Andries Smit               Netherlands         1
# August Rosenmeier          Denmark             1
# Chris Bullard              England             1
# Francisco Cruz             Portugal            1
# Manuel Bachoore            Netherlands         1
# Mohamad Al-Bacha           Denmark             1
# Mohammed Harkous           Germany             1
# Nenad Stojkovic            Serbia              1
# Nicolas Villalba           Argentina           1
# Spencer Ealing             England             1
# Thiago Carrico de Azevedo  Brazil              1
# Umut Gültekin              Germany             1
# Name: count, dtype: int64

# %%
runners_up = fifa_data_frame[['runner_up', 'runner_up_country']].value_counts()
runners_up
# Out:
# runner_up               runner_up_country
# Nicolas Villalba        Argentina            2
# Andrei Torres Vivero    Mexico               1
# Ayhan Altundag          Germany              1
# Stefano Pinna           Belgium              1
# Sean Allen              England              1
# Ruben Morales Zerecero  Mexico               1
# Mosaad Aldossary        Saudi Arabia         1
# Mohammed Harkous        Germany              1
# Michael Ribeiro         United States        1
# Matija Biljeskovic      United States        1
# Mark Zakhary            Australia            1
# Kai Wollin              Germany              1
# Julien Dassonville      France               1
# Javier Munoz            Columbia             1
# Gábor Mokos             Hungary              1
# David Bytheway          England              1
# Bruce Grannec           France               1
# Wolfgang Meier          Austria              1
# Name: count, dtype: int64
