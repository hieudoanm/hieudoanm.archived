# %%
import pandas

# %%
champions_data_frame = pandas.read_csv("./champions.csv")
champions_data_frame
# Out:
#                  competition    year          host      champion  \
# 0             FIFA World Cup  1930.0       Uruguay       Uruguay
# 1             FIFA World Cup  1934.0         Italy         Italy
# 2             FIFA World Cup  1938.0        France         Italy
# 3             FIFA World Cup  1950.0        Brazil       Uruguay
# 4             FIFA World Cup  1954.0   Switzerland  West Germany
# ..                       ...     ...           ...           ...
# 106  FIFA Confederations Cup  2003.0        France        France
# 107  FIFA Confederations Cup  2005.0       Germany        Brazil
# 108  FIFA Confederations Cup  2009.0  South Africa        Brazil
# 109  FIFA Confederations Cup  2013.0        Brazil        Brazil
# 110  FIFA Confederations Cup  2017.0        Russia       Germany
#
#     champion_former  champion_score       runner_up runner_up_former  \
# 0               NaN             NaN       Argentina              NaN
# ...

# %%
competitions = champions_data_frame["competition"].unique()
competitions
# Out:
# array(['FIFA World Cup', 'UEFA European Championship', 'AFC Asian Cup',
#        'AFF Cup', 'Copa América', 'FIFA Confederations Cup'], dtype=object)

# %% [markdown]
# ## FIFA World Cup

# %%
world_cup_data_frame = champions_data_frame[champions_data_frame["competition"] == "FIFA World Cup"]
world_cup_data_frame
# Out:
#        competition    year               host      champion champion_former  \
# 0   FIFA World Cup  1930.0            Uruguay       Uruguay             NaN
# 1   FIFA World Cup  1934.0              Italy         Italy             NaN
# 2   FIFA World Cup  1938.0             France         Italy             NaN
# 3   FIFA World Cup  1950.0             Brazil       Uruguay             NaN
# 4   FIFA World Cup  1954.0        Switzerland  West Germany             NaN
# 5   FIFA World Cup  1958.0             Sweden        Brazil             NaN
# 6   FIFA World Cup  1962.0              Chile        Brazil             NaN
# 7   FIFA World Cup  1966.0            England       England             NaN
# 8   FIFA World Cup  1970.0             Mexico        Brazil             NaN
# 9   FIFA World Cup  1974.0       West Germany  West Germany             NaN
# 10  FIFA World Cup  1978.0          Argentina     Argentina             NaN
# ...

# %%
hosts = world_cup_data_frame['host'].value_counts()
hosts
# Out:
# host
# France               2
# Brazil               2
# Mexico               2
# Italy                2
# Uruguay              1
# Spain                1
# Russia               1
# South Africa         1
# Germany              1
# South Korea;Japan    1
# United States        1
# West Germany         1
# Argentina            1
# England              1
# Chile                1
# Sweden               1
# Switzerland          1
# Qatar                1
# Name: count, dtype: int64

# %%
champions = world_cup_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Brazil          5
# Italy           4
# West Germany    3
# Argentina       3
# Uruguay         2
# France          2
# England         1
# Spain           1
# Germany         1
# Name: count, dtype: int64

# %%
runners_up = world_cup_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Argentina         3
# West Germany      3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# France            2
# Sweden            1
# Germany           1
# Croatia           1
# Name: count, dtype: int64

# %% [markdown]
# ## FIFA Confederations Cup

# %%
confederations_cup_data_frame = champions_data_frame[champions_data_frame["competition"] == "FIFA Confederations Cup"]
confederations_cup_data_frame
# Out:
#                  competition    year                 host    champion  \
# 101  FIFA Confederations Cup  1992.0         Saudi Arabia  Argentina
# 102  FIFA Confederations Cup  1995.0         Saudi Arabia     Denmark
# 103  FIFA Confederations Cup  1997.0         Saudi Arabia     Brazil
# 104  FIFA Confederations Cup  1999.0               Mexico      Mexico
# 105  FIFA Confederations Cup  2001.0  South Korea / Japan      France
# 106  FIFA Confederations Cup  2003.0               France      France
# 107  FIFA Confederations Cup  2005.0              Germany      Brazil
# 108  FIFA Confederations Cup  2009.0         South Africa      Brazil
# 109  FIFA Confederations Cup  2013.0               Brazil      Brazil
# 110  FIFA Confederations Cup  2017.0               Russia     Germany
#
#     champion_former  champion_score       runner_up runner_up_former  \
# 101             NaN             3.0   Saudi Arabia               NaN
# ...

# %%
champions = confederations_cup_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Brazil        3
# France        2
# Argentina     1
# Denmark       1
# Brazil        1
# Mexico        1
# Germany       1
# Name: count, dtype: int64
