# %%
import pandas as pd

# %%
players_data_frame = pd.read_csv("./players.csv")
players_data_frame = players_data_frame.sort_values(by=['club', 'position_line'])
players_data_frame.to_csv("./players.csv", index=False)
players_data_frame
# Out:
#              club position_line              position abbreviation  \
# 0        AC Milan    1-Defender             Left Back           LB
# 1        AC Milan    1-Defender           Centre Back           CB
# 2        AC Milan    1-Defender           Centre Back           CB
# 3        AC Milan  2-Midfielder  Attacking Midfielder           AM
# 4       Barcelona    1-Defender            Right Back           RB
# 5       Barcelona  2-Midfielder    Central Midfielder           CM
# 6       Barcelona  2-Midfielder  Attacking Midfielder           AM
# 7       Barcelona  2-Midfielder  Defensive Midfielder           DM
# 8       Barcelona     3-Forward           Left Winger           LW
# 9       Barcelona     3-Forward           Left Winger           LW
# 10      Barcelona     3-Forward       Central Forward           CF
# 11      Barcelona     3-Forward           Left Winger           LW
# 12  Bayern Munich  0-Goalkeeper            Goalkeeper           GK
# ...
