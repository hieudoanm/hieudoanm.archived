# %%
import pandas

# %%
top_scorers_data_frame = pandas.read_csv("./datasets.csv")
top_scorers_data_frame
# Out:
#         competition     season            name      country  \
# 0        Eredivisie    1956-57     Coen Dillen          NaN
# 1        Eredivisie    1957-58     Leo Canjels          NaN
# 2        Eredivisie    1958-59     Leo Canjels          NaN
# 3        Eredivisie    1959-60      Henk Groot          NaN
# 4        Eredivisie    1960-61      Henk Groot          NaN
# ..              ...        ...             ...          ...
# 333  Premier League  2019-2020     Jamie Vardy      England
# 334  Premier League  2020-2021      Harry Kane      England
# 335  Premier League  2021-2022   Mohamed Salah        Egypt
# 336  Premier League  2021-2022   Son Heung-min  South Korea
# 337  Premier League  2022-2023  Erling Haaland       Norway
#
#                   club goals games  rate
# 0                  NaN    43   NaN   NaN
# 1                  NaN    32   NaN   NaN
# 2                  NaN    34   NaN   NaN
# 3                  NaN    38   NaN   NaN
# ...

# %%
sorted_top_scorers_data_frame = top_scorers_data_frame.sort_values(by=['competition', 'season'])
sorted_top_scorers_data_frame.to_csv("./top-scorers.csv", index=False)
sorted_top_scorers_data_frame
# Out:
#      competition   season               name   country      club  goals  \
# 0     Eredivisie  1956-57        Coen Dillen       NaN       NaN     43
# 1     Eredivisie  1957-58        Leo Canjels       NaN       NaN     32
# 2     Eredivisie  1958-59        Leo Canjels       NaN       NaN     34
# 3     Eredivisie  1959-60         Henk Groot       NaN       NaN     38
# 4     Eredivisie  1960-61         Henk Groot       NaN       NaN     41
# ..           ...      ...                ...       ...       ...    ...
# 294      Serie A  2019-20      Ciro Immobile     Italy     Lazio     36
# 295      Serie A  2020-21  Cristiano Ronaldo  Portugal  Juventus     29
# 296      Serie A  2021-22      Ciro Immobile     Italy     Lazio     27
# 297      Serie A  2022-23     Victor Osimhen   Nigeria    Napoli     26
# 298  competition   season               name   country      club  goals
#
#      games  rate
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# ...

# %%
competitions = top_scorers_data_frame["competition"].unique()
competitions
# Out:
# array(['Eredivisie', 'La Liga', 'Primeira Liga', 'Serie A', 'competition',
#        'Premier League'], dtype=object)

# %% [markdown]
# ## Premier League

# %%
premier_league_top_scorers_data_frame = top_scorers_data_frame[top_scorers_data_frame["competition"] == "Premier League"]
premier_league_top_scorers_data_frame
# Out:
#         competition     season                       name  \
# 299  Premier League  1992-1993           Teddy Sheringham
# 300  Premier League  1993-1994                  Andy Cole
# 301  Premier League  1994-1995               Alan Shearer
# 302  Premier League  1995-1996               Alan Shearer
# 303  Premier League  1996-1997               Alan Shearer
# 304  Premier League  1997-1998               Chris Sutton
# 305  Premier League  1997-1998                Dion Dublin
# 306  Premier League  1997-1998               Michael Owen
# 307  Premier League  1998-1999               Michael Owen
# 308  Premier League  1998-1999               Dwight Yorke
# 309  Premier League  1998-1999    Jimmy Floyd Hasselbaink
# 310  Premier League  1999-2000             Kevin Phillips
# 311  Premier League  2000-2001    Jimmy Floyd Hasselbaink
# 312  Premier League  2001-2002              Thierry Henry
# 313  Premier League  2002-2003        Ruud van Nistelrooy
# ...

# %%
top_scorers = premier_league_top_scorers_data_frame['name'].value_counts()
top_scorers
# Out:
# name
# Thierry Henry                4
# Alan Shearer                 3
# Mohamed Salah                3
# Harry Kane                   3
# Robin van Persie             2
# Michael Owen                 2
# Jimmy Floyd Hasselbaink      2
# Didier Drogba                2
# Teddy Sheringham             1
# Son Heung-min                1
# Jamie Vardy                  1
# Sadio Mané                   1
# Pierre-Emerick Aubameyang    1
# Sergio Agüero                1
# Luis Suárez                  1
# Nicolas Anelka               1
# Dimitar Berbatov             1
# Carlos Tevez                 1
# Andy Cole                    1
# Cristiano Ronaldo            1
# Ruud van Nistelrooy          1
# Kevin Phillips               1
# Dwight Yorke                 1
# Dion Dublin                  1
# Chris Sutton                 1
# Erling Haaland               1
# Name: count, dtype: int64
