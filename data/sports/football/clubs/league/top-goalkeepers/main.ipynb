# %%
import pandas

# %%
golden_gloves_data_frame = pandas.read_csv("./datasets.csv")
golden_gloves_data_frame
# Out:
#     season_start  season_end               name         country  \
# 0           2004        2005          Petr Čech  Czech Republic
# 1           2005        2006         Pepe Reina           Spain
# 2           2006        2007         Pepe Reina           Spain
# 3           2007        2008         Pepe Reina           Spain
# 4           2008        2009  Edwin van der Sar     Netherlands
# 5           2009        2010          Petr Čech  Czech Republic
# 6           2010        2011           Joe Hart         England
# 7           2011        2012           Joe Hart         England
# 8           2012        2013           Joe Hart         England
# 9           2013        2014          Petr Čech  Czech Republic
# 10          2013        2014  Wojciech Szczęsny          Poland
# 11          2014        2015           Joe Hart         England
# 12          2015        2016          Petr Čech  Czech Republic
# 13          2016        2017   Thibaut Courtois         Belgium
# ...

# %%
players = golden_gloves_data_frame["name"].value_counts()
players
# Out:
# name
# Petr Čech            4
# Joe Hart             4
# Pepe Reina           3
# Ederson              3
# David de Gea         2
# Alisson              2
# Edwin van der Sar    1
# Wojciech Szczęsny    1
# Thibaut Courtois     1
# Name: count, dtype: int64
