# %%
import pandas

# %%
standings_data_frame = pandas.read_csv("./datasets.csv")
standings_data_frame
# Out:
#     competition     season                champion champion_former  \
# 0    Bundesliga  1963-1964              1. FC Köln             NaN
# 1    Bundesliga  1964-1965           Werder Bremen             NaN
# 2    Bundesliga  1965-1966         TSV 1860 Munich             NaN
# 3    Bundesliga  1966-1967  Eintracht Braunschweig             NaN
# 4    Bundesliga  1967-1968          1. FC Nürnberg             NaN
# ..          ...        ...                     ...             ...
# 579   J1 League       2018       Kawasaki Frontale             NaN
# 580   J1 League       2019     Yokohama F. Marinos             NaN
# 581   J1 League       2020       Kawasaki Frontale             NaN
# 582   J1 League       2021       Kawasaki Frontale             NaN
# 583   J1 League       2022     Yokohama F. Marinos             NaN
#
#      champion_point            runner_up runner_up_former  runner_up_point  \
# 0               NaN       Meidericher SV              NaN              NaN
# 1               NaN           1. FC Köln              NaN              NaN
# 2               NaN    Borussia Dortmund              NaN              NaN
# 3               NaN      TSV 1860 Munich              NaN              NaN
# 4               NaN        Werder Bremen              NaN              NaN
# ..              ...                  ...              ...              ...
# 579             NaN  Sanfrecce Hiroshima              NaN              NaN
# 580             NaN             FC Tokyo              NaN              NaN
# 581             NaN          Gamba Osaka              NaN              NaN
# 582             NaN  Yokohama F. Marinos              NaN              NaN
# 583             NaN    Kawasaki Frontale              NaN              NaN
#
#                   third_place third_place_former  third_place_point  \
# 0         Eintracht Frankfurt                NaN                NaN
# 1           Borussia Dortmund                NaN                NaN
# 2               Bayern Munich                NaN                NaN
# 3           Borussia Dortmund                NaN                NaN
# 4    Borussia Mönchengladbach                NaN                NaN
# ..                        ...                ...                ...
# 579           Kashima Antlers                NaN                NaN
# 580           Kashima Antlers                NaN                NaN
# 581            Nagoya Grampus                NaN                NaN
# 582               Vissel Kobe                NaN                NaN
# 583       Sanfrecce Hiroshima                NaN                NaN
#
#     fourth_place  fourth_place_point  teams  rounds
# 0            NaN                 NaN    NaN     NaN
# 1            NaN                 NaN    NaN     NaN
# 2            NaN                 NaN    NaN     NaN
# 3            NaN                 NaN    NaN     NaN
# 4            NaN                 NaN    NaN     NaN
# ..           ...                 ...    ...     ...
# 579          NaN                 NaN    NaN     NaN
# 580          NaN                 NaN    NaN     NaN
# 581          NaN                 NaN    NaN     NaN
# 582          NaN                 NaN    NaN     NaN
# 583          NaN                 NaN    NaN     NaN
#
# [584 rows x 15 columns]

# %%
sorted_standings_data_frame = standings_data_frame.sort_values(by=['competition', 'season'])
sorted_standings_data_frame.to_csv("./datasets.csv", index=False)
sorted_standings_data_frame
# Out:
#                   competition     season                champion  \
# 0                  Bundesliga  1963-1964              1. FC Köln
# 1                  Bundesliga  1964-1965           Werder Bremen
# 2                  Bundesliga  1965-1966         TSV 1860 Munich
# 3                  Bundesliga  1966-1967  Eintracht Braunschweig
# 4                  Bundesliga  1967-1968          1. FC Nürnberg
# ..                        ...        ...                     ...
# 522  Singapore Premier League       2018         Albirex Niigata
# 523  Singapore Premier League       2019                 DPMM FC
# 524  Singapore Premier League       2020         Albirex Niigata
# 525  Singapore Premier League       2021       Lion City Sailors
# 526  Singapore Premier League       2022         Albirex Niigata
#
#     champion_former  champion_point          runner_up runner_up_former  \
# 0               NaN             NaN     Meidericher SV              NaN
# 1               NaN             NaN         1. FC Köln              NaN
# 2               NaN             NaN  Borussia Dortmund              NaN
# 3               NaN             NaN    TSV 1860 Munich              NaN
# 4               NaN             NaN      Werder Bremen              NaN
# ..              ...             ...                ...              ...
# 522             NaN             NaN  Lion City Sailors      Home United
# 523             NaN             NaN    Tampines Rovers              NaN
# 524             NaN             NaN    Tampines Rovers              NaN
# 525             NaN             NaN    Albirex Niigata              NaN
# 526             NaN             NaN  Lion City Sailors              NaN
#
#      runner_up_point               third_place third_place_former  \
# 0                NaN       Eintracht Frankfurt                NaN
# 1                NaN         Borussia Dortmund                NaN
# 2                NaN             Bayern Munich                NaN
# 3                NaN         Borussia Dortmund                NaN
# 4                NaN  Borussia Mönchengladbach                NaN
# ..               ...                       ...                ...
# 522              NaN                       NaN                NaN
# 523              NaN                       NaN                NaN
# 524              NaN                       NaN                NaN
# 525              NaN                       NaN                NaN
# 526              NaN                       NaN                NaN
#
#      third_place_point fourth_place  fourth_place_point  teams  rounds
# 0                  NaN          NaN                 NaN    NaN     NaN
# 1                  NaN          NaN                 NaN    NaN     NaN
# 2                  NaN          NaN                 NaN    NaN     NaN
# 3                  NaN          NaN                 NaN    NaN     NaN
# 4                  NaN          NaN                 NaN    NaN     NaN
# ..                 ...          ...                 ...    ...     ...
# 522                NaN          NaN                 NaN    NaN     NaN
# 523                NaN          NaN                 NaN    NaN     NaN
# 524                NaN          NaN                 NaN    NaN     NaN
# 525                NaN          NaN                 NaN    NaN     NaN
# 526                NaN          NaN                 NaN    NaN     NaN
#
# [584 rows x 15 columns]

# %%
competitions = standings_data_frame['competition'].unique()
competitions
# Out:
# array(['Bundesliga', 'Eredivisie', 'K League 1', 'K League 2', 'La Liga',
#        'Ligue 1', 'Premier League', 'Primeira Liga', 'Seria A',
#        'Singapore Premier League', 'J1 League'], dtype=object)

# %% [markdown]
# ## Premier League

# %%
premier_league_data_frame = standings_data_frame[standings_data_frame["competition"] == "Premier League"]
premier_league_data_frame
# Out:
#         competition     season           champion champion_former  \
# 353  Premier League  1992-1993  Manchester United             NaN
# 354  Premier League  1993-1994  Manchester United             NaN
# 355  Premier League  1994-1995   Blackburn Rovers             NaN
# 356  Premier League  1995-1996  Manchester United             NaN
# 357  Premier League  1996-1997  Manchester United             NaN
# 358  Premier League  1997-1998            Arsenal             NaN
# 359  Premier League  1998-1999  Manchester United             NaN
# 360  Premier League  1999-2000  Manchester United             NaN
# 361  Premier League  2000-2001  Manchester United             NaN
# 362  Premier League  2001-2002            Arsenal             NaN
# 363  Premier League  2002-2003  Manchester United             NaN
# 364  Premier League  2003-2004            Arsenal             NaN
# 365  Premier League  2004-2005            Chelsea             NaN
# 366  Premier League  2005-2006            Chelsea             NaN
# 367  Premier League  2006-2007  Manchester United             NaN
# 368  Premier League  2007-2008  Manchester United             NaN
# 369  Premier League  2008-2009  Manchester United             NaN
# 370  Premier League  2009-2010            Chelsea             NaN
# 371  Premier League  2010-2011  Manchester United             NaN
# 372  Premier League  2011-2012    Manchester City             NaN
# 373  Premier League  2012-2013  Manchester United             NaN
# 374  Premier League  2013-2014    Manchester City             NaN
# 375  Premier League  2014-2015            Chelsea             NaN
# 376  Premier League  2015-2016     Leicester City             NaN
# 377  Premier League  2016-2017            Chelsea             NaN
# 378  Premier League  2017-2018    Manchester City             NaN
# 379  Premier League  2018-2019    Manchester City             NaN
# 380  Premier League  2019-2020          Liverpool             NaN
# 381  Premier League  2020-2021    Manchester City             NaN
# 382  Premier League  2021-2022    Manchester City             NaN
# 383  Premier League  2022-2023    Manchester City             NaN
#
#      champion_point          runner_up runner_up_former  runner_up_point  \
# 353             NaN        Aston Villa              NaN              NaN
# 354             NaN   Blackburn Rovers              NaN              NaN
# 355             NaN  Manchester United              NaN              NaN
# 356             NaN   Newcastle United              NaN              NaN
# 357             NaN   Newcastle United              NaN              NaN
# 358             NaN  Manchester United              NaN              NaN
# 359             NaN            Arsenal              NaN              NaN
# 360             NaN            Arsenal              NaN              NaN
# 361             NaN            Arsenal              NaN              NaN
# 362             NaN          Liverpool              NaN              NaN
# 363             NaN            Arsenal              NaN              NaN
# 364             NaN            Chelsea              NaN              NaN
# 365             NaN            Arsenal              NaN              NaN
# 366             NaN  Manchester United              NaN              NaN
# 367             NaN            Chelsea              NaN              NaN
# 368             NaN            Chelsea              NaN              NaN
# 369             NaN          Liverpool              NaN              NaN
# 370             NaN  Manchester United              NaN              NaN
# 371             NaN            Chelsea              NaN              NaN
# 372             NaN  Manchester United              NaN              NaN
# 373             NaN    Manchester City              NaN              NaN
# 374             NaN          Liverpool              NaN              NaN
# 375             NaN    Manchester City              NaN              NaN
# 376             NaN            Arsenal              NaN              NaN
# 377             NaN  Tottenham Hotspur              NaN              NaN
# 378             NaN  Manchester United              NaN              NaN
# 379             NaN          Liverpool              NaN              NaN
# 380             NaN    Manchester City              NaN              NaN
# 381             NaN  Manchester United              NaN              NaN
# 382             NaN          Liverpool              NaN              NaN
# 383             NaN            Arsenal              NaN              NaN
#
#             third_place third_place_former  third_place_point  \
# 353        Norwich City                NaN                NaN
# 354    Newcastle United                NaN                NaN
# 355  Nottingham Forrest                NaN                NaN
# 356           Liverpool                NaN                NaN
# 357             Arsenal                NaN                NaN
# 358           Liverpool                NaN                NaN
# 359             Chelsea                NaN                NaN
# 360        Leeds United                NaN                NaN
# 361           Liverpool                NaN                NaN
# 362   Manchester United                NaN                NaN
# 363    Newcastle United                NaN                NaN
# 364   Manchester United                NaN                NaN
# 365   Manchester United                NaN                NaN
# 366           Liverpool                NaN                NaN
# 367           Liverpool                NaN                NaN
# 368             Arsenal                NaN                NaN
# 369             Chelsea                NaN                NaN
# 370             Arsenal                NaN                NaN
# 371             Arsenal                NaN                NaN
# 372                 NaN                NaN                NaN
# 373             Chelsea                NaN                NaN
# 374             Chelsea                NaN                NaN
# 375             Arsenal                NaN                NaN
# 376   Tottenham Hotspur                NaN                NaN
# 377     Manchester City                NaN                NaN
# 378   Tottenham Hotspur                NaN                NaN
# 379             Chelsea                NaN                NaN
# 380   Manchester United                NaN                NaN
# 381           Liverpool                NaN                NaN
# 382             Chelsea                NaN                NaN
# 383   Manchester United                NaN                NaN
#
#           fourth_place  fourth_place_point  teams  rounds
# 353   Blackburn Rovers                 NaN    NaN     NaN
# 354            Arsenal                 NaN    NaN     NaN
# 355          Liverpool                 NaN    NaN     NaN
# 356        Aston Villa                 NaN    NaN     NaN
# 357          Liverpool                 NaN    NaN     NaN
# 358            Chelsea                 NaN    NaN     NaN
# 359       Leeds United                 NaN    NaN     NaN
# 360          Liverpool                 NaN    NaN     NaN
# 361       Leeds United                 NaN    NaN     NaN
# 362   Newcastle United                 NaN    NaN     NaN
# 363            Chelsea                 NaN    NaN     NaN
# 364          Liverpool                 NaN    NaN     NaN
# 365            Everton                 NaN    NaN     NaN
# 366            Arsenal                 NaN    NaN     NaN
# 367            Arsenal                 NaN    NaN     NaN
# 368          Liverpool                 NaN    NaN     NaN
# 369            Arsenal                 NaN    NaN     NaN
# 370  Tottenham Hotspur                 NaN    NaN     NaN
# 371    Manchester City                 NaN    NaN     NaN
# 372            Chelsea                 NaN    NaN     NaN
# 373            Arsenal                 NaN    NaN     NaN
# 374            Arsenal                 NaN    NaN     NaN
# 375  Manchester United                 NaN    NaN     NaN
# 376    Manchester City                 NaN    NaN     NaN
# 377          Liverpool                 NaN    NaN     NaN
# 378          Liverpool                 NaN    NaN     NaN
# 379  Tottenham Hotspur                 NaN    NaN     NaN
# 380            Chelsea                 NaN    NaN     NaN
# 381            Chelsea                 NaN    NaN     NaN
# 382  Tottenham Hotspur                 NaN    NaN     NaN
# 383   Newcastle United                 NaN    NaN     NaN

# %%
champions = premier_league_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Manchester United    13
# Manchester City       7
# Chelsea               5
# Arsenal               3
# Blackburn Rovers      1
# Leicester City        1
# Liverpool             1
# Name: count, dtype: int64

# %%
runners_up = premier_league_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Manchester United    7
# Arsenal              7
# Liverpool            5
# Chelsea              4
# Manchester City      3
# Newcastle United     2
# Aston Villa          1
# Blackburn Rovers     1
# Tottenham Hotspur    1
# Name: count, dtype: int64

# %%
third_places = premier_league_data_frame['third_place'].value_counts()
third_places
# Out:
# third_place
# Liverpool             6
# Chelsea               6
# Arsenal               5
# Manchester United     5
# Newcastle United      2
# Tottenham Hotspur     2
# Norwich City          1
# Nottingham Forrest    1
# Leeds United          1
# Manchester City       1
# Name: count, dtype: int64

# %%
fourth_places = premier_league_data_frame['fourth_place'].value_counts()
fourth_places
# Out:
# fourth_place
# Liverpool            7
# Arsenal              6
# Chelsea              5
# Tottenham Hotspur    3
# Leeds United         2
# Newcastle United     2
# Manchester City      2
# Blackburn Rovers     1
# Aston Villa          1
# Everton              1
# Manchester United    1
# Name: count, dtype: int64
