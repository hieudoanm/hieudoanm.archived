# %%
import pandas

# %%
finals_data_frame = pandas.read_csv("./finals.csv")
finals_data_frame
# Out:
#                competition   season         champion champion_country score  \
# 0    UEFA Champions League  1955-56      Real Madrid            Spain   4-3
# 1    UEFA Champions League  1956-57      Real Madrid            Spain   2-0
# 2    UEFA Champions League  1957-58      Real Madrid            Spain   3-2
# 3    UEFA Champions League  1958-59      Real Madrid            Spain   2-0
# 4    UEFA Champions League  1959-60      Real Madrid            Spain   7-3
# ..                     ...      ...              ...              ...   ...
# 373                 FA Cup  2018-19  Manchester City              NaN   6-0
# 374                 FA Cup  2019-20          Arsenal              NaN   2-1
# 375                 FA Cup  2020-21   Leicester City              NaN   1-0
# 376                 FA Cup  2021-22        Liverpool              NaN   0-0
# 377                 FA Cup  2022-23  Manchester City              NaN   2-1
#
# ...

# %%
competitions = finals_data_frame["competition"].unique()
competitions
# Out:
# array(['UEFA Champions League', 'UEFA Europa League', 'EFL Cup', 'FA Cup'],
#       dtype=object)

# %% [markdown]
# ## UEFA Champions League

# %%
champions_league_data_frame = finals_data_frame[finals_data_frame["competition"] == "UEFA Champions League"]
champions_league_data_frame
# Out:
#               competition   season         champion champion_country score  \
# 0   UEFA Champions League  1955-56      Real Madrid            Spain   4-3
# 1   UEFA Champions League  1956-57      Real Madrid            Spain   2-0
# 2   UEFA Champions League  1957-58      Real Madrid            Spain   3-2
# 3   UEFA Champions League  1958-59      Real Madrid            Spain   2-0
# 4   UEFA Champions League  1959-60      Real Madrid            Spain   7-3
# ..                    ...      ...              ...              ...   ...
# 64  UEFA Champions League  2018-19        Liverpool          England   2-0
# 65  UEFA Champions League  2019-20    Bayern Munich          Germany   1-0
# 66  UEFA Champions League  2020-21          Chelsea          England   1-0
# 67  UEFA Champions League  2021-22      Real Madrid            Spain   1-0
# 68  UEFA Champions League  2022-23  Manchester City          England   1-0
#
# ...

# %%
hosts = champions_league_data_frame['host_country'].value_counts()
hosts
# Out:
# host_country
# Italy             9
# England           8
# Spain             8
# France            6
# Germany           5
# Netherlands       4
# Austria           4
# Belgium           4
# Portugal          4
# Scotland          3
# West Germany      3
# Greece            3
# Turkey            2
# Switzerland       1
# SFR Yugoslavia    1
# Russia            1
# Wales             1
# Ukraine           1
# Name: count, dtype: int64

# %%
champions = champions_league_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Real Madrid          14
# Milan                 7
# Bayern Munich         6
# Liverpool             6
# Barcelona             5
# Ajax                  4
# Inter Milan           3
# Manchester United     3
# Chelsea               2
# Nottingham Forest     2
# Benfica               2
# Juventus              2
# Porto                 2
# Red Star Belgrade     1
# Borussia Dortmund     1
# Marseille             1
# Aston Villa           1
# PSV Eindhoven         1
# Steaua București      1
# Hamburger SV          1
# Feyenoord             1
# Celtic                1
# Manchester City       1
# Name: count, dtype: int64

# %%
runners_up = champions_league_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Juventus                    7
# Bayern Munich               5
# Benfica                     5
# Liverpool                   4
# Milan                       4
# Barcelona                   3
# Real Madrid                 3
# Inter Milan                 3
# Atlético Madrid             3
# Valencia                    2
# Reims                       2
# Ajax                        2
# Manchester United           2
# Steaua București            1
# Borussia Dortmund           1
# Chelsea                     1
# Arsenal                     1
# Monaco                      1
# Bayer Leverkusen            1
# Tottenham Hotspur           1
# Sampdoria                   1
# Paris Saint-Germain         1
# Marseille                   1
# Malmö FF                    1
# Roma                        1
# Hamburger SV                1
# Fiorentina                  1
# Club Brugge                 1
# Borussia Mönchengladbach    1
# Saint-Étienne               1
# ...
