# %%
import pandas

# %%
champions_data_frame = pandas.read_csv("./champions.csv")
champions_data_frame
# Out:
#                   competition  year         host  champion  champion_score  \
# 0       FIFA Futsal World Cup  1989  Netherlands    Brazil             NaN
# 1       FIFA Futsal World Cup  1992    Hong Kong    Brazil             NaN
# 2       FIFA Futsal World Cup  1996        Spain    Brazil             NaN
# 3       FIFA Futsal World Cup  2000    Guatemala     Spain             NaN
# 4       FIFA Futsal World Cup  2004       Taiwan     Spain             NaN
# ..                        ...   ...          ...       ...             ...
# 75  ASEAN Futsal Championship  2016     Thailand  Thailand             8.0
# 76  ASEAN Futsal Championship  2017      Vietnam  Thailand             4.0
# 77  ASEAN Futsal Championship  2018    Indonesia  Thailand             4.0
# 78  ASEAN Futsal Championship  2019      Vietnam  Thailand             5.0
# 79  ASEAN Futsal Championship  2022     Thailand  Thailand             2.0
#
#         runner_up  runner_up_score    third_place fourth_place
# 0     Netherlands              NaN  United States      Belgium
# 1   United States              NaN          Spain         Iran
# 2           Spain              NaN         Russia      Ukraine
# 3          Brazil              NaN       Portugal       Russia
# 4           Italy              NaN         Brazil    Argentina
# ..            ...              ...            ...          ...
# 75        Myanmar              1.0            NaN          NaN
# 76       Malaysia              3.0            NaN          NaN
# 77       Malaysia              2.0            NaN          NaN
# 78      Indonesia              0.0            NaN          NaN
# 79      Indonesia              2.0            NaN          NaN
#
# [80 rows x 9 columns]

# %%
competitions = champions_data_frame["competition"].unique()
competitions
# Out:
# array(['FIFA Futsal World Cup', 'Copa América de Futsal',
#        'CONCACAF Futsal Championship', 'UEFA Futsal Championship',
#        'AFC Futsal Asian Cup', 'Futsal Africa Cup of Nations',
#        'ASEAN Futsal Championship'], dtype=object)

# %% [markdown]
# ## FIFA Futsal World Cup

# %%
world_cup_data_frame = champions_data_frame[champions_data_frame["competition"] == "FIFA Futsal World Cup"]
world_cup_data_frame
# Out:
#              competition  year         host   champion  champion_score  \
# 0  FIFA Futsal World Cup  1989  Netherlands     Brazil             NaN
# 1  FIFA Futsal World Cup  1992    Hong Kong     Brazil             NaN
# 2  FIFA Futsal World Cup  1996        Spain     Brazil             NaN
# 3  FIFA Futsal World Cup  2000    Guatemala      Spain             NaN
# 4  FIFA Futsal World Cup  2004       Taiwan      Spain             NaN
# 5  FIFA Futsal World Cup  2008       Brazil     Brazil             NaN
# 6  FIFA Futsal World Cup  2012     Thailand     Brazil             NaN
# 7  FIFA Futsal World Cup  2016     Colombia  Argentina             NaN
# 8  FIFA Futsal World Cup  2021    Lithuania   Portugal             NaN
#
#        runner_up  runner_up_score    third_place fourth_place
# 0    Netherlands              NaN  United States      Belgium
# 1  United States              NaN          Spain         Iran
# 2          Spain              NaN         Russia      Ukraine
# 3         Brazil              NaN       Portugal       Russia
# 4          Italy              NaN         Brazil    Argentina
# 5          Spain              NaN          Italy       Russia
# 6          Spain              NaN          Italy     Colombia
# 7         Russia              NaN           Iran     Portugal
# 8      Argentina              NaN         Brazil   Kazakhstan

# %%
hosts = world_cup_data_frame['host'].value_counts()
hosts
# Out:
# host
# Netherlands    1
# Hong Kong      1
# Spain          1
# Guatemala      1
# Taiwan         1
# Brazil         1
# Thailand       1
# Colombia       1
# Lithuania      1
# Name: count, dtype: int64

# %%
champions = world_cup_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Brazil       5
# Spain        2
# Argentina    1
# Portugal     1
# Name: count, dtype: int64

# %%
runners_up = world_cup_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Spain            3
# Netherlands      1
# United States    1
# Brazil           1
# Italy            1
# Russia           1
# Argentina        1
# Name: count, dtype: int64

# %%
third_places = world_cup_data_frame['third_place'].value_counts()
third_places
# Out:
# third_place
# Brazil           2
# Italy            2
# United States    1
# Spain            1
# Russia           1
# Portugal         1
# Iran             1
# Name: count, dtype: int64

# %%
fourth_places = world_cup_data_frame['fourth_place'].value_counts()
fourth_places
# Out:
# fourth_place
# Russia        2
# Belgium       1
# Iran          1
# Ukraine       1
# Argentina     1
# Colombia      1
# Portugal      1
# Kazakhstan    1
# Name: count, dtype: int64

# %% [markdown]
# ## AFC Futsal Asian Cup

# %%
afc_data_frame = champions_data_frame[champions_data_frame["competition"] == "AFC Futsal Asian Cup"]
afc_data_frame
# Out:
#              competition  year                  host champion  champion_score  \
# 41  AFC Futsal Asian Cup  1999              Malaysia     Iran             NaN
# 42  AFC Futsal Asian Cup  2000              Thailand     Iran             NaN
# 43  AFC Futsal Asian Cup  2001                  Iran     Iran             NaN
# 44  AFC Futsal Asian Cup  2002             Indonesia     Iran             NaN
# 45  AFC Futsal Asian Cup  2003                  Iran     Iran             NaN
# 46  AFC Futsal Asian Cup  2004                 Macau     Iran             NaN
# 47  AFC Futsal Asian Cup  2005               Vietnam     Iran             NaN
# 48  AFC Futsal Asian Cup  2006            Uzbekistan    Japan             NaN
# 49  AFC Futsal Asian Cup  2007                 Japan     Iran             NaN
# 50  AFC Futsal Asian Cup  2008              Thailand     Iran             NaN
# 51  AFC Futsal Asian Cup  2010            Uzbekistan     Iran             NaN
# 52  AFC Futsal Asian Cup  2012  United Arab Emirates    Japan             NaN
# 53  AFC Futsal Asian Cup  2014               Vietnam    Japan             NaN
# 54  AFC Futsal Asian Cup  2016            Uzbekistan     Iran             NaN
# 55  AFC Futsal Asian Cup  2018                Taiwan     Iran             NaN
# 56  AFC Futsal Asian Cup  2022                Kuwait    Japan             NaN
#
#       runner_up  runner_up_score  third_place fourth_place
# 41  South Korea              NaN   Kazakhstan        Japan
# 42   Kazakhstan              NaN     Thailand        Japan
# 43   Uzbekistan              NaN  South Korea        Japan
# 44        Japan              NaN     Thailand  South Korea
# 45        Japan              NaN     Thailand       Kuwait
# 46        Japan              NaN     Thailand   Uzbekistan
# 47        Japan              NaN   Uzbekistan   Kyrgyzstan
# 48   Uzbekistan              NaN         Iran   Kyrgyzstan
# 49        Japan              NaN   Uzbekistan   Kyrgyzstan
# 50     Thailand              NaN        Japan        China
# 51   Uzbekistan              NaN        Japan        China
# 52     Thailand              NaN         Iran    Australia
# 53         Iran              NaN   Uzbekistan       Kuwait
# 54   Uzbekistan              NaN     Thailand      Vietnam
# 55        Japan              NaN   Uzbekistan         Iraq
# 56         Iran              NaN   Uzbekistan     Thailand

# %%
champions = afc_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Iran     12
# Japan     4
# Name: count, dtype: int64

# %%
runners_up = afc_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Japan          6
# Uzbekistan     4
# Thailand       2
# Iran           2
# South Korea    1
# Kazakhstan     1
# Name: count, dtype: int64

# %% [markdown]
# ## ASEAN Futsal Championship

# %%
asean_data_frame = champions_data_frame[champions_data_frame["competition"] == "ASEAN Futsal Championship"]
asean_data_frame
# Out:
#                   competition  year       host   champion  champion_score  \
# 63  ASEAN Futsal Championship  2001   Malaysia   Thailand            12.0
# 64  ASEAN Futsal Championship  2003   Malaysia   Thailand             4.0
# 65  ASEAN Futsal Championship  2005   Thailand   Thailand             5.0
# 66  ASEAN Futsal Championship  2006   Thailand   Thailand            10.0
# 67  ASEAN Futsal Championship  2007   Thailand   Thailand             7.0
# 68  ASEAN Futsal Championship  2008   Thailand   Thailand             5.0
# 69  ASEAN Futsal Championship  2009    Vietnam   Thailand             4.0
# 70  ASEAN Futsal Championship  2010    Vietnam  Indonesia             5.0
# 71  ASEAN Futsal Championship  2012   Thailand   Thailand             9.0
# 72  ASEAN Futsal Championship  2013   Thailand   Thailand             2.0
# 73  ASEAN Futsal Championship  2014   Malaysia   Thailand             6.0
# 74  ASEAN Futsal Championship  2015   Thailand   Thailand             5.0
# 75  ASEAN Futsal Championship  2016   Thailand   Thailand             8.0
# 76  ASEAN Futsal Championship  2017    Vietnam   Thailand             4.0
# 77  ASEAN Futsal Championship  2018  Indonesia   Thailand             4.0
# 78  ASEAN Futsal Championship  2019    Vietnam   Thailand             5.0
# 79  ASEAN Futsal Championship  2022   Thailand   Thailand             2.0
#
#     runner_up  runner_up_score third_place fourth_place
# 63  Singapore              1.0         NaN          NaN
# 64   Malaysia              0.0         NaN          NaN
# 65   Malaysia              1.0         NaN          NaN
# 66  Indonesia              3.0         NaN          NaN
# 67  Australia              1.0         NaN          NaN
# 68  Indonesia              1.0         NaN          NaN
# 69    Vietnam              1.0         NaN          NaN
# 70   Malaysia              0.0         NaN          NaN
# 71    Vietnam              4.0         NaN          NaN
# 72  Australia              1.0         NaN          NaN
# 73  Australia              0.0         NaN          NaN
# 74  Australia              3.0         NaN          NaN
# 75    Myanmar              1.0         NaN          NaN
# 76   Malaysia              3.0         NaN          NaN
# 77   Malaysia              2.0         NaN          NaN
# 78  Indonesia              0.0         NaN          NaN
# 79  Indonesia              2.0         NaN          NaN

# %%
champions = asean_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Thailand     16
# Indonesia     1
# Name: count, dtype: int64

# %%
runners_up = asean_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Malaysia     5
# Indonesia    4
# Australia    4
# Vietnam      2
# Singapore    1
# Myanmar      1
# Name: count, dtype: int64
