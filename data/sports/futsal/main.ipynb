# %%
import pandas

# %%
champions_data_frame = pandas.read_csv("./champions.csv")
champions_data_frame = champions_data_frame.sort_values(by=['sport', 'gender', 'competition', 'year'])
champions_data_frame
# Out:
#                  sport gender               competition competition_area  \
# 199  american-football   male                       NFL    United States
# 200  american-football   male                       NFL    United States
# 201  american-football   male                       NFL    United States
# 202  american-football   male                       NFL    United States
# 203  american-football   male                       NFL    United States
# ..                 ...    ...                       ...              ...
# 36              futsal   male  UEFA Futsal Championship           Europe
# 37              futsal   male  UEFA Futsal Championship           Europe
# 38              futsal   male  UEFA Futsal Championship           Europe
# 39              futsal   male  UEFA Futsal Championship           Europe
# 40              futsal   male  UEFA Futsal Championship           Europe
#
#        year   host_country            champion  champion_score  \
# ...

# %%
competitions = champions_data_frame["competition"].unique()
competitions
# Out:
# array(['NFL', 'NBA', "FIFA Women's World Cup", 'AFC Asian Cup', 'AFF Cup',
#        'Copa América', 'FIFA Confederations Cup', 'FIFA World Cup',
#        'UEFA European Championship', 'AFL', 'AFC Futsal Asian Cup',
#        'ASEAN Futsal Championship', 'CONCACAF Futsal Championship',
#        'Copa América de Futsal', 'FIFA Futsal World Cup',
#        'Futsal Africa Cup of Nations', 'UEFA Futsal Championship'],
#       dtype=object)

# %% [markdown]
# ## FIFA Futsal World Cup

# %%
world_cup_data_frame = champions_data_frame[champions_data_frame["competition"] == "FIFA Futsal World Cup"]
world_cup_data_frame
# Out:
#     sport gender            competition competition_area    year host_country  \
# 0  futsal   male  FIFA Futsal World Cup            World  1989.0  Netherlands
# 1  futsal   male  FIFA Futsal World Cup            World  1992.0    Hong Kong
# 2  futsal   male  FIFA Futsal World Cup            World  1996.0        Spain
# 3  futsal   male  FIFA Futsal World Cup            World  2000.0    Guatemala
# 4  futsal   male  FIFA Futsal World Cup            World  2004.0       Taiwan
# 5  futsal   male  FIFA Futsal World Cup            World  2008.0       Brazil
# 6  futsal   male  FIFA Futsal World Cup            World  2012.0     Thailand
# 7  futsal   male  FIFA Futsal World Cup            World  2016.0     Colombia
# 8  futsal   male  FIFA Futsal World Cup            World  2021.0    Lithuania
#
#     champion  champion_score champion_manager champion_manager_country  \
# 0     Brazil             NaN              NaN                      NaN
# ...

# %%
hosts = world_cup_data_frame['host'].value_counts()
hosts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'host'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
champions = world_cup_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Brazil       5
# Spain        2
# Argentina    1
# Portugal     1
# Name: count, dtype: int64

# %%
runners_up = world_cup_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Spain            3
# Netherlands      1
# United States    1
# Brazil           1
# Italy            1
# Russia           1
# Argentina        1
# Name: count, dtype: int64

# %%
third_places = world_cup_data_frame['third_place'].value_counts()
third_places
# Out:
# third_place
# Brazil           2
# Italy            2
# United States    1
# Spain            1
# Russia           1
# Portugal         1
# Iran             1
# Name: count, dtype: int64

# %%
fourth_places = world_cup_data_frame['fourth_place'].value_counts()
fourth_places
# Out:
# fourth_place
# Russia        2
# Belgium       1
# Iran          1
# Ukraine       1
# Argentina     1
# Colombia      1
# Portugal      1
# Kazakhstan    1
# Name: count, dtype: int64

# %% [markdown]
# ## AFC Futsal Asian Cup

# %%
afc_data_frame = champions_data_frame[champions_data_frame["competition"] == "AFC Futsal Asian Cup"]
afc_data_frame
# Out:
#      sport gender           competition    year                  host  \
# 41  futsal   male  AFC Futsal Asian Cup  1999.0              Malaysia
# 42  futsal   male  AFC Futsal Asian Cup  2000.0              Thailand
# 43  futsal   male  AFC Futsal Asian Cup  2001.0                  Iran
# 44  futsal   male  AFC Futsal Asian Cup  2002.0             Indonesia
# 45  futsal   male  AFC Futsal Asian Cup  2003.0                  Iran
# 46  futsal   male  AFC Futsal Asian Cup  2004.0                 Macau
# 47  futsal   male  AFC Futsal Asian Cup  2005.0               Vietnam
# 48  futsal   male  AFC Futsal Asian Cup  2006.0            Uzbekistan
# 49  futsal   male  AFC Futsal Asian Cup  2007.0                 Japan
# 50  futsal   male  AFC Futsal Asian Cup  2008.0              Thailand
# 51  futsal   male  AFC Futsal Asian Cup  2010.0            Uzbekistan
# 52  futsal   male  AFC Futsal Asian Cup  2012.0  United Arab Emirates
# ...

# %%
champions = afc_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Iran     12
# Japan     4
# Name: count, dtype: int64

# %%
runners_up = afc_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Japan          6
# Uzbekistan     4
# Thailand       2
# Iran           2
# South Korea    1
# Kazakhstan     1
# Name: count, dtype: int64

# %% [markdown]
# ## ASEAN Futsal Championship

# %%
asean_data_frame = champions_data_frame[champions_data_frame["competition"] == "ASEAN Futsal Championship"]
asean_data_frame
# Out:
#      sport gender                competition    year       host   champion  \
# 63  futsal   male  ASEAN Futsal Championship  2001.0   Malaysia   Thailand
# 64  futsal   male  ASEAN Futsal Championship  2003.0   Malaysia   Thailand
# 65  futsal   male  ASEAN Futsal Championship  2005.0   Thailand   Thailand
# 66  futsal   male  ASEAN Futsal Championship  2006.0   Thailand   Thailand
# 67  futsal   male  ASEAN Futsal Championship  2007.0   Thailand   Thailand
# 68  futsal   male  ASEAN Futsal Championship  2008.0   Thailand   Thailand
# 69  futsal   male  ASEAN Futsal Championship  2009.0    Vietnam   Thailand
# 70  futsal   male  ASEAN Futsal Championship  2010.0    Vietnam  Indonesia
# 71  futsal   male  ASEAN Futsal Championship  2012.0   Thailand   Thailand
# 72  futsal   male  ASEAN Futsal Championship  2013.0   Thailand   Thailand
# 73  futsal   male  ASEAN Futsal Championship  2014.0   Malaysia   Thailand
# ...

# %%
champions = asean_data_frame['champion'].value_counts()
champions
# Out:
# champion
# Thailand     16
# Indonesia     1
# Name: count, dtype: int64

# %%
runners_up = asean_data_frame['runner_up'].value_counts()
runners_up
# Out:
# runner_up
# Malaysia     5
# Indonesia    4
# Australia    4
# Vietnam      2
# Singapore    1
# Myanmar      1
# Name: count, dtype: int64
