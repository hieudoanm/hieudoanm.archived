# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    if num_lines < 100:
        print(path, num_lines)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
files_data_frame.reset_index()
# Out:
# 99
# ./world/regions/asia/vietnam/beauty-pageants/miss-vietnam.csv 54
# ./world/regions/asia/vietnam/other/ethnic-minorities.csv 55
# ./world/regions/asia/vietnam/sports/football/stadiums.csv 38
# ./sports/players/players.csv 45
# ./languages/words/characters.csv 38
# ./finance/banks/data.csv 61
# ./games/pokemon/data/type-chart.csv 19
#     index                                          file_path  num_lines
# 0      96                ./games/pokemon/data/type-chart.csv         19
# 1      30  ./world/regions/asia/vietnam/sports/football/s...         38
# 2      72                   ./languages/words/characters.csv         38
# 3      67                       ./sports/players/players.csv         45
# 4      26  ./world/regions/asia/vietnam/beauty-pageants/m...         54
# 5      27  ./world/regions/asia/vietnam/other/ethnic-mino...         55
# 6      93                           ./finance/banks/data.csv         61
# 7      81                        ./languages/tarot/cards.csv        100
# 8      59                           ./sports/clubs/clubs.csv        102
# 9      35  ./world/regions/americas/usa/government/legisl...        119
# 10     39  ./world/regions/americas/usa/government/execut...        122
# 11     80                       ./languages/news/sources.csv        129
# 12     24  ./world/regions/asia/vietnam/maps/license-plat...        150
# 13     85                ./finance/currencies/currencies.csv        162
# 14     88                 ./finance/forex/csv/currencies.csv        163
# 15     60                 ./sports/football/competitions.csv        166
# 16     79                ./languages/languages/languages.csv        172
# 17     62            ./sports/football/full/competitions.csv        175
# 18     91    ./finance/stock/vnindex/vps/data/industries.csv        178
# 19     32                ./world/regions/europe/football.csv        179
# 20     54                 ./world/independence-days/data.csv        184
# 21     55                  ./world/independence-days/raw.csv        184
# 22     66                ./sports/football/fifa/rankings.csv        208
# 23     38  ./world/regions/americas/usa/government/legisl...        217
# 24     53                          ./world/states/states.csv        242
# 25     58                          ./world/countries/all.csv        251
# 26     57                ./world/countries/restcountries.csv        251
# 27     56                    ./world/countries/countries.csv        256
# 28     31  ./world/regions/asia/vietnam/sports/football/s...        295
# 29     44  ./world/regions/americas/usa/states/governors.csv        296
# 30     65  ./sports/football/clubs/league/teams-of-the-se...        331
# 31     16            ./world/organizations/organizations.csv        337
# 32     51                          ./world/cities/cities.csv        340
# 33     47                    ./world/timezones/timezones.csv        351
# 34     29  ./world/regions/asia/vietnam/sports/football/p...        403
# 35     49                   ./world/timezones/timezones3.csv        419
# 36     48                   ./world/timezones/timezones2.csv        419
# 37     68                        ./sports/futsal/players.csv        422
# 38     69                      ./sports/futsal/champions.csv        459
# 39     63             ./sports/football/clubs/cup/finals.csv        460
# 40     84                         ./finance/crypto/coins.csv        501
# 41     78                     ./languages/languages/full.csv        548
# 42     64  ./sports/football/clubs/league/standings/datas...        621
# 43     71                     ./sports/esports/champions.csv        699
# 44     23    ./world/regions/asia/vietnam/maps/districts.csv        726
# 45     82             ./languages/1000-most-common/words.csv       1000
# 46     15  ./education/universities/rankings/csv/shanghai...       1001
# 47     33         ./world/regions/europe/nobel/laureates.csv       1048
# 48     34  ./world/regions/europe/nobel/transformed/laure...       1048
# 49     98                   ./games/pokemon/data/pokemon.csv       1272
# 50     97                   ./games/pokemon/data/combats.csv       1272
# 51      9  ./oracle-of-bacon/data/links/900000-1000000-cu...       1317
# 52     40  ./world/regions/americas/usa/government/execut...       1378
# 53     14       ./education/universities/rankings/csv/qs.csv       1499
# 54     21  ./world/regions/asia/korea/music/transformed/i...       1779
# 55     20         ./world/regions/asia/korea/music/idols.csv       1779
# 56      0              ./technology/github/emojis/emojis.csv       1878
# 57     92  ./finance/stock/vnindex/dragon-capital/history...       1901
# 58     18  ./world/regions/oceania/australia/stock/statis...       2071
# 59     19  ./world/regions/oceania/australia/stock/compan...       2071
# 60     73                      ./languages/quotes/quotes.csv       2278
# 61     90     ./finance/stock/vnindex/vps/data/companies.csv       2309
# 62     13    ./education/universities/rankings/csv/times.csv       2346
# 63     28  ./world/regions/asia/vietnam/sports/football/m...       2781
# 64     77  ./languages/text-classification/output/submiss...       3264
# 65     76  ./languages/text-classification/input/sample_s...       3264
# 66     45  ./world/regions/americas/usa/stock/market/nyse...       3299
# 67     46  ./world/regions/americas/usa/stock/market/nasd...       3371
# 68     70   ./sports/chess/lichess.org/openings/openings.csv       3415
# 69     74     ./languages/text-classification/input/test.csv       3700
# 70     61                        ./sports/football/teams.csv       5001
# 71     41  ./world/regions/americas/usa/stock-watch/clean...       6341
# 72     25  ./world/regions/asia/vietnam/national-assembly...       6516
# 73     43  ./world/regions/americas/usa/stock-watch/raw/s...       8306
# 74     75    ./languages/text-classification/input/train.csv       8562
# 75     87                      ./finance/forex/csv/dates.csv       8884
# 76     86                    ./finance/forex/csv/history.csv       8884
# 77     94  ./machine-learning/supervised/house-price-pred...       9359
# 78     12           ./education/universities/universites.csv       9950
# 79     22        ./world/regions/asia/vietnam/maps/wards.csv      11563
# 80     36  ./world/regions/americas/usa/government/legisl...      13498
# 81     37  ./world/regions/americas/usa/government/legisl...      13501
# 82     95  ./machine-learning/supervised/employee-retenti...      15000
# 83     17  ./world/regions/oceania/australia/postal-code.csv      16884
# 84     42  ./world/regions/americas/usa/stock-watch/raw/h...      16914
# 85     50                            ./world/visas/visas.csv      27670
# 86      7     ./oracle-of-bacon/data/links/600000-700000.csv     100001
# 87      4     ./oracle-of-bacon/data/links/500000-600000.csv     100001
# 88      8     ./oracle-of-bacon/data/links/400000-500000.csv     100001
# 89      3     ./oracle-of-bacon/data/links/700000-800000.csv     100001
# 90      2    ./oracle-of-bacon/data/links/900000-1000000.csv     100001
# 91     10     ./oracle-of-bacon/data/links/300000-400000.csv     100001
# 92     11     ./oracle-of-bacon/data/links/200000-300000.csv     100001
# 93      1     ./oracle-of-bacon/data/links/800000-900000.csv     100001
# 94      5          ./oracle-of-bacon/data/links/0-100000.csv     100001
# 95      6     ./oracle-of-bacon/data/links/100000-200000.csv     100001
# 96     83         ./languages/1000-most-common/languages.csv     103887
# 97     52                             ./world/cities/all.csv     209580
# 98     89       ./finance/stock/vnindex/vps/data/history.csv    4021643
