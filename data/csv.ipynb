# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    if num_lines < 100:
        print(path, num_lines)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
files_data_frame.reset_index()
# Out:
# 88
# ./world/regions/vietnam/other/ethnic-minorities.csv 55
# ./languages/words/characters.csv 38
# ./games/pokemon/data/type-chart.csv 19
#     index                                          file_path  num_lines
# 0      85                ./games/pokemon/data/type-chart.csv         19
# 1      66                   ./languages/words/characters.csv         38
# 2      40  ./world/regions/vietnam/other/ethnic-minoritie...         55
# 3      73                        ./languages/tarot/cards.csv        100
# 4      22  ./world/regions/usa/government/legislative/con...        119
# 5      63                     ./sports/stadiums/stadiums.csv        140
# 6      38    ./world/regions/vietnam/maps/license-plates.csv        150
# 7      57                 ./sports/football/competitions.csv        166
# 8      59            ./sports/football/full/competitions.csv        175
# 9      81    ./finance/stock/vnindex/vps/data/industries.csv        178
# 10     21    ./world/regions/usa/government/institutions.csv        182
# 11     51                 ./world/independence-days/data.csv        184
# 12     52                  ./world/independence-days/raw.csv        184
# 13     61                ./sports/football/fifa/rankings.csv        208
# 14     25  ./world/regions/usa/government/legislative/con...        217
# 15     50                          ./world/states/states.csv        242
# 16     55                          ./world/countries/all.csv        251
# 17     54                ./world/countries/restcountries.csv        251
# 18     53                    ./world/countries/countries.csv        256
# 19     56                           ./sports/clubs/clubs.csv        280
# 20     43  ./world/regions/vietnam/sports/football/standi...        295
# 21     30           ./world/regions/usa/states/governors.csv        296
# 22     20            ./world/organizations/organizations.csv        337
# 23     48                          ./world/cities/cities.csv        340
# 24     44                    ./world/timezones/timezones.csv        351
# 25     42  ./world/regions/vietnam/sports/football/player...        403
# 26     46                   ./world/timezones/timezones3.csv        419
# 27     45                   ./world/timezones/timezones2.csv        419
# 28     76                         ./finance/crypto/coins.csv        501
# 29     72                ./languages/languages/languages.csv        548
# 30     60  ./sports/football/clubs/league/standings/datas...        621
# 31     37         ./world/regions/vietnam/maps/districts.csv        726
# 32     62                       ./sports/players/players.csv        849
# 33     74             ./languages/1000-most-common/words.csv       1000
# 34     19  ./education/universities/rankings/csv/shanghai...       1001
# 35      2                              ./nobel/laureates.csv       1048
# 36      3                  ./nobel/transformed/laureates.csv       1048
# 37     86                   ./games/pokemon/data/combats.csv       1272
# 38     87                   ./games/pokemon/data/pokemon.csv       1272
# 39     13  ./oracle-of-bacon/data/links/900000-1000000-cu...       1317
# 40     26  ./world/regions/usa/government/executive/indiv...       1378
# 41     18       ./education/universities/rankings/csv/qs.csv       1499
# 42     65                   ./sports/champions/champions.csv       1616
# 43      0                                  ./music/idols.csv       1779
# 44      1                      ./music/transformed/idols.csv       1779
# 45      4              ./technology/github/emojis/emojis.csv       1878
# 46     82  ./finance/stock/vnindex/dragon-capital/history...       1901
# 47     35      ./world/regions/australia/stock/companies.csv       2071
# 48     34     ./world/regions/australia/stock/statistics.csv       2071
# 49     67                      ./languages/quotes/quotes.csv       2278
# 50     80     ./finance/stock/vnindex/vps/data/companies.csv       2309
# 51     17    ./education/universities/rankings/csv/times.csv       2346
# 52     41  ./world/regions/vietnam/sports/football/matche...       2781
# 53     70  ./languages/text-classification/input/sample_s...       3264
# 54     71  ./languages/text-classification/output/submiss...       3264
# 55     31          ./world/regions/usa/stock/market/nyse.csv       3299
# 56     32        ./world/regions/usa/stock/market/nasdaq.csv       3371
# 57     64   ./sports/chess/lichess.org/openings/openings.csv       3415
# 58     68     ./languages/text-classification/input/test.csv       3700
# 59     58                        ./sports/football/teams.csv       5001
# 60     27   ./world/regions/usa/stock-watch/clean/senate.csv       6341
# 61     39  ./world/regions/vietnam/national-assembly/memb...       6516
# 62     29     ./world/regions/usa/stock-watch/raw/senate.csv       8306
# 63     69    ./languages/text-classification/input/train.csv       8562
# 64     78                      ./finance/forex/csv/dates.csv       8884
# 65     77                    ./finance/forex/csv/history.csv       8884
# 66     83  ./machine-learning/supervised/house-price-pred...       9359
# 67     16           ./education/universities/universites.csv       9950
# 68     36             ./world/regions/vietnam/maps/wards.csv      11563
# 69     23  ./world/regions/usa/government/legislative/mem...      13498
# 70     24  ./world/regions/usa/government/legislative/con...      13501
# 71     84  ./machine-learning/supervised/employee-retenti...      15000
# 72     33          ./world/regions/australia/postal-code.csv      16884
# 73     28      ./world/regions/usa/stock-watch/raw/house.csv      16914
# 74     47                            ./world/visas/visas.csv      27670
# 75     11     ./oracle-of-bacon/data/links/600000-700000.csv     100001
# 76      6    ./oracle-of-bacon/data/links/900000-1000000.csv     100001
# 77     12     ./oracle-of-bacon/data/links/400000-500000.csv     100001
# 78      7     ./oracle-of-bacon/data/links/700000-800000.csv     100001
# 79      8     ./oracle-of-bacon/data/links/500000-600000.csv     100001
# 80      9          ./oracle-of-bacon/data/links/0-100000.csv     100001
# 81     15     ./oracle-of-bacon/data/links/200000-300000.csv     100001
# 82     14     ./oracle-of-bacon/data/links/300000-400000.csv     100001
# 83      5     ./oracle-of-bacon/data/links/800000-900000.csv     100001
# 84     10     ./oracle-of-bacon/data/links/100000-200000.csv     100001
# 85     75         ./languages/1000-most-common/languages.csv     103887
# 86     49                             ./world/cities/all.csv     209580
# 87     79       ./finance/stock/vnindex/vps/data/history.csv    4021643
