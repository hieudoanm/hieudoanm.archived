# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    if num_lines < 100:
        print(path, num_lines)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
files_data_frame.reset_index()
# Out:
# 80
# ./world/regions/vietnam/other/ethnic-minorities.csv 55
# ./languages/words/characters.csv 38
# ./games/pokemon/data/type-chart.csv 19
#     index                                          file_path  num_lines
# 0      77                ./games/pokemon/data/type-chart.csv         19
# 1      60                   ./languages/words/characters.csv         38
# 2      39  ./world/regions/vietnam/other/ethnic-minoritie...         55
# 3      22  ./world/regions/usa/government/legislative/con...        119
# 4      57                     ./sports/stadiums/stadiums.csv        140
# 5      51                 ./sports/football/competitions.csv        166
# 6      53            ./sports/football/full/competitions.csv        175
# 7      73    ./finance/stock/vnindex/vps/data/industries.csv        178
# 8      21    ./world/regions/usa/government/institutions.csv        182
# 9      48                 ./world/independence-days/data.csv        184
# 10     49                  ./world/independence-days/raw.csv        184
# 11     55                ./sports/football/fifa/rankings.csv        208
# 12     25  ./world/regions/usa/government/legislative/con...        217
# 13     47                          ./world/states/states.csv        242
# 14     50                           ./sports/clubs/clubs.csv        280
# 15     42  ./world/regions/vietnam/sports/football/standi...        295
# 16     30           ./world/regions/usa/states/governors.csv        296
# 17     20            ./world/organizations/organizations.csv        337
# 18     45                          ./world/cities/cities.csv        340
# 19     41  ./world/regions/vietnam/sports/football/player...        403
# 20     66                ./languages/languages/languages.csv        548
# 21     54  ./sports/football/clubs/league/standings/datas...        621
# 22     37         ./world/regions/vietnam/maps/districts.csv        726
# 23     56                       ./sports/players/players.csv        849
# 24     67             ./languages/1000-most-common/words.csv       1000
# 25     19  ./education/universities/rankings/csv/shanghai...       1001
# 26      3                  ./nobel/transformed/laureates.csv       1048
# 27      2                              ./nobel/laureates.csv       1048
# 28     78                   ./games/pokemon/data/combats.csv       1272
# 29     79                   ./games/pokemon/data/pokemon.csv       1272
# 30     13  ./oracle-of-bacon/data/links/900000-1000000-cu...       1317
# 31     26  ./world/regions/usa/government/executive/indiv...       1378
# 32     18       ./education/universities/rankings/csv/qs.csv       1499
# 33     59                   ./sports/champions/champions.csv       1616
# 34      1                      ./music/transformed/idols.csv       1779
# 35      0                                  ./music/idols.csv       1779
# 36      4              ./technology/github/emojis/emojis.csv       1878
# 37     74  ./finance/stock/vnindex/dragon-capital/history...       1901
# 38     34     ./world/regions/australia/stock/statistics.csv       2071
# 39     35      ./world/regions/australia/stock/companies.csv       2071
# 40     61                      ./languages/quotes/quotes.csv       2278
# 41     72     ./finance/stock/vnindex/vps/data/companies.csv       2309
# 42     17    ./education/universities/rankings/csv/times.csv       2346
# 43     40  ./world/regions/vietnam/sports/football/matche...       2781
# 44     64  ./languages/text-classification/input/sample_s...       3264
# 45     65  ./languages/text-classification/output/submiss...       3264
# 46     31          ./world/regions/usa/stock/market/nyse.csv       3299
# 47     32        ./world/regions/usa/stock/market/nasdaq.csv       3371
# 48     58   ./sports/chess/lichess.org/openings/openings.csv       3415
# 49     62     ./languages/text-classification/input/test.csv       3700
# 50     52                        ./sports/football/teams.csv       5001
# 51     27   ./world/regions/usa/stock-watch/clean/senate.csv       6341
# 52     38  ./world/regions/vietnam/national-assembly/memb...       6516
# 53     29     ./world/regions/usa/stock-watch/raw/senate.csv       8306
# 54     63    ./languages/text-classification/input/train.csv       8562
# 55     70                      ./finance/forex/csv/dates.csv       8884
# 56     69                    ./finance/forex/csv/history.csv       8884
# 57     75  ./machine-learning/supervised/house-price-pred...       9359
# 58     16           ./education/universities/universites.csv       9950
# 59     36             ./world/regions/vietnam/maps/wards.csv      11563
# 60     23  ./world/regions/usa/government/legislative/mem...      13498
# 61     24  ./world/regions/usa/government/legislative/con...      13501
# 62     76  ./machine-learning/supervised/employee-retenti...      15000
# 63     33          ./world/regions/australia/postal-code.csv      16884
# 64     28      ./world/regions/usa/stock-watch/raw/house.csv      16914
# 65     44                            ./world/visas/visas.csv      27670
# 66      8     ./oracle-of-bacon/data/links/500000-600000.csv     100001
# 67      6    ./oracle-of-bacon/data/links/900000-1000000.csv     100001
# 68      5     ./oracle-of-bacon/data/links/800000-900000.csv     100001
# 69      9          ./oracle-of-bacon/data/links/0-100000.csv     100001
# 70     10     ./oracle-of-bacon/data/links/100000-200000.csv     100001
# 71     12     ./oracle-of-bacon/data/links/400000-500000.csv     100001
# 72     14     ./oracle-of-bacon/data/links/300000-400000.csv     100001
# 73     15     ./oracle-of-bacon/data/links/200000-300000.csv     100001
# 74      7     ./oracle-of-bacon/data/links/700000-800000.csv     100001
# 75     11     ./oracle-of-bacon/data/links/600000-700000.csv     100001
# 76     68         ./languages/1000-most-common/languages.csv     103887
# 77     43                   ./world/timezones/time_zones.csv     145827
# 78     46                             ./world/cities/all.csv     209580
# 79     71       ./finance/stock/vnindex/vps/data/history.csv    4021643
