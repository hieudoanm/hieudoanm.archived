# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

# %%
def get_csv_paths(directory : str, extension : str):
    csv_paths = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(extension):
                csv_paths.append(os.path.join(root, file))
    return csv_paths

# %%
def get_num_lines(directory : str):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# %%
def get_files(extension : str):
    # Replace 'your_directory_path' with the path of the directory you want to search
    directory_path = '.'
    csv_paths = get_csv_paths(directory_path, extension)
    print(len(csv_paths))
    files = []
    for path in csv_paths:
        num_lines = get_num_lines(path)
        if num_lines < 100:
            print(path, num_lines)
        files.append({
            "file_path": path,
            "num_lines": num_lines
        })
    files_data_frame = pd.DataFrame(files)
    files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
    files_data_frame.reset_index()
    return files_data_frame

# %%
csv_data_frame = get_files('.csv')
csv_data_frame
# Out:
# 77
# ./games/pokemon/data/type-chart.csv 19
#                                             file_path  num_lines
# 74                ./games/pokemon/data/type-chart.csv         19
# 21  ./world/regions/usa/government/legislative/con...        119
# 55                     ./sports/stadiums/stadiums.csv        140
# 49                 ./sports/football/competitions.csv        166
# 51            ./sports/football/full/competitions.csv        175
# 70    ./finance/stock/vnindex/vps/data/industries.csv        178
# 20    ./world/regions/usa/government/institutions.csv        182
# 47                  ./world/independence-days/raw.csv        184
# 46                 ./world/independence-days/data.csv        184
# 53                ./sports/football/fifa/rankings.csv        208
# 24  ./world/regions/usa/government/legislative/con...        217
# 45                          ./world/states/states.csv        242
# 48                           ./sports/clubs/clubs.csv        280
# 40  ./world/regions/vietnam/sports/football/standi...        295
# 29           ./world/regions/usa/states/governors.csv        296
# 43                          ./world/cities/cities.csv        340
# 39  ./world/regions/vietnam/sports/football/player...        403
# 63                ./languages/languages/languages.csv        548
# 52  ./sports/football/clubs/league/standings/datas...        621
# 36         ./world/regions/vietnam/maps/districts.csv        726
# 54                       ./sports/players/players.csv        849
# 64             ./languages/1000-most-common/words.csv       1000
# 19  ./education/universities/rankings/csv/shanghai...       1001
# 3                   ./nobel/transformed/laureates.csv       1048
# 2                               ./nobel/laureates.csv       1048
# 75                   ./games/pokemon/data/combats.csv       1272
# 76                   ./games/pokemon/data/pokemon.csv       1272
# 13  ./oracle-of-bacon/data/links/900000-1000000-cu...       1317
# 25  ./world/regions/usa/government/executive/indiv...       1378
# 18       ./education/universities/rankings/csv/qs.csv       1499
# 57                   ./sports/champions/champions.csv       1616
# 0                                   ./music/idols.csv       1779
# 1                       ./music/transformed/idols.csv       1779
# 4               ./technology/github/emojis/emojis.csv       1878
# 71  ./finance/stock/vnindex/dragon-capital/history...       1901
# 33     ./world/regions/australia/stock/statistics.csv       2071
# 34      ./world/regions/australia/stock/companies.csv       2071
# 58                      ./languages/quotes/quotes.csv       2278
# 69     ./finance/stock/vnindex/vps/data/companies.csv       2309
# 17    ./education/universities/rankings/csv/times.csv       2346
# 38  ./world/regions/vietnam/sports/football/matche...       2781
# 61  ./languages/text-classification/input/sample_s...       3264
# 62  ./languages/text-classification/output/submiss...       3264
# 30          ./world/regions/usa/stock/market/nyse.csv       3299
# 31        ./world/regions/usa/stock/market/nasdaq.csv       3371
# 56   ./sports/chess/lichess.org/openings/openings.csv       3415
# 59     ./languages/text-classification/input/test.csv       3700
# 50                        ./sports/football/teams.csv       5001
# 26   ./world/regions/usa/stock-watch/clean/senate.csv       6341
# 37  ./world/regions/vietnam/national-assembly/memb...       6516
# 28     ./world/regions/usa/stock-watch/raw/senate.csv       8306
# 60    ./languages/text-classification/input/train.csv       8562
# 67                      ./finance/forex/csv/dates.csv       8884
# 66                    ./finance/forex/csv/history.csv       8884
# 72  ./machine-learning/supervised/house-price-pred...       9359
# 16           ./education/universities/universites.csv       9950
# 35             ./world/regions/vietnam/maps/wards.csv      11563
# 22  ./world/regions/usa/government/legislative/mem...      13498
# 23  ./world/regions/usa/government/legislative/con...      13501
# 73  ./machine-learning/supervised/employee-retenti...      15000
# 32          ./world/regions/australia/postal-code.csv      16884
# 27      ./world/regions/usa/stock-watch/raw/house.csv      16914
# 42                            ./world/visas/visas.csv      27670
# 8      ./oracle-of-bacon/data/links/500000-600000.csv     100001
# 10     ./oracle-of-bacon/data/links/100000-200000.csv     100001
# 6     ./oracle-of-bacon/data/links/900000-1000000.csv     100001
# 5      ./oracle-of-bacon/data/links/800000-900000.csv     100001
# 11     ./oracle-of-bacon/data/links/600000-700000.csv     100001
# 12     ./oracle-of-bacon/data/links/400000-500000.csv     100001
# 14     ./oracle-of-bacon/data/links/300000-400000.csv     100001
# 15     ./oracle-of-bacon/data/links/200000-300000.csv     100001
# 7      ./oracle-of-bacon/data/links/700000-800000.csv     100001
# 9           ./oracle-of-bacon/data/links/0-100000.csv     100001
# 65         ./languages/1000-most-common/languages.csv     103887
# 41                   ./world/timezones/time_zones.csv     145827
# 44                             ./world/cities/all.csv     209580
# 68       ./finance/stock/vnindex/vps/data/history.csv    4021643

# %%
ipynb_data_frame = get_files('.ipynb')
ipynb_data_frame
# Out:
# 64
# ./oracle-of-bacon/number.ipynb 99
# ./world/regions/usa/government/legislative/main.ipynb 87
# ./sports/chess/chess.com/players/test.ipynb 58
# ./finance/stock/nasdaq/query.ipynb 34
#                                             file_path  num_lines
# 49                 ./finance/stock/nasdaq/query.ipynb         34
# 37        ./sports/chess/chess.com/players/test.ipynb         58
# 16  ./world/regions/usa/government/legislative/mai...         87
# 8                      ./oracle-of-bacon/number.ipynb         99
# 5               ./technology/github/emojis/main.ipynb        108
# 4           ./technology/github/gitignores/main.ipynb        110
# 47                 ./languages/detection/detect.ipynb        111
# 6     ./technology/github/codes_of_conduct/main.ipynb        113
# 43                    ./languages/geo-text/main.ipynb        128
# 52  ./finance/stock/vnindex/dragon-capital/query.i...        134
# 40                      ./languages/quotes/main.ipynb        143
# 20               ./world/regions/usa/stock/main.ipynb        155
# 21         ./world/regions/australia/stock/main.ipynb        157
# 42                        ./languages/ntlk/main.ipynb        181
# 58  ./machine-learning/supervised/fashion-mnist/ma...        187
# 7                        ./oracle-of-bacon/main.ipynb        218
# 17  ./world/regions/usa/government/legislative/con...        222
# 63                      ./games/pokemon/analyse.ipynb        232
# 62                        ./games/pokemon/query.ipynb        240
# 56  ./machine-learning/supervised/text-classificat...        253
# 50            ./finance/stock/vnindex/vps/query.ipynb        259
# 36       ./sports/chess/chess.com/players/games.ipynb        269
# 25                          ./world/states/main.ipynb        276
# 3             ./technology/github/licenses/main.ipynb        277
# 23                           ./world/visas/main.ipynb        283
# 27                          ./sports/clubs/main.ipynb        288
# 45            ./languages/1000-most-common/main.ipynb        312
# 15                     ./world/regions/usa/main.ipynb        327
# 2                                  ./nobel/main.ipynb        464
# 34                         ./sports/chess/games.ipynb        511
# 26               ./world/independence-days/main.ipynb        524
# 32                          ./sports/chess/main.ipynb        590
# 55  ./machine-learning/supervised/employee-retenti...        721
# 41         ./languages/text-classification/main.ipynb        773
# 54  ./machine-learning/supervised/linear-regressio...        775
# 59  ./machine-learning/supervised/marketing-cost/m...        777
# 38     ./sports/chess/chess.com/players/analyse.ipynb        807
# 61  ./machine-learning/supervised/length-conversio...        964
# 19              ./world/regions/usa/states/main.ipynb        986
# 1                                  ./music/main.ipynb       1022
# 0                                       ./files.ipynb       1059
# 53  ./machine-learning/supervised/house-price-pred...       1122
# 60  ./machine-learning/supervised/linear-regressio...       1207
# 31                        ./sports/players/main.ipynb       1219
# 22                       ./world/timezones/main.ipynb       1258
# 35          ./sports/chess/lichess.org/openings.ipynb       1360
# 29  ./sports/football/clubs/league/standings/main....       1369
# 57  ./machine-learning/supervised/fuel-efficiency/...       1535
# 18  ./world/regions/usa/government/executive/usa.i...       1800
# 39                      ./sports/champions/main.ipynb       2202
# 28                  ./sports/football/full/main.ipynb       3060
# 9                 ./education/universities/main.ipynb       3088
# 30                  ./sports/football/fifa/main.ipynb       3123
# 24                          ./world/cities/main.ipynb       3350
# 10    ./education/universities/rankings/top-200.ipynb       3700
# 48                         ./finance/forex/main.ipynb       4887
# 46                   ./languages/detection/main.ipynb       5252
# 33              ./sports/chess/analyse-openings.ipynb       6555
# 14                                 ./excel/main.ipynb       6610
# 12  ./education/universities/rankings/rankings-sha...      18912
# 44                     ./languages/popular/main.ipynb      20279
# 11  ./education/universities/rankings/rankings-qs....      34542
# 13  ./education/universities/rankings/rankings-tim...      41814
# 51          ./finance/stock/vnindex/vps/analyse.ipynb     119393
