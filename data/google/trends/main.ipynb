# %%
import requests

# %%
response = requests.get("https://trends.google.com/trends/hottrends/visualize/internal/data")
data = response.json()
data
# Out:
# {'united_states': ['Chiefs',
#   'Cowboys vs Eagles',
#   'Raiders',
#   'USC football',
#   'Tampa Bay Buccaneers',
#   'Buffalo Bills',
#   'Josh Dobbs',
#   'Real Madrid',
#   'Seahawks vs Ravens',
#   'Bass Reeves',
#   'Giants vs Raiders',
#   'India vs South Africa',
#   'Bears vs Saints',
#   'Vikings vs Falcons',
#   'Commanders vs Patriots',
#   'Daniel Jones',
#   'Barcelona',
#   'Cardinals vs Browns',
#   'Damar Hamlin',
#   'Shohei Ohtani'],
#  'india': ['Real Madrid vs Rayo Vallecano',
#   'India vs South Africa',
#   'Ahoi Ashtami',
#   'भारत बनाम दक्षिण अफ्रीका',
#   'IND बनाम SA',
#   'Yuvraj Singh',
#   'Arsenal',
#   'Matthew Perry funeral',
#   'Grok',
#   'Tiger 3 Advance Booking',
#   'Points Table ICC World Cup',
#   'IND vs SA',
#   'New Zealand vs Pakistan',
#   'Earthquake',
#   'न्यूजीलैंड बनाम पाकिस्तान',
#   'Shaheen Afridi',
#   'Crown Jewel 2023',
#   'Hardik Pandya news',
#   'Live news',
#   'Hasan Ali'],
#  'japan': ['地震',
#   '道頓堀 飛び込み',
#   '日本シリーズ MVP',
#   '全日本大学駅伝',
#   '阪神優勝セール',
#   '岡田彰布',
#   '横田 阪神',
#   'アルゼンチン共和国杯',
#   '鈴木千裕',
#   '富山マラソン',
#   'みやこステークス',
#   'RIZIN',
#   '進撃の巨人 完結編',
#   '全日本大学駅伝対校選手権大会',
#   '阪神',
#   '阪神 オリックス',
#   'ネパール 地震',
#   'ブリーダーズカップ',
#   '高校サッカー選手権',
#   'JUJU'],
#  'singapore': ['Luis Diaz father',
#   'Real Madrid vs Rayo Vallecano',
#   'F1 Brazil',
#   'Heng Swee Keat',
#   'India vs South Africa',
#   'Lawrence Wong',
#   'Prince William Singapore',
#   'Virat Kohli',
#   'Man City',
#   'Running Man',
#   'Doku',
#   'Grok',
#   'Man utd',
#   'Attack on Titan',
#   'Nepal earthquake',
#   'Fulham',
#   'Singapore Airlines',
#   'Sam Bankman-Fried',
#   'Mohammed Shami',
#   'Hezbollah'],
#  'israel': ['צוללת גרעינית',
#   'Real Madrid',
#   'אלומה לב',
#   'עמיחי אליהו',
#   'אימאן חטיב',
#   'אוגדה 36',
#   'נערן אשחר',
#   'יצחק בריק',
#   'מנסור עבאס',
#   'ידידיה אליהו',
#   'נועה תשבי',
#   'חנן מור',
#   'עמיחי שיקלי',
#   'יהונתן מימון',
#   "בוריס ג'ונסון",
#   'גילה גמליאל',
#   'נבחרת ישראל',
#   'יובל סמו',
#   'יוסיאן',
#   'Barcelona'],
#  'australia': ['Luton Town vs Liverpool',
#   'Phillip Island',
#   'Real Madrid vs Rayo Vallecano',
#   'Remembrance day',
#   'Scott Morrison',
#   'New York Marathon',
#   'Elvis',
#   'Jay Weinberg',
#   'Daylesford',
#   'India vs South Africa',
#   'UFC',
#   'Melbourne Cup field 2023',
#   'Virat Kohli',
#   'Manchester United',
#   'Kourtney Kardashian',
#   'Newcastle vs Arsenal',
#   'Copa Libertadores',
#   'Crunchyroll',
#   'Man City',
#   'Noosa Triathlon'],
#  'hong_kong': ['阿仙奴',
#   '熱刺',
#   '湯洛雯',
#   'Grok',
#   '黃妍',
#   '氣腹機',
#   '啟德海灣',
#   '尹光演唱會',
#   '葉劉淑儀',
#   '李強',
#   '進擊的巨人',
#   '進擊的巨人完結篇後篇',
#   '地震',
#   '洪卓立',
#   '地震香港',
#   '共創明Teen',
#   '以愛為營',
#   'Wembanyama',
#   '膿腫分枝桿菌',
#   'FTX'],
#  'taiwan': ['唐禹哲',
#   '梁文傑',
#   '廖先翔',
#   '鹿角蕨',
#   '太平山翻車',
#   '周天成',
#   '阪神',
#   'NONO',
#   '林子偉',
#   '梁朝偉',
#   '三重派出所',
#   '進擊的巨人',
#   '林昀儒',
#   '劉基鴻',
#   '進擊的巨人完結篇後篇',
#   '季中錦標賽',
#   '徐佳瑩',
#   '尼泊爾',
#   '味全龍',
#   '廖科溢'],
#  'canada': ['Oilers',
#   'Kansas City Chiefs',
#   'Real Madrid',
#   'Raptors vs Spurs',
#   'Calgary Flames',
#   'Connor Bedard',
#   'Spurs',
#   'Buffalo Bills',
#   'Virat Kohli',
#   'Whitecaps',
#   'Time',
#   'Luton Town vs Liverpool',
#   'Chicago Blackhawks',
#   'Lakers',
#   'Joshua Dobbs',
#   'Fernando Alonso',
#   'Grok',
#   'Cowboys vs Eagles',
#   'Claudette Dion',
#   'Barbra Streisand'],
#  'germany': ['DFB-Pokal Auslosung',
#   'Heidenheim gegen VfB Stuttgart',
#   'Werder Bremen',
#   'Real Madrid',
#   'Russland Interkontinentalrakete',
#   'Bayern',
#   'Hertha BSC',
#   'Tatort: Was ihr nicht seht',
#   'Arsenal',
#   'Jay Weinberg',
#   'Polarlichter',
#   'Hamburg Flughafen',
#   'NFL',
#   'Tuchel',
#   'Voss-Tecklenburg',
#   'BVB',
#   'Sam Bankman-Fried',
#   'Sturm',
#   'Antisemitismus',
#   'Alles Licht, das wir nicht sehen'],
#  'netherlands': ['Noorderlicht Nederland',
#   'NEC',
#   'FC Utrecht',
#   'Sparta',
#   'RTL Verkiezingsdebat',
#   'PEC Zwolle',
#   'Alonso',
#   'Pieter Omtzigt',
#   'Hamburg',
#   'Marathon New York',
#   'Fem van Empel',
#   'Queens of the Stone Age',
#   'Hercules',
#   'Go Ahead',
#   'Rico Verhoeven',
#   'Ajax  Heerenveen',
#   'Feyenoord',
#   'PSV',
#   'Vitesse',
#   'Rico'],
#  'indonesia': ['Fiorentina vs Juventus',
#   'Roma vs Lecce',
#   'Tottenham vs Chelsea',
#   'Demo',
#   'Madrid vs Rayo',
#   'Real Sociedad vs Barcelona',
#   'Al-nassr vs Al Khaleej',
#   'Luton vs Liverpool',
#   'Dortmund vs Bayern',
#   'Milan vs Udinese',
#   'Atalanta vs Inter',
#   'Sscasn.bkn.go.id 2023',
#   'Nottingham Forest vs Aston Villa',
#   'Jadwal final Hylo Open 2023',
#   'Girona',
#   'Istri founder Grab dukung Israel',
#   'Venom',
#   'Hassan Nasrallah',
#   'ASN',
#   'Lyon'],
#  'south_korea': ['UFC',
#   '프로야구',
#   '김하성',
#   '태풍',
#   '리플',
#   '공매도 금지',
#   '1092회 로또 당첨번호',
#   'T1',
#   'T1 LNG',
#   '야구',
#   '황희찬',
#   '김길수 이틀째',
#   'JTBC 마라톤',
#   'LNG',
#   '김효진',
#   '이상민',
#   'PSG',
#   '광안리 불꽃축제',
#   '이동건',
#   '정주연'],
#  'turkey': ['Kim Milyoner Olmak İster',
#   'Kuzey Işıkları',
#   'Jeomanyetik fırtına',
#   'Monaco',
#   'Nice',
#   'Enes Kanter',
#   'Villarreal',
#   'Stuttgart',
#   'Beşiktaş',
#   'Real Madrid',
#   'Adana Demirspor',
#   'Başakşehir  Ankaragücü',
#   'Büyük İskender',
#   'Konyaspor',
#   'Amedspor',
#   'Eric Bailly',
#   'Giresunspor',
#   'İncirlik Üssü',
#   'Bursaspor',
#   'Formula 1'],
#  'philippines': ['Cavaliers vs Warriors',
#   'Spurs vs Raptors',
#   'Pistons vs Suns',
#   'Daylight savings time',
#   'Essay',
#   'DST',
#   'Short Story',
#   'June Mar Fajardo',
#   'Rivermaya',
#   'Collapsed lung',
#   'Mental health',
#   'Flag',
#   'Magic vs Lakers',
#   '76ers vs Suns',
#   'PBA',
#   'Nets vs Celtics',
#   'Juan Jumalon',
#   'Elvish Yadav',
#   'Portfolio',
#   'UFC'],
#  'italy': ['Cuori ultima puntata',
#   'Kkr',
#   'Roma - Lecce',
#   'Verona-Monza',
#   'Andrea Iovino morto',
#   'Patty Pravo',
#   'Aurora boreale Italia',
#   'Real Madrid',
#   'Lino Banfi',
#   'Cremonese-Spezia',
#   'Dove vedere Fiorentina Juventus',
#   'Annalena Baerbock',
#   'Taranto Juve Stabia',
#   'Reggiana',
#   'Giuggiole',
#   'Parma-Sudtirol',
#   'Sentenza Tar Lazio Visite fiscali',
#   'Schumacher',
#   'Juventus Football Club',
#   'Marcelo'],
#  'vietnam': ['Real Madrid',
#   'Real vs',
#   'Roma',
#   'Saudi Pro League',
#   'Newcastle đấu với Arsenal',
#   'Al-nassr đấu với Al Khaleej',
#   'Gin Tuấn Kiệt',
#   'Bang xep hang ngoai hang anh',
#   'Aston Villa',
#   'Liverpool vs',
#   'Ac milan',
#   'Inter Milan',
#   'Dortmund',
#   'Tottenham vs Chelsea',
#   'T1',
#   'Xổ số miền Nam ngày 5 tháng 11',
#   'Barcelona',
#   'Manchester city',
#   'Tennis Paris Masters',
#   'Bxh ngoai hang anh'],
#  'egypt': ['Real Madrid',
#   'الريال',
#   'احمد فتوح',
#   'مسلسل روحي فيك',
#   'ريال مدريد',
#   'برشلونة',
#   'بيومي فؤاد',
#   'الوداد وصن داونز',
#   'ارسنال',
#   'الاسماعيلي',
#   'فيوتشر',
#   'اسلام البحيري',
#   'كاس العالم للاندية',
#   'جيرونا',
#   'امير كرارة',
#   'مستر اولمبيا 2023',
#   'مارسيلو',
#   'الاهلي',
#   'مانشستر سيتي',
#   'النصر'],
#  'argentina': ['Racing',
#   'Talleres',
#   'Union',
#   'Cyber Monday',
#   'Estudiantes',
#   "Newell's",
#   'Real Madrid',
#   'Ferro',
#   'Partido Boca',
#   'Debate presidencial',
#   'Temperley',
#   'Copa Argentina',
#   'Luton  Liverpool',
#   'Temblor en Mendoza',
#   'Formula 1 Brasil',
#   'Fiorentina - Juventus',
#   'Lunes 6 de noviembre es feriado',
#   'Central Norte',
#   'Meme Boca Fluminense',
#   'Nottingham Forest  Aston Villa'],
#  'poland': ['Śląsk Wrocław – ŁKS Łódź',
#   'Zorza polarna',
#   'Barcelona',
#   'Radomiak – Legia Warszawa',
#   'Raków Częstochowa – Zagłębie Lubin',
#   'Anita Lipnicka',
#   'GKS Tychy – Lechia',
#   'Luton Town – Liverpool',
#   'Jerzy Bralczyk',
#   'Bruce Willis',
#   'Fiorentina – Juventus',
#   'UFC',
#   'Patryk Klimala',
#   'Motor Lublin – Wisła Płock',
#   'Real',
#   'Kubica',
#   'Lech',
#   'Stal – GKS Katowice',
#   'Roma',
#   'Dzien Postaci z Bajek'],
#  'colombia': ['Cúcuta  Millonarios',
#   'Real Madrid',
#   'Luton  Liverpool',
#   'Barcelona',
#   'Arsenal',
#   'Juventus',
#   'FC Barcelona',
#   'Nottingham Forest - Aston Villa',
#   'Maria Jimena duzan',
#   'ESPN',
#   'Barcelona hoy',
#   'Loteria de boyaca 4 de noviembre 2023',
#   'Racing  Central Córdoba',
#   'Gol de luis diaz',
#   'Nottingham Forest vs Aston Villa',
#   'Marilyn Patiño',
#   'Villarreal',
#   'Corregimiento El Plateado Cauca',
#   'BARRANQUILLA.  Llaneros',
#   'Chiefs  Dolphins'],
#  'ukraine': ['Юрій Глодан',
#   'Північне сяйво Аврора',
#   'Северное сияние',
#   'Жирона',
#   'Лутон – Ливерпуль',
#   'Реал Мадрид – Райо Вальекано',
#   'Седово',
#   'Пугачева',
#   'Минай – Ворскла',
#   'Мэттью Перри',
#   'Металлист 1925 – Черноморец',
#   'Новости Одессы',
#   '5 листопада свято',
#   'Арсенал',
#   'Верес – Заря',
#   'Металіст 1925 – Чорноморець',
#   'Рома – Лечче',
#   '128 бригада',
#   'Осасуна Жирона',
#   'Аскольд корабль'],
#  'saudi_arabia': ['الوحدة',
#   'محمود عباس',
#   'ريال مدريد',
#   'ترتيب الدوري الانجليزي',
#   'برشلونة',
#   'دوري ابطال اسيا',
#   'الدوري الإنجليزي الممتاز',
#   'احمد حجازي',
#   'ابطال اسيا',
#   'بيومي فؤاد',
#   'مارسيلو',
#   'الوداد وصن داونز',
#   'WWE',
#   'الأهلي',
#   'Grok',
#   'انتر ميلان',
#   'بايرن',
#   'نيوكاسل',
#   'بوكا جونيورز',
#   'الاتفاق'],
#  'kenya': ['Luton Town vs Liverpool',
#   'Arsenal',
#   'Nottm Forest vs Aston Villa',
#   'Real Madrid vs Rayo Vallecano',
#   'New York Marathon 2023',
#   'Barcelona',
#   'MrBeast',
#   'India vs South Africa',
#   'Gor Mahia',
#   'Roma',
#   'Grok',
#   'Arsenal vs Man City',
#   'Girona',
#   'Stuttgart FC',
#   'Boca Juniors vs Fluminense',
#   'Haaland',
#   'Monaco',
#   'Luis Diaz father',
#   'Celine Dion',
#   'IND vs SA'],
#  'chile': ['Real Madrid',
#   'Prince royce',
#   'Joe Vasconcellos',
#   'Barcelona',
#   'Luton  Liverpool',
#   'Arsenal',
#   'Aston Villa',
#   'Villarreal  Athletic',
#   'Neven Ilic',
#   'Juventus',
#   'Barranquilla',
#   'Juegos Parapanamericanos',
#   'Ricardo Lagos',
#   'Cuestionario Disney 100 5 de noviembre',
#   'FC Barcelona',
#   'Cbum',
#   'Francisco Dañobeitía',
#   'Juegos olimpicos',
#   'Artistas cierre Panamericanos',
#   'Jay Weinberg'],
#  'romania': ['Farul Constanța  Botoşani',
#   'Aurora boreala romania',
#   '„U” Cluj  Voluntari',
#   'Real Madrid - Rayo',
#   'Alaves',
#   'Copa Libertadores',
#   'Nepal',
#   'FCSB vs Rapid București',
#   'Alegeri Moldova',
#   'Arsenal',
#   'Grok',
#   'Doru Octavian Dumitru',
#   'Max Verstappen',
#   'AC Milan',
#   'Derek Lunsford',
#   'FCSB vs Rapid',
#   'Djokovic Dimitrov',
#   'Kourtney Kardashian',
#   'Hamburg',
#   'Universitatea Craiova  U Craiova 1948'],
#  'south_africa': ['Tottenham vs Chelsea',
#   'Luton Town vs Liverpool',
#   'Bonginkosi Ntuli',
#   'Real Madrid',
#   'Cricket',
#   'Barcelona',
#   'Nottm Forest vs Aston Villa',
#   'Sundowns vs Wydad',
#   'Roma',
#   'Fiorentina vs Juventus',
#   'Girona',
#   'UFC',
#   'Tottenham',
#   'Brentfordfc',
#   'Soweto Marathon',
#   'Brazilian Grand Prix',
#   'Kourtney Kardashian',
#   'Norwich City',
#   'Chiefs vs Dolphins',
#   'VfL Wolfsburg'],
#  'belgium': ['Club NXT',
#   'Anderlecht',
#   'Real Madrid',
#   'Cercle Bruges – Anderlecht',
#   'Celine Dion',
#   'Real Madrid – Rayo',
#   'Gert Verhulst',
#   'Max Verstappen',
#   'Noorderlicht belgie',
#   'Juventus',
#   'Standard  Mechelen',
#   'Marathon New York',
#   'Michael Vanthourenhout',
#   'Barca',
#   'Luton Town – Liverpool',
#   'Jacques Vermeire',
#   'Claude Lelouch',
#   'RWDM',
#   'Fem van Empel',
#   'Aeroport Hambourg otage'],
#  'sweden': ['Real Madrid',
#   'Elfsborg',
#   'Malmö FF',
#   'Alba August',
#   'Arsenal',
#   'Djurgården',
#   'UFC',
#   'Bluesky',
#   'Brommapojkarna',
#   'Kjell Höglund',
#   'Bögen är lös',
#   'Gais',
#   'Örebro',
#   'Hammarby',
#   'Coco Chanel',
#   'Copa Libertadores',
#   'Manchester United',
#   'Elton John',
#   'Sirius',
#   'Frölunda'],
#  'austria': ['LASK gegen Sturm Graz',
#   'SCR Altach gegen Rapid Wien',
#   'Polarlichter Österreich',
#   'Real Madrid',
#   'ÖFB-Cup',
#   'Hartberg gegen Blau-Weiß Linz',
#   'NFL Frankfurt',
#   'Florian David Fitz',
#   'Leiche im Wolfgangsee gefunden',
#   'Özgür Özel',
#   'Alonso',
#   'Ottfried Fischer',
#   'Crunchyroll',
#   'Antisemitismus',
#   'Arsenal',
#   'Jenny Elvers',
#   'DFB-Pokal-Auslosung',
#   'WAC',
#   'Wolfsburg gegen Werder Bremen',
#   'WTA Finals'],
#  'switzerland': ['Hambourg prise otage',
#   'Hamburg Flughafen',
#   'Real Madrid',
#   'Stade-Lausanne gegen St.Gallen',
#   'FCL',
#   'FCB gegen Yverdon-Sport',
#   'New York marathon 2023',
#   'Celine Dion',
#   'FC Bayern',
#   'Max Verstappen',
#   'Polarlichter Schweiz',
#   'Fiorentina  Juventus',
#   'Luton Town gegen Liverpool',
#   'NFL Frankfurt',
#   'Patrick Fischer',
#   'FC Sion',
#   'Florian David Fitz',
#   'Werdinsel',
#   'Özgür Özel',
#   'Real Madrid – Rayo'],
#  'greece': ['Βορειο σελασ',
#   'Βολος',
#   'ΡΕΑΛ ΜΑΔΡΙΤΗΣ',
#   'ΠΑΟΚ',
#   'ΑΡΗΣ ΑΤΡΟΜΗΤΟΣ',
#   'ΠΑΟΚ ολυμπιακοσ μπασκετ',
#   'Νατάσα Θεοδωρίδου',
#   'Στα συνορα',
#   'Παναιτωλικοσ',
#   'ΠΑΣ γιαννινα',
#   'Metropolis',
#   'Πετροσ κοκκαλησ',
#   'Αμβουργο',
#   'Μπερλουσκόνι',
#   'Αρησ λεμπεσοπουλοσ',
#   'Κοζανη ΑΕΛ',
#   'Ανδρεασ μικρουτσικοσ',
#   'Lotto',
#   'Τζοκοβιτσ',
#   'ΙΩΝΙΚΟΣ'],
#  'denmark': ['Real Madrid',
#   'Luton  Liverpool',
#   'UFC',
#   'Hamburg airport',
#   'Max Verstappen',
#   'Attack on Titan',
#   'Wales',
#   'India vs South Africa',
#   'Crunchyroll',
#   'Brent Faiyaz',
#   'New York Marathon 2023',
#   'Cliff Richard',
#   'Fulham  Man utd',
#   'Man City  Bournemouth',
#   'Rublev',
#   'Arsenal',
#   'Copa Libertadores',
#   'Nicolas Dalby',
#   'Real Sociedad  Barcelona',
#   'Dortmund  Bayern'],
#  'norway': ['Nordlys',
#   'KFUM',
#   'Bodø/Glimt',
#   'ROSENBORG - MOLDE',
#   'Luton',
#   'Sverre Nypan',
#   'Stabæk',
#   'Til',
#   'Tromsø',
#   'Newcastle',
#   'LSK',
#   'Bjarne Melgaard',
#   'Tromsø strømsgodset',
#   'Grok',
#   'Odd René Andersen',
#   'Bayern',
#   '71 grader nord kjendis',
#   'Gro Harlem Brundtland',
#   'Allehelgensdag',
#   'Manchester United'],
#  'nigeria': ['Sporting',
#   'Real Madrid vs Rayo Vallecano',
#   'Luton Town vs Liverpool',
#   'Barcelona',
#   'Nottm Forest vs Aston Villa',
#   'Roma vs Lecce',
#   'Girona',
#   'Fcbarcelona',
#   'Arsenal vs Man City',
#   'Grok',
#   'Stuttgart FC',
#   'India vs South Africa',
#   'Lyon',
#   'Juventus vs Fiorentina',
#   'Crunchyroll',
#   'Fluminense',
#   'Brentford',
#   'Marcelo',
#   'Nepal',
#   'Fulham vs Man United'],
#  'new zealand': ['Cricket World Cup Table',
#   'Luton Town vs Liverpool',
#   'India vs South Africa',
#   'UFC',
#   'Melbourne Cup field 2023',
#   'IND vs SA',
#   'Whale New Brighton',
#   'Fulham vs Man United',
#   'Attack on Titan final episode',
#   'Mr. Olympia 2023',
#   'Kourtney Kardashian',
#   'Newcastle vs Arsenal',
#   'Kate Bush',
#   'Sylvester Stallone',
#   'Crunchyroll',
#   'Man City',
#   'Man City vs Bournemouth',
#   'WWE Crown Jewel 2023',
#   'Locked in',
#   'Pickleball'],
#  'ireland': ['Aurora borealis',
#   'Luton Town vs Liverpool',
#   'India vs South Africa',
#   'Nottm Forest vs Aston Villa',
#   'Real Madrid',
#   'Des Cahill',
#   'Luis Diaz father',
#   'Hamburg airport',
#   'Keanu Reeves',
#   'Bruce Springsteen tickets',
#   'Northern lights Ireland',
#   'Wrexham',
#   'New York Marathon 2023',
#   'Attack on Titan',
#   'Suella Braverman',
#   'Ogbene',
#   'Wayne Lineker',
#   'Paul McCartney',
#   'Virat Kohli',
#   'Arsenal vs Man City'],
#  'czech_republic': ['Slavia – Plzeň',
#   'Alois Fišárek',
#   'Polární záře',
#   'Max Verstappen',
#   'Metráček',
#   'Luton – Liverpool',
#   'Emma Smetana',
#   'Kráska a zvíře',
#   'Jakub Vadlejch',
#   'Arsenal',
#   'Kourtney Kardashian',
#   'Svatý Martin',
#   'San jose Sharks',
#   'Simonová',
#   'Sparta',
#   'StarDance',
#   'Real Sociedad – Barcelona',
#   'Teplice – Boleslav',
#   'Melanie Martinez',
#   'Hoffenheim – Leverkusen'],
#  'portugal': ['Lewis Hamilton',
#   'Jogos Sporting',
#   'SPORTING BENFICA',
#   'Sporting',
#   'Real Madrid',
#   'Manifestação IUC',
#   'Palmeiras',
#   'Moreirense',
#   'Luton Town  Liverpool',
#   'Sporting cp',
#   'Barcelona',
#   'Fortaleza  Flamengo',
#   'Leiria  Marítimo',
#   'Cruzeiro',
#   'Distritos sob aviso vermelho',
#   'Aeroporto Hamburgo Alemanha',
#   'MAAT',
#   'Fiorentina  Juventus',
#   'Max Verstappen',
#   'Casa Pia-Vizela'],
#  'mexico': ['Real Madrid',
#   'Pumas',
#   'Santos  Toluca',
#   'Chiefs  Dolphins',
#   'Barcelona',
#   'Eagles  Cowboys',
#   'Luton  Liverpool',
#   'Necaxa',
#   'Juárez  Querétaro',
#   'Arsenal',
#   'Seahawks',
#   'Refrigerador',
#   'Raiders',
#   'Aston Villa',
#   'Villarreal',
#   'Slipknot Jay Weinberg',
#   'Pago Pensión Bienestar adultos mayores',
#   'Fiorentina - Juventus',
#   'Bills',
#   'Club Deportivo Guadalajara'],
#  'malaysia': ['Luton Town vs Liverpool',
#   'Real Madrid vs Rayo Vallecano',
#   'Fiorentina vs Juventus',
#   'India vs South Africa',
#   'Newcastle vs Arsenal',
#   'Man City',
#   'Nottm Forest vs Aston Villa',
#   'Real Sociedad vs Barcelona',
#   'IND vs SA',
#   'Yahya Sinwar',
#   'UFC',
#   'Sheffield United vs Wolves',
#   'Fluminense',
#   'Lawrence Wong',
#   'Milan vs Udinese',
#   'Novak Djokovic',
#   'Burnley vs Crystal Palace',
#   'Grok',
#   'Fulham vs Man United',
#   'New Zealand vs Pakistan'],
#  'hungary': ['Brasch Bence',
#   'Luton–liverpool',
#   'Sarki fény',
#   'Jákob Zoltán',
#   'Real madrid–rayo',
#   'Tóth Gabi',
#   'Harry Potter',
#   'Nottingham forest–aston Villa',
#   'BYD',
#   'Hertha',
#   'Zacher Gábor',
#   'KTE',
#   'Baba Vanga',
#   'Kecskemét Ferencváros',
#   'Matteo Salvini',
#   'AC Milan',
#   'Hamburg',
#   'Kulcsár Edina',
#   'Nyugdíjemelés',
#   'Villarreal–bilbao'],
#  'russia': ['Магнитные бури',
#   'Спартак-Москва',
#   'Краснодар – Крылья Советов',
#   'Реал Мадрид – Райо Вальекано',
#   'Северное сияние',
#   'Локомотив Спартак',
#   'Лутон – Ливерпуль',
#   'UFC',
#   'Адам Кадыров',
#   'Арсенал',
#   'Темирканов',
#   'Казанская икона Божией Матери',
#   'Балтика – Зенит',
#   'Атака титанов',
#   'Гонконгский грипп',
#   'Мэттью Перри',
#   'Мэттью Перри похороны',
#   'Землетрясение в Непале',
#   'Казанская икона Божией Матери Праздник',
#   'Манчестер Юнайтед'],
#  'thailand': ['เรอัลมาดริด',
#   'ดอร์ทมุนด์ พบ บาเยิร์น',
#   'หมอกฤตไท',
#   'ราชบุรี เอฟซี พบ ชลบุรี',
#   'คะแนนพรีเมียร์ลีก',
#   'เกาหลีใต้',
#   'บัวขาว VS แสนชัย',
#   'แมนยู',
#   'แมนซิตี้',
#   'ฟูแล่ม',
#   'ทอดกฐิน',
#   'พระสมุทรเจดีย์สมุทรปราการ',
#   'แอนโทเนีย',
#   'เลสเตอร์ซิตี้',
#   'คืนเปลี่ยนชีวิต Ep.12',
#   'ณพ ณรงค์เดช',
#   'แมนยู',
#   'ลิเวอร์พูล',
#   'ลีกคัพ',
#   'พระเจ้าท้ายสระ'],
#  'brazil': ['Nair Bello',
#   'Bragantino',
#   'Barcelona',
#   'Coritiba x Goiás',
#   'EC Vitória x Vila Nova',
#   'Arsenal',
#   'Luton Town x Liverpool',
#   'Marilia Mendonça',
#   'Juventus',
#   'David Niven',
#   'Sporting',
#   'Soweto',
#   'Ludmilla',
#   'Greve onibus DF',
#   'Quantas questões tem o Enem',
#   'Roma',
#   'Attack on Titan',
#   'Chiefs x Dolphins',
#   'Lyon',
#   'Rei leao'],
#  'france': ['Section Paloise',
#   'Celine Dion',
#   'Aline',
#   'Real Madrid',
#   'OL',
#   'Madonna',
#   'Nice – Rennes',
#   'Claude Lelouch',
#   'Spurs',
#   'Otages aeroport Hambourg',
#   'Josephine Baker',
#   'Edouard Philippe service militaire',
#   'Monaco – Brest',
#   'Strasbourg – Clermont',
#   'Lyon',
#   'Toulouse – Le Havre',
#   'Marathon New York',
#   'Darmanin',
#   'FC Nantes',
#   'Grand Prix bresil'],
#  'united_kingdom': ['Northern Lights',
#   'Jay Weinberg',
#   'Luton Town vs Liverpool',
#   'India vs South Africa',
#   'Nottm Forest vs Aston Villa',
#   'UFC',
#   'Real Madrid',
#   'F1 results',
#   'Norwich City',
#   'Luis Diaz father',
#   'Hamburg airport',
#   'Virat Kohli',
#   'Remembrance Sunday',
#   'Portsmouth FC',
#   'Adam Thomas',
#   'Bayern',
#   'Machine Gun Kelly',
#   'Glastonbury 2024',
#   'Bristol City',
#   'Wayne Lineker'],
#  'finland': ['Jay Weinberg',
#   'India vs South Africa',
#   'Luton Town – Liverpool',
#   'Real Sociedad – Barcelona',
#   'Nashville Predators',
#   'UFC',
#   'Add',
#   'Hamburg airport',
#   'Real Madrid – Rayo Vallecano',
#   'Kourtney Kardashian',
#   'It 2',
#   'Leonard Cohen',
#   'Arsenal',
#   'Sound of Freedom',
#   'New Zealand vs Pakistan',
#   'Mr. Olympia 2023',
#   'Manchester United',
#   'Waterloo',
#   'Cohen',
#   'Matthew Perry funeral']}

# %%
countries = list(data.keys())
countries.sort()
countries
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'belgium',
#  'brazil',
#  'canada',
#  'chile',
#  'colombia',
#  'czech_republic',
#  'denmark',
#  'egypt',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong_kong',
#  'hungary',
#  'india',
#  'indonesia',
#  'ireland',
#  'israel',
#  'italy',
#  'japan',
#  'kenya',
#  'malaysia',
#  'mexico',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'philippines',
#  'poland',
#  'portugal',
#  'romania',
#  'russia',
#  'saudi_arabia',
#  'singapore',
#  'south_africa',
#  'south_korea',
#  'sweden',
#  'switzerland',
#  'taiwan',
#  'thailand',
#  'turkey',
#  'ukraine',
#  'united_kingdom',
#  'united_states',
#  'vietnam']

# %%
vietnam = data.get('vietnam', [])
vietnam.sort()
vietnam
# Out:
# ['Ac milan',
#  'Al-nassr đấu với Al Khaleej',
#  'Aston Villa',
#  'Bang xep hang ngoai hang anh',
#  'Barcelona',
#  'Bxh ngoai hang anh',
#  'Dortmund',
#  'Gin Tuấn Kiệt',
#  'Inter Milan',
#  'Liverpool vs',
#  'Manchester city',
#  'Newcastle đấu với Arsenal',
#  'Real Madrid',
#  'Real vs',
#  'Roma',
#  'Saudi Pro League',
#  'T1',
#  'Tennis Paris Masters',
#  'Tottenham vs Chelsea',
#  'Xổ số miền Nam ngày 5 tháng 11']
