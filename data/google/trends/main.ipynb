# %%
import requests

# %%
response = requests.get("https://trends.google.com/trends/hottrends/visualize/internal/data")
data = response.json()
data
# Out:
# {'united_states': ['Olivia Rodrigo',
#   'Australia vs Netherlands',
#   'Marvin Jones',
#   'Meta',
#   'NBA',
#   'Tom Emmer',
#   'Warriors',
#   'Lakers',
#   'Richard Roundtree',
#   'Dwight Howard',
#   'Real Madrid',
#   'UEFA Champions League',
#   'Hurricane',
#   'Arsenal',
#   'LeBron James',
#   'Kurt Cobain',
#   'Bayern Munich',
#   'Britney Spears book',
#   'Al Nassr',
#   'Kelce and Swift'],
#  'india': ['Glenn Maxwell',
#   'Al Nassr',
#   'Sevilla vs Arsenal',
#   'Fastest century in ODI',
#   'Real Madrid',
#   'Nilesh Rane',
#   'Blue Jet Healthcare IPO GMP',
#   'Bill Ackman',
#   'Aspirants',
#   'Pat Cummins',
#   'Vinayakan',
#   'Leo box office collection worldwide day',
#   'Leo box office collection worldwide day 6',
#   'England vs Sri Lanka',
#   'Australia vs Netherlands',
#   'BAN vs SA',
#   'Champions League',
#   'Putin',
#   'Wankhede Stadium',
#   'Happy Vijayadashami'],
#  'japan': ['FGO',
#   'ジャパンモビリティショー2023',
#   'じゃこ天',
#   'NBA',
#   '山田太郎',
#   '黒柳徹子',
#   'Cl',
#   '雪虫 大量発生',
#   'プーチン',
#   '度会隆輝',
#   '社会保険料',
#   'リバース1999',
#   '後藤真希',
#   '李尚福',
#   'フリースクール',
#   '性別変更 手術 違憲',
#   'バクチク 櫻井',
#   '山崎まさよし',
#   '所得税 減税 給付金',
#   '名城高校'],
#  'singapore': ['Glenn Maxwell',
#   'Man United vs Copenhagen',
#   'Australia vs Netherlands',
#   'Sevilla vs Arsenal',
#   'Al Nassr',
#   'Lakers',
#   'Real Madrid',
#   'Bayern Munich',
#   'G-Dragon',
#   'Warriors',
#   'Bill Kenwright',
#   'Champions League',
#   'Jisoo',
#   'Bitcoin',
#   'Putin',
#   'AFC Champions League',
#   'Li Shangfu',
#   'ERP',
#   'Champions League',
#   'Zhang Ziyi'],
#  'israel': ['NBA',
#   'ערן זהבי',
#   'יצחק רבין',
#   'ארדואן',
#   'מאיר שפיגלר',
#   'מלכת ירדן',
#   'אבו עוביידה',
#   'הילולת רחל אמנו',
#   'דליית אל כרמל',
#   'אלפרד אקירוב',
#   'אילת',
#   'אבי מעוז',
#   'ארסנל',
#   'חיים אתגר',
#   'דוד מידן',
#   'דרוזים',
#   "מנצ'סטר יונייטד",
#   'קבר רחל',
#   'עמיחי אליהו',
#   'אלפי מנשה'],
#  'australia': ['Glenn Maxwell',
#   'Kate And Leopold',
#   'NBA',
#   'Australia vs Netherlands',
#   'Arsenal',
#   'Warriors vs Suns',
#   'Geelong Cup',
#   'Inflation rate Australia',
#   'Britney Spears book',
#   'Al Nassr',
#   'Frances Bean Cobain',
#   'Lakers',
#   'Real Madrid',
#   'Vegemite',
#   'LeBron James',
#   'Richard Roundtree',
#   'Radar',
#   'AFC Champions League',
#   'Russell Northe',
#   'Bayern Munich'],
#  'hong_kong': ['NBA',
#   '施政報告 2024',
#   '李善均',
#   '刘昆',
#   '许家印',
#   '許文明',
#   'DJI Pocket 3',
#   'Now',
#   '侯孝賢',
#   '傑志',
#   'Ado',
#   '買樓印花稅',
#   '新生嬰兒',
#   '北部都會區',
#   '越南',
#   '欧冠',
#   '佘詩曼',
#   '施政報告2023',
#   '李尚福',
#   'My little airport'],
#  'taiwan': ['NBA',
#   '侯孝賢',
#   'GD',
#   '台中購物節',
#   '勇士',
#   '嘉義火災',
#   '宋楚瑜',
#   '旺宏',
#   '內心住著什麼小怪物',
#   '宜蘭',
#   '體育',
#   '響尾蛇',
#   '後藤真希',
#   '李佳琦',
#   '張漢雄',
#   '兆豐金',
#   '心理測驗',
#   '錐麓古道',
#   '地震',
#   '新澳隧道'],
#  'canada': ['Australia vs Netherlands',
#   'Calgary Flames',
#   'Acapulco',
#   'Ottawa Senators',
#   'Travis Dermott',
#   'Taux directeur Banque du Canada',
#   'Olivia Rodrigo',
#   'Panera Bread Charged Lemonade lawsuit',
#   'PSG',
#   'NewJerseyDevils',
#   'Frozen Frenzy NHL',
#   'Bruins',
#   'NBA',
#   'Canadiens',
#   'Sault Ste. Marie',
#   'Lakers',
#   'Tom Emmer',
#   'Maple Leafs vs Capitals',
#   'Suns vs Warriors',
#   'Arsenal'],
#  'germany': ['NBA',
#   'RB Leipzig',
#   'Richard Roundtree',
#   'Lutz Riemann',
#   'Bayern München',
#   'Guterres',
#   'Peter Hahn Insolvenzverfahren',
#   'In aller Freundschaft',
#   'Helgoland',
#   'Cities: Skylines 2',
#   'Biontech',
#   'Champions League',
#   'Galatasaray',
#   'Oliver Pocher',
#   'Bombendrohungen Schulen',
#   'Bombendrohung',
#   'Rockstar Games',
#   'Sahra Wagenknecht',
#   'Salman Rushdie',
#   'Tatort Murot und das Paradies'],
#  'netherlands': ['Feyenoord',
#   'Richard Roundtree',
#   'Taylor Swift',
#   'Europa League',
#   'CIDI',
#   'Bilal Wahib',
#   'Tour de France 2024',
#   'NBA',
#   'Omtzigt verkiezingsprogramma',
#   'StemWijzer',
#   'Bitcoin',
#   'Real Madrid',
#   'Steijn',
#   'Ten Hag',
#   'PSV',
#   'Fcgroningen',
#   'FC Emmen',
#   'Ajax',
#   'Utrecht -  Ajax',
#   'FC Twente'],
#  'indonesia': ['Al-nassr vs al-duhail',
#   'Braga vs Madrid',
#   'Andi Amran Sulaiman',
#   'Barcelona vs Shakhtar',
#   'Jembatan kaca Banyumas',
#   'NBA',
#   'PSG',
#   'Lazio',
#   'Newcastle',
#   'Champion',
#   'Luhut Binsar Pandjaitan',
#   'Koalisi Indonesia Maju',
#   'Jason Statham',
#   'City',
#   'Ustadz Hanan Attaki',
#   'Liga Saudi',
#   'Liga eropa',
#   'Hujan',
#   'Fetus in fetu',
#   'Woozi'],
#  'south_korea': ['K5',
#   '독도',
#   '지진',
#   'NBA',
#   '경기도 버스 파업',
#   '맨유',
#   '바이에른 뮌헨',
#   '최원석',
#   '신인규',
#   '강치',
#   '여의도 싱크홀',
#   '이필모',
#   '푸틴 건강 이상설',
#   '이호진 태광그룹',
#   '지드래곤',
#   '그대들은 어떻게 살 것인가',
#   '남현희 전청조',
#   '비트코인',
#   '전혜진',
#   '챔피언스리그'],
#  'turkey': ['Steam',
#   'Otoyol ve köprü geçiş ücretlerine zam',
#   'Kerem Aktürkoğlu',
#   'Pişmaniye nasıl yapılır',
#   'NBA',
#   'Manchester City',
#   'Newcastle',
#   'Uzay Heparı',
#   'Devlet Bahçeli',
#   'PSG',
#   'BIST',
#   'Feyenoord',
#   'Recep Tayyip Erdoğan İsrail',
#   'Anayasa Mahkemesi Can Atalay',
#   'Atletico Madrid',
#   'Devre kesici nedir',
#   'Resmi Gazete vergisiz telefon',
#   'Lazanya tarifi',
#   'TV',
#   'Manchester United-Kopenhag'],
#  'philippines': ['Bulusan Volcano',
#   'NBA',
#   'Warriors vs Suns',
#   'Miss Grand International 2023',
#   'Sports',
#   'Putin',
#   'Comelec',
#   'LeBron James',
#   'Dwight Howard',
#   'Champions League',
#   'Qatar Airways CEO Akbar Al Baker',
#   'Cathay Pacific',
#   'The Exorcist: Believer',
#   'Atsushi Sakurai',
#   'ESPN',
#   'Kevin Durant',
#   'Tom Cruise',
#   'Precinct Finder',
#   'Ahn Bo-hyun',
#   'Cruel Summer Taylor Swift'],
#  'italy': ['Terremoto oggi',
#   'NBA',
#   'Vittorio Sgarbi',
#   'Europa League',
#   'Rovigo',
#   'Papa Francesco celibato',
#   'Douglas Costa',
#   'Geolier',
#   'Youtuber arrestato',
#   'Matteo Bocelli',
#   'Warriors  Suns',
#   'Renato Zero',
#   'Isabella Ferrari malattia',
#   'Tony Hawk',
#   'Ducati Motocross',
#   'Atto di fede',
#   'Claps',
#   'Erdogan',
#   'Lens-PSV',
#   'David LaChapelle'],
#  'vietnam': ['Al-Nassr đấu với Al-Duhail',
#   'Miss Grand International 2023',
#   'Real Madrid',
#   'Hải Phòng đấu với Sabah',
#   'NBA',
#   'Biệt dược đen tập 23',
#   'Arsenal vs',
#   'Inter',
#   'PSG',
#   'Xổ số miền Nam ngày 25 tháng 10',
#   'Đào Ngọc Dung',
#   'Newcastle',
#   'Làng Cù Lần',
#   'Napoli vs',
#   'Benfica',
#   'CR-V 2024',
#   'Record Of Ragnarok',
#   'Lazio',
#   'Biển Đông',
#   'Real madrid vs'],
#  'egypt': ['محمد سلام',
#   'الترجي',
#   'الوداد',
#   'باريس سان جيرمان',
#   'Sports',
#   'التوقيت الشتوي في مصر',
#   'احمد فرحات',
#   'حلمي بكر',
#   'مباريات دوري أبطال أوروبا',
#   'الاهلي',
#   'مباراة الاهلي',
#   'مانشستر يونايتد',
#   'ارسنال',
#   'بايرن ميونخ',
#   'REAL MADRID',
#   'الريال',
#   'بدرية طلبة',
#   'نابولي',
#   'جيسون ستاثام',
#   'انتر ميلان'],
#  'argentina': ['Mariana Moyano periodista',
#   'Colon',
#   'Warriors',
#   'UCR',
#   'Corte de luz',
#   'Violencia de genero',
#   '25 de octubre',
#   'Cristian Castro',
#   'Newcastle',
#   'Sigali',
#   'Murio Ricardo Iorio',
#   'Martin jauregui',
#   'Santoro',
#   'Unión  Defensa y Justicia',
#   'Real Madrid',
#   'Instituto',
#   'Bayern',
#   'Barracas Central  Gimnasia',
#   'Rosario Central',
#   'Argentinos jrs. . Huracán'],
#  'poland': ['Liga Mistrzów',
#   'Sonia Bohosiewicz',
#   'Krzysztof Sobolewski',
#   'NBA',
#   'Dzień Kundelka',
#   'Barbara Stesłowicz',
#   'Marek Sowa',
#   'PSG',
#   'Philipp Plein',
#   'Ursula von der Leyen',
#   'Liga Mistrzów uefa',
#   'Newcastle',
#   'Ucl',
#   'Lech Poznań – Jagiellonia Białystok',
#   'Galatasaray – Bayern',
#   'Wanda Półtawska',
#   'Union Berlin – Napoli',
#   'Manchester United',
#   'Bitcoin',
#   'Wakacje kredytowe'],
#  'colombia': ['Miss Grand International 2023',
#   'Feyenoord',
#   'Victoria Secret',
#   'Ley seca elecciones',
#   'Newcastle',
#   'Galatasaray Bayern',
#   'Kings League',
#   'Real Madrid',
#   'Champions',
#   'Deportivo Cali  Jaguares',
#   'Galatasaray  Bayern',
#   'Al Nassr',
#   'Paro de taxistas Bogotá',
#   'Champions hoy',
#   'Sevilla  Arsenal',
#   'Aguilas Doradas',
#   'Manchester United',
#   'Marilyn Patiño',
#   'Boca Juniors',
#   'NBA'],
#  'ukraine': ['Лига чемпионов',
#   'Славута',
#   'Ліга чемпіонів',
#   'Ворскла – Днепр-1',
#   'Ворскла – Дніпро-1',
#   'Бенфіка – Реал Сосьєдад',
#   '26 жовтня - свято',
#   'Аль-Наср',
#   '25 жовтня',
#   'Шепетівка',
#   'Севілья – Арсенал',
#   'Гепатит А',
#   'Шарий',
#   'Манчестер Юнайтед – Копенгаген',
#   'Галатасарай – Бавария',
#   'Брага – Реал Мадрид',
#   '24 жовтня свято',
#   'Марино Пушич',
#   'Гепатита',
#   'Орбан'],
#  'saudi_arabia': ['محمد سلام',
#   'فاطمة المؤمن',
#   'باريس سان جيرمان',
#   'ايلون ماسك',
#   'سعر الدولار اليوم في مصر',
#   'هونغ كونغ',
#   'نابولي',
#   'دي بروين',
#   "Five Nights at Freddy's",
#   'النصر',
#   'ريال مدريد',
#   'الاهلي',
#   'نادي النصر',
#   'مانشستر يونايتد',
#   'Champions League',
#   'جيسون ستاثام',
#   'بايرن ميونخ',
#   'ارسنال',
#   'محمد بن سلمان',
#   'REAL MADRID'],
#  'kenya': ['UEFA',
#   'PSG vs Milan',
#   'Live Score',
#   'Celtic vs Atletico Madrid',
#   'Newcastle vs Dortmund prediction',
#   'NBA',
#   'Feyenoord vs Lazio',
#   'Barcelona vs Shakhtar Donetsk',
#   'Richard Roundtree',
#   'Nuggets vs Lakers',
#   'Newcastle',
#   'Warriors vs Suns',
#   'African Football League',
#   'Real Madrid cf',
#   'DStv',
#   'Norwich City',
#   'Millwall',
#   'Man United vs Copenhagen',
#   'Sevilla vs Arsenal',
#   'UEFA Champions League'],
#  'chile': ['Casa de Moneda',
#   'Warriors  Suns',
#   'Resiliencia',
#   'Inter',
#   'Real Madrid',
#   'Twitter',
#   'Nicolás Jarry',
#   'Galatasaray  Bayern',
#   'Ina',
#   'Sevilla  Arsenal',
#   'Boca',
#   'Manchester United',
#   'Al Nassr',
#   'NBA',
#   'Atsushi Sakurai',
#   'UEFA Champions League',
#   'Lakers',
#   'Tomas Barrios',
#   'JUNJI',
#   'Periodista Miguel Acuña Canal 13'],
#  'romania': ['Real Madrid',
#   'NBA',
#   'NOUA LEGE A SALARIZARII',
#   'Sfântul Dumitru',
#   'PSG',
#   'CSA Steaua',
#   'Cupa romaniei',
#   'Cutremur romania',
#   'Europa League',
#   'Charlie Ottley',
#   'Kurt Cobain',
#   'UEFA',
#   'UCL',
#   'Braga  Real Madrid',
#   'Via Transilvanica',
#   'Arsenal',
#   'ASF',
#   'Bitcoin',
#   'FC arges',
#   'Ozempic'],
#  'south_africa': ['Champions League',
#   'Australia vs Netherlands',
#   'UEFA',
#   'Gold Reef City',
#   'NBA',
#   'Newcastle vs Dortmund',
#   'Newcastle',
#   'Nuggets vs Lakers',
#   'Atletico Madrid',
#   'Richard Roundtree',
#   'Barcelona vs Shakhtar Donetsk',
#   'FC Barcelona',
#   'Taylor Swift South Africa',
#   'Leeds United',
#   'RB Leipzig',
#   'Portsmouth FC',
#   'Man United vs Copenhagen',
#   'South Africa vs Bangladesh',
#   'Sevilla vs Arsenal',
#   'Sundowns'],
#  'belgium': ['Tour de France 2024',
#   'Vincent Van Quickenborne',
#   'Europa League',
#   'Richard Roundtree',
#   'David Holmes',
#   'Massive Attack',
#   'Guterres',
#   'Man utd',
#   'Maggie Smith',
#   'Feyenoord',
#   'Fed',
#   'Conference League',
#   'Acapulco',
#   'Worldline',
#   'Dune',
#   'Macron',
#   'Galatasaray',
#   'Real Madrid',
#   'Arsenal',
#   'Manchester United'],
#  'sweden': ['Strömavbrott Stockholm',
#   'Johanna Jansson',
#   'NBA',
#   'Richard Roundtree',
#   'Anders jansson skådespelare',
#   'Manchester United',
#   'Real Madrid',
#   'Arsenal',
#   'Björn Hellkvist',
#   'Galatasaray mot Bayern',
#   'Galatasaray',
#   'Putin',
#   'Peg Parnevik',
#   'Europa League',
#   'Bayern munchen',
#   'Utsikten',
#   'Return to Moria',
#   'Thomas Di Leva',
#   'Pär Holmgren',
#   'Förbifart Stockholm'],
#  'austria': ['Zeitumstellung 2023',
#   'NBA',
#   'Nationalfeiertag',
#   'Richard Roundtree',
#   'Handels KV-Verhandlungen',
#   'MV Agusta',
#   'Monfils',
#   'Flughafenfest Innsbruck',
#   'Clemens Stammler',
#   'Jason Statham',
#   'ServusTV',
#   'Microsoft-Aktie',
#   'Medvedev',
#   'Heldenplatz',
#   'Benfica',
#   'Alphabet-Aktie',
#   'Klanglicht',
#   'Acapulco',
#   'Hailey Bieber',
#   'Abnehmspritze'],
#  'switzerland': ['NBA',
#   'Guterres',
#   'Direct Mail Company',
#   'Richard Roundtree',
#   'Tour de France 2024',
#   'Fribourg gotteron',
#   'Acapulco',
#   'Til Schweiger',
#   'Europa League',
#   'Disparition Lina',
#   'Lens',
#   'Worldline',
#   'Generation Z',
#   'Microsoft-Aktie',
#   'Schwerer Verkehrsunfall',
#   'Alphabet-Aktie',
#   'Sony WH-1000XM4',
#   'Champions League',
#   'Galatasaray',
#   'Manchester City'],
#  'greece': ['Γραμματικακησ',
#   'NBA',
#   'Φωφη γεννηματα',
#   'Καρκινοσ του μαστου',
#   'ΤΖΟΚΕΡ 24/10 23',
#   'Προσληψεισ αναπληρωτων',
#   'Δριτσασ',
#   'Κωστασ χατζησ',
#   'ΜΑΡΙΑ ΙΩΑΝΝΙΔΟΥ',
#   'Μπενφικα',
#   'Σεφερησ',
#   'Τζωρτζίνα Λιώση',
#   'ΜΑΡΓΑΡΙΤΑ ΓΕΡΑΛΗ',
#   'Παγκοσμια ημερα ζυμαρικων',
#   'Μουσειο ακροπολησ',
#   'Γιουλικα σκαφιδα',
#   'Γκουτερεσ',
#   'Βασιλισσησ ολγασ',
#   'Champions League',
#   'Μαρινα σαττι'],
#  'denmark': ['Madonna',
#   'Tour de France 2024',
#   'Richard Roundtree',
#   'NBA',
#   'Bobby Charlton',
#   'Galatasaray',
#   'Real Madrid',
#   'DSV',
#   'Arsenal',
#   'Verity',
#   'Bitcoin',
#   'Sam Smith',
#   'Al Nassr',
#   'Kelly McGillis today',
#   'Putin',
#   'UEFA Champions League',
#   'Cl',
#   'Cities: Skylines 2',
#   'SKIMS',
#   'The line'],
#  'norway': ['Thorbjørn Jagland',
#   'NBA',
#   'Manchester City',
#   'David Holmes',
#   'Richard Roundtree',
#   'Champions League',
#   'Manchester United',
#   'Arsenal',
#   'FN',
#   'Bitcoin',
#   'Tons of Rock 2024',
#   'Helgoland',
#   'Real Madrid',
#   'Raymond Johansen',
#   'Anne-Cath. Vestly',
#   'Putin',
#   'UEFA Champions League',
#   'Tom Emmer',
#   'Emilie Enger Mehl',
#   'Sound of Freedom'],
#  'nigeria': ['Barcelona vs Shakhtar Donetsk',
#   'PSG',
#   'Isaac Oyedepo',
#   'NBA',
#   'Newcastle vs Dortmund prediction',
#   'Celtic vs Atletico Madrid',
#   'Naira Marley',
#   'Newcastle',
#   'Warriors vs Suns',
#   'Nuggets vs Lakers',
#   'Richard Roundtree',
#   'Championship',
#   'Europa league',
#   'Sevilla vs Arsenal',
#   'LiveScore',
#   'Braga vs Real Madrid',
#   'Galatasaray vs Bayern',
#   'Union Berlin vs Napoli',
#   'Inter Milan',
#   'Al Nassr'],
#  'new zealand': ['NBA',
#   'Australia vs Netherlands',
#   'Arsenal',
#   'Nuggets vs Lakers',
#   'UEFA Champions League',
#   'Vanuatu Cyclone',
#   'Interest rates NZ',
#   'Warriors vs Suns',
#   'Al Nassr',
#   'Real Madrid',
#   'Richard Roundtree',
#   'Britney Spears book',
#   'Champions League',
#   'South Africa vs Bangladesh',
#   'Cyclone Lola',
#   'Tottenham',
#   'Ligar Bay',
#   'Putin',
#   'Bitcoin',
#   'Cerebral palsy'],
#  'ireland': ['Dave Courtney',
#   'NBA',
#   'Australia vs Netherlands',
#   'Championship',
#   'Richard Roundtree',
#   'Celtic',
#   'John Gotti',
#   'Steve Baker',
#   'Tony Hawk',
#   'Man utd',
#   'Champions League',
#   'Arsenal',
#   'Bill Kenwright',
#   'Putin',
#   'Bayern Munich',
#   'Britney Spears book',
#   'Real Madrid',
#   'Bitcoin price',
#   'Wix',
#   'South Africa vs Bangladesh'],
#  'czech_republic': ['Al Nassr',
#   'Ozempic',
#   'NBA',
#   'Robert Fico',
#   'Evropská liga',
#   'Liga mistrů',
#   'Bitcoin',
#   'Tomáš Fejfar',
#   'Radar',
#   'Real madrid',
#   'Manchester United',
#   'BTC',
#   'Putin',
#   'Monika Žídková',
#   'Arsenal',
#   'Daniela Písařovicová',
#   'Massive Attack',
#   'VW',
#   'Reflux',
#   'Max Verstappen'],
#  'portugal': ['Champions',
#   'NBA',
#   'Yolanda Tati',
#   'Dalila Carmo',
#   'Tony Hawk',
#   'PSG',
#   'Richard Roundtree',
#   'Drake',
#   'Manchester City',
#   'Furacao Otis mexico',
#   'Notícias de Coimbra',
#   'Championship',
#   'Sorteio Taça de Portugal',
#   'Al Nassr',
#   'Sara Carreira',
#   'Porto',
#   'Prime Video',
#   'Guterres',
#   'Universidade de Coimbra',
#   'Jude Bellingham'],
#  'mexico': ['Feyenoord - Lazio',
#   'Manchester City',
#   '25 de octubre',
#   'Integra',
#   'PSG',
#   'Newcastle',
#   'Carlos Urzúa AMLO',
#   'Golden State Warriors',
#   'Amnistía',
#   'Monterrey vs Tijuana',
#   'James Rodríguez',
#   'Real Madrid',
#   'Al-Nassr',
#   'Galatasaray  Bayern',
#   'Sevilla  Arsenal',
#   'Feyenoord',
#   'NBA',
#   'Lens - PSV',
#   'Manchester United',
#   'Lakers'],
#  'malaysia': ['Sevilla vs Arsenal',
#   'Australia vs Netherlands',
#   'Braga vs Real Madrid',
#   'Galatasaray vs Bayern',
#   'NBA',
#   'French Open 2023',
#   'Inter vs RB Salzburg',
#   'Mu',
#   'Ed Sheeran',
#   'Nuggets vs Lakers',
#   'Champions League results',
#   'Yair Netanyahu',
#   'Thalapathy Vijay',
#   'Warriors vs Suns',
#   'Union Berlin vs Napoli',
#   'Actor Vinayakan',
#   'Man United vs Copenhagen',
#   'Champions League',
#   'South Africa vs Bangladesh',
#   'AFC Champions League'],
#  'hungary': ['Császár Zsolt',
#   'Ádám Zoltán Corvinus',
#   'NBA',
#   'Richard Roundtree',
#   'Donáth Anna',
#   'Barcelona–sahtar',
#   'Szijjártó Péter',
#   'LENS PSV',
#   'Union Berlin',
#   'Kormányinfó',
#   'Braga–real Madrid',
#   'Galatasaray–Bayern München',
#   'Bajnokok Ligája',
#   'Manchester United',
#   'Braga',
#   'Inter',
#   'Szilágyi Liliána',
#   'Radar',
#   'Bitcoin',
#   'Dwayne Johnson'],
#  'russia': ['25 октября праздник',
#   'Манчестер Юнайтед',
#   'Анфиса Резцова',
#   'День таможенника',
#   'Пенсии неработающим пенсионерам',
#   'День спецназа',
#   'Лига чемпионов',
#   'Брага – Реал Мадрид',
#   'Галатасарай – Бавария',
#   'Севилья – Арсенал',
#   'Лукойла Владимир Некрасов',
#   'Шри-Ланка',
#   'Анатолий Шарий',
#   'Функциональная грамотность',
#   'Биткоин',
#   'Дядя Слава',
#   'Закон о тишине',
#   'Евгений Сатановский',
#   'Крылья Советов',
#   'Спартак'],
#  'thailand': ['ธี่หยดเรื่องย่อ',
#   'บุรีรัมย์ ยูไนเต็ด พบ เมลเบิร์น ซิตี้',
#   'เรอัลมาดริด',
#   'Miss Grand International 2023',
#   'แมนซิตี้',
#   'NBA',
#   'พิธาลิ้มเจริญรัตน์',
#   'พันท้ายนรสิงห์',
#   'OPPO Find N3',
#   'สเปอร์ส',
#   'ยูฟ่า',
#   'บาเยิร์น',
#   'เลสเตอร์ซิตี้',
#   'เบนซ์เรซซิ่ง',
#   'เอเอฟซี',
#   'ชาดาไทยเศรษฐ์',
#   'Ucl',
#   'วันหยุดปีใหม่ 2567',
#   'วัดแขก',
#   'แขก คําผกา'],
#  'brazil': ['Liga dos Campeões',
#   'Barcelona',
#   'Barcelona x Shakhtar Donetsk',
#   'Furacao Otis',
#   'Internet banking',
#   'WEGE3',
#   'Celtic',
#   'AGRO3',
#   'Corinthians hoje',
#   'Atletico de Madrid',
#   'Gustavo Mioto',
#   'Cruzeiro x Bahia',
#   'O Lado Bom de Ser traida',
#   'Maquiagem de Halloween',
#   'Frei Galvão',
#   'NBA',
#   'Local de prova Enem',
#   'Al-Nassr',
#   'Manchester United',
#   'Arsenal'],
#  'france': ['NBA',
#   'Acapulco',
#   'Rappel lait',
#   'Maggie Smith',
#   'Mamadou Sakho',
#   'Richard Roundtree',
#   'Worldline',
#   'Rania de Jordanie',
#   'Voiture électrique leasing social',
#   'Ligue Europa',
#   'Questionnaire harcelement scolaire CE2',
#   'Massive Attack',
#   'Lens PSV',
#   'Harry Potter',
#   'Braga – Real Madrid',
#   'Hellfest',
#   'Macron',
#   'Galatasaray',
#   'Contrôle technique motos',
#   'Albert Dupontel'],
#  'united_kingdom': ['NBA',
#   'Australia vs Netherlands',
#   'Richard Roundtree',
#   'Arnold Schwarzenegger',
#   "Five Nights at Freddy's movie",
#   "Five Nights at Freddy's",
#   'Wrexham',
#   'Huddersfield Town',
#   'Reading FC',
#   'Man utd',
#   'Bill Kenwright',
#   'Arsenal',
#   'Bayern Munich',
#   'Real Madrid',
#   'South Africa vs Bangladesh',
#   'Britney Spears book',
#   'Leicester City',
#   'Massive Attack',
#   'Leicester City vs Sunderland',
#   'Bitcoin price'],
#  'finland': ['Real Madrid',
#   'Sevilla – Arsenal',
#   'Oppenheimer',
#   'Defender',
#   'NBA',
#   'Australia vs Netherlands',
#   'Al Nassr',
#   'OnePlus Open',
#   'Richard Roundtree',
#   'UEFA Champions League',
#   'Champions League',
#   'Newnew Polar Bear',
#   'Putin',
#   'Justin Timberlake',
#   'Bitcoin',
#   'Tottenham',
#   'UPM',
#   'Cities: Skylines 2',
#   'Blinding lights',
#   'Galatasaray']}

# %%
countries = data.keys()
countries
# Out:
# dict_keys(['united_states', 'india', 'japan', 'singapore', 'israel', 'australia', 'hong_kong', 'taiwan', 'canada', 'germany', 'netherlands', 'indonesia', 'south_korea', 'turkey', 'philippines', 'italy', 'vietnam', 'egypt', 'argentina', 'poland', 'colombia', 'ukraine', 'saudi_arabia', 'kenya', 'chile', 'romania', 'south_africa', 'belgium', 'sweden', 'austria', 'switzerland', 'greece', 'denmark', 'norway', 'nigeria', 'new zealand', 'ireland', 'czech_republic', 'portugal', 'mexico', 'malaysia', 'hungary', 'russia', 'thailand', 'brazil', 'france', 'united_kingdom', 'finland'])

# %%
vietnam = data.get('vietnam', [])
vietnam
# Out:
# ['Al-Nassr đấu với Al-Duhail',
#  'Miss Grand International 2023',
#  'Real Madrid',
#  'Hải Phòng đấu với Sabah',
#  'NBA',
#  'Biệt dược đen tập 23',
#  'Arsenal vs',
#  'Inter',
#  'PSG',
#  'Xổ số miền Nam ngày 25 tháng 10',
#  'Đào Ngọc Dung',
#  'Newcastle',
#  'Làng Cù Lần',
#  'Napoli vs',
#  'Benfica',
#  'CR-V 2024',
#  'Record Of Ragnarok',
#  'Lazio',
#  'Biển Đông',
#  'Real madrid vs']
