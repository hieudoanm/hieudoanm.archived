# %%
import pandas as pd
import requests

# %%
response = requests.get("https://trends.google.com/trends/hottrends/visualize/internal/data")
data = response.json()
data : dict

# %%
countries_data_frame = pd.DataFrame(data=data)
countries_data_frame
# Out:
#                       united_states                        india        japan  \
# 0                 Leonard Bernstein                    Aquaman 2   Twitter不具合
# 1              Winter solstice 2023             Inox Share Price  影の実力者になりたくて
# 2                           Celtics              CAT Result 2023   有馬記念 枠順抽選会
# 3               Barcelona - Almería                Narendra Modi       十角館の殺人
# 4                   Survivor finale                    Liverpool        スペーシア
# 5                   Duke basketball                     COVID-19         ダイハツ
# 6                      Timberwolves               Justin Trudeau   ユニクロ マリメッコ
# 7                    UNC basketball                 Twitter down         宮野真守
# 8                             Bulls                      Maestro         藤あや子
# 9                      Jayson Tatum  Dunki Box Office Collection    アイスランド 噴火
# 10  Action News' helicopter crashes                        Dunki     近鉄橿原線 事故
# ...

# %%
selected_countries = countries_data_frame[['australia', 'singapore', 'united_states', 'vietnam']]
selected_countries
# Out:
#                 australia                     singapore  \
# 0   Liverpool vs West Ham         Liverpool vs West Ham
# 1             Parkerville                         Dunki
# 2               Gravy Day                  Liverpool FC
# 3            Twitter down               Is Twitter down
# 4                   Dunki                       Maestro
# 5            Liverpool FC           Teppan Kappou Kenji
# 6           Bayern Munich          Pasir Ris West Plaza
# 7                   Trump                       Chelsea
# 8            Franco Cozzo                           COE
# 9           Percy Jackson                 Percy Jackson
# 10      Leonard Bernstein                     Ja Morant
# 11                Chelsea  Aquaman And The Lost Kingdom
# 12     Antoinette Lattouf                         Trump
# 13        Perth Scorchers            Singapore Covid-19
# 14            Mary Fowler                           MOE
# 15     The Bachelors 2023                       Toshiba
# ...
