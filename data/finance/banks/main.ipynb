# %%
import pandas as pd

# %%
institutions_dataframe = pd.read_csv("./data.csv")
institutions_dataframe = institutions_dataframe.sort_values(by = ["type", "country"])
institutions_dataframe.to_csv("./data.csv", index=False)
institutions_dataframe
# Out:
#                type         country  \
# 0              Bank       Australia
# 1              Bank       Australia
# 2              Bank       Australia
# 3              Bank       Australia
# 4              Bank         Vietnam
# 5              Bank         Vietnam
# 6              Bank         Vietnam
# 7              Bank         Vietnam
# 8              Bank         Vietnam
# 9              Bank         Vietnam
# 10             Bank         Vietnam
# 11             Bank         Vietnam
# 12             Bank         Vietnam
# 13             Bank         Vietnam
# 14             Bank         Vietnam
# 15             Bank         Vietnam
# 16             Bank         Vietnam
# 17             Bank         Vietnam
# 18             Bank         Vietnam
# 19             Bank         Vietnam
# 20             Bank         Vietnam
# 21             Bank         Vietnam
# 22             Bank         Vietnam
# 23             Bank         Vietnam
# 24             Bank         Vietnam
# ...
