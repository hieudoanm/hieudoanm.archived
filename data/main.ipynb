# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame
# Out:
# 157
#                                              file_path  num_lines
# 0                ./technology/github/emojis/emojis.csv       1878
# 1       ./oracle-of-bacon/data/links/800000-900000.csv     100001
# 2      ./oracle-of-bacon/data/links/900000-1000000.csv     100001
# 3       ./oracle-of-bacon/data/links/700000-800000.csv     100001
# 4       ./oracle-of-bacon/data/links/500000-600000.csv     100001
# 5            ./oracle-of-bacon/data/links/0-100000.csv     100001
# 6       ./oracle-of-bacon/data/links/100000-200000.csv     100001
# 7       ./oracle-of-bacon/data/links/600000-700000.csv     100001
# 8       ./oracle-of-bacon/data/links/400000-500000.csv     100001
# 9    ./oracle-of-bacon/data/links/900000-1000000-cu...       1317
# 10      ./oracle-of-bacon/data/links/300000-400000.csv     100001
# 11      ./oracle-of-bacon/data/links/200000-300000.csv     100001
# 12              ./education/universities/countries.csv        206
# 13            ./education/universities/universites.csv       9950
# 14     ./education/universities/rankings/csv/times.csv       2346
# 15        ./education/universities/rankings/csv/qs.csv       1499
# 16   ./education/universities/rankings/csv/shanghai...       1001
# 17   ./education/coursera/python-statistics-financi...        507
# 18   ./education/coursera/python-statistics-financi...        781
# 19   ./education/coursera/python-statistics-financi...       2833
# 20   ./education/coursera/python-statistics-financi...       2058
# 21   ./education/coursera/python-statistics-financi...        809
# 22   ./education/coursera/python-statistics-financi...        781
# 23   ./education/coursera/python-statistics-financi...       2630
# 24   ./education/coursera/python-statistics-financi...       2690
# 25   ./education/coursera/python-statistics-financi...       2680
# 26   ./education/coursera/python-statistics-financi...       2705
# 27   ./education/coursera/python-statistics-financi...       2680
# 28   ./education/coursera/python-statistics-financi...       2680
# 29   ./education/coursera/python-statistics-financi...       2678
# 30   ./education/coursera/python-statistics-financi...       2680
# 31   ./education/coursera/python-statistics-financi...       2623
# 32   ./education/coursera/python-statistics-financi...       2721
# 33                                     ./world/all.csv        251
# 34             ./world/organizations/organizations.csv        337
# 35   ./world/regions/oceania/australia/postal-code.csv      16884
# 36   ./world/regions/oceania/australia/family-and-d...       3199
# 37   ./world/regions/oceania/australia/family-and-d...       3010
# 38   ./world/regions/oceania/australia/family-and-d...       2099
# 39   ./world/regions/oceania/australia/family-and-d...       3174
# 40   ./world/regions/oceania/australia/family-and-d...       3189
# 41   ./world/regions/oceania/australia/family-and-d...       1642
# 42   ./world/regions/oceania/australia/family-and-d...       3116
# 43   ./world/regions/oceania/australia/family-and-d...       3256
# 44   ./world/regions/oceania/australia/family-and-d...       3206
# 96                     ./world/timezones/timezones.csv        351
# 97                    ./world/timezones/timezones2.csv        419
# 98                    ./world/timezones/timezones3.csv        419
# 99                             ./world/visas/visas.csv      27670
# 100                          ./world/cities/cities.csv        340
# 101                             ./world/cities/all.csv     209580
# 102                          ./world/states/states.csv        242
# 103                 ./world/independence-days/data.csv        184
# 104                  ./world/independence-days/raw.csv        184
# 105                    ./world/countries/countries.csv        256
# 106                ./world/countries/restcountries.csv        251
# 107                          ./world/countries/all.csv        251
# 108           ./sports/american-football/champions.csv        260
# 109                           ./sports/clubs/clubs.csv        102
# 110                 ./sports/football/competitions.csv        166
# 111                        ./sports/football/teams.csv       5001
# 112                   ./sports/football/favourites.csv         32
# 113            ./sports/football/full/competitions.csv        175
# 114                   ./sports/football/full/teams.csv         21
# 115                 ./sports/football/full/matches.csv         39
# 116             ./sports/football/clubs/cup/finals.csv        460
# 117  ./sports/football/clubs/league/top-goalkeepers...         22
# 118  ./sports/football/clubs/league/standings/datas...        621
# 119  ./sports/football/clubs/league/top-scorers/dat...        339
# 120  ./sports/football/clubs/league/teams-of-the-se...        331
# 121                ./sports/football/fifa/rankings.csv        208
# 122        ./sports/football/international/players.csv         37
# 123      ./sports/football/international/champions.csv        120
# 124        ./sports/futsal/international/champions.csv         81
# 125  ./sports/chess/fide.com/competitions/champions...        238
# 126           ./sports/chess/fide.com/2800/players.csv         15
# 127   ./sports/chess/lichess.org/openings/openings.csv       3415
# 128                      ./sports/tennis/champions.csv        351
# 129                   ./languages/words/characters.csv         38
# 130                      ./languages/quotes/quotes.csv       2278
# 131     ./languages/text-classification/input/test.csv       3700
# 132    ./languages/text-classification/input/train.csv       8562
# 133  ./languages/text-classification/input/sample_s...       3264
# 134  ./languages/text-classification/output/submiss...       3264
# 135                     ./languages/languages/full.csv        548
# 136                ./languages/languages/languages.csv        172
# 137                       ./languages/news/sources.csv        129
# 138                        ./languages/tarot/cards.csv        100
# 139             ./languages/1000-most-common/words.csv       1000
# 140         ./languages/1000-most-common/languages.csv     103887
# 141                         ./finance/crypto/coins.csv        501
# 142                ./finance/currencies/currencies.csv        162
# 143                    ./finance/forex/csv/history.csv       8884
# 144                      ./finance/forex/csv/dates.csv       8884
# 145                 ./finance/forex/csv/currencies.csv        163
# 146       ./finance/stock/vnindex/vps/data/history.csv    4021643
# 147     ./finance/stock/vnindex/vps/data/companies.csv       2309
# 148    ./finance/stock/vnindex/vps/data/industries.csv        178
# 149  ./finance/stock/vnindex/dragon-capital/history...       1901
# 150  ./machine-learning/supervised/house-price-pred...       9359
# 151  ./machine-learning/supervised/employee-retenti...      15000
# 152  ./machine-learning/supervised/length-conversio...         29
# 153                ./games/pokemon/data/type-chart.csv         19
# 154                   ./games/pokemon/data/combats.csv       1272
# 155                   ./games/pokemon/data/pokemon.csv       1272
# 156                      ./games/esports/champions.csv         59
