# %% [markdown]
# # Top 100

# %%
from IPython.display import HTML
from functools import reduce
import json
import pandas

# %%
qs_rankings_data_frame = pandas.read_csv("./csv/qs.csv")
shanghai_rankings_data_frame = pandas.read_csv("./csv/shanghai.csv")
times_rankings_data_frame = pandas.read_csv("./csv/times.csv")

# %%
top_100_qs_rankings_data_frame : pandas.DataFrame = qs_rankings_data_frame.head(100)
top_100_qs_rankings_data_frame.to_csv("./csv/top-100-qs.csv", index=False)
top_100_qs_universities : list[str] = top_100_qs_rankings_data_frame['university'].unique()
top_100_qs_countries : list[str] = top_100_qs_rankings_data_frame['country'].unique()
top_100_qs_rankings_data_frame
# Out:
#                                      university         country  rank_qs
# 0         Massachusetts Institute of Technology   United States      1.0
# 1                       University of Cambridge  United Kingdom      2.0
# 2                          University of Oxford  United Kingdom      3.0
# 3                            Harvard University   United States      4.0
# 4                           Stanford University   United States      5.0
# ..                                          ...             ...      ...
# 95                     University of St Andrews  United Kingdom     96.0
# 96              Georgia Institute of Technology   United States     97.0
# 97                    Freie Universitaet Berlin         Germany     98.0
# 98           Purdue University - West Lafayette   United States     99.0
# 99  Pohang University of Science and Technology     South Korea    100.0
#
# [100 rows x 3 columns]

# %%
top_100_shanghai_rankings_data_frame : pandas.DataFrame = shanghai_rankings_data_frame.head(100)
top_100_shanghai_rankings_data_frame.to_csv("./csv/top-100-shanghai.csv", index=False)
top_100_shanghai_universities : list[str] = top_100_shanghai_rankings_data_frame['university'].unique()
top_100_shanghai_countries : list[str] = top_100_shanghai_rankings_data_frame['country'].unique()
top_100_shanghai_rankings_data_frame
# Out:
#                                        university         country  \
# 0                              Harvard University   United States
# 1                             Stanford University   United States
# 2           Massachusetts Institute of Technology   United States
# 3                         University of Cambridge  United Kingdom
# 4              University of California, Berkeley   United States
# ..                                            ...             ...
# 95  Huazhong University of Science and Technology           China
# 96                        University of Hong Kong       Hong Kong
# 97                      Seoul National University     South Korea
# 98                               Brown University   United States
# 99                University of Western Australia       Australia
#
#     rank_shanghai
# 0             1.0
# 1             2.0
# 2             3.0
# 3             4.0
# 4             5.0
# ..            ...
# 95           96.0
# ...

# %%
top_100_times_rankings_data_frame : pandas.DataFrame = times_rankings_data_frame.head(100)
top_100_times_rankings_data_frame.to_csv("./csv/top-100-times.csv", index=False)
top_100_times_universities : list[str] = top_100_times_rankings_data_frame['university'].unique()
top_100_times_countries : list[str] = top_100_times_rankings_data_frame['country'].unique()
top_100_times_rankings_data_frame
# Out:
#                                university         country  rank_times
# 0                    University of Oxford  United Kingdom           1
# 1                      Harvard University   United States           2
# 2                 University of Cambridge  United Kingdom           3
# 3                     Stanford University   United States           4
# 4   Massachusetts Institute of Technology   United States           5
# ..                                    ...             ...         ...
# 95        Institut Polytechnique de Paris          France          96
# 96                     Nanjing University           China          97
# 97                  Vanderbilt University   United States          98
# 98           City University of Hong Kong       Hong Kong          99
# 99                 RWTH Aachen University         Germany         100
#
# [100 rows x 3 columns]

# %%
# -*- coding: utf-8 -*-

top_100_universities : list[str] = list(
    set([
        *top_100_qs_universities, 
        *top_100_shanghai_universities,
        *top_100_times_universities
    ])
)
top_100_universities.sort()
# Write to File
top_100_universities_file = open('./json/top-100-universities.json', 'w', encoding="utf-8")
json.dump(top_100_universities, top_100_universities_file, indent=2, ensure_ascii=False)
top_100_universities_file.close()

len(top_100_universities)
# Out:
# 150

# %%
# -*- coding: utf-8 -*-

top_100_countries : list[str] = list(
    set([
        *top_100_times_countries,
        *top_100_shanghai_countries,
        *top_100_times_countries
    ])
)
top_100_countries.sort()
# Write to File
top_100_countries_file = open('./json/top-100-countries.json', 'w', encoding="utf-8")
json.dump(top_100_countries, top_100_countries_file, indent=2, ensure_ascii=False)
top_100_countries_file.close()

len(top_100_countries)
# Out:
# 19

# %%
top_100_data_frames = [
    top_100_qs_rankings_data_frame,
    top_100_shanghai_rankings_data_frame,
    top_100_times_rankings_data_frame
]
on = ['university', 'country']
top_100_data_frame = reduce(lambda left, right: pandas.merge(left, right, on=on, how='outer'), top_100_data_frames)

top_100_data_frame.fillna(101, inplace=True)
top_100_data_frame['rank_average'] = round(top_100_data_frame[['rank_qs', 'rank_shanghai', 'rank_times']].mean(axis=1), 2)

sorted_top_100_data_frame = top_100_data_frame.sort_values('rank_average', ascending=True)
sorted_top_100_data_frame = sorted_top_100_data_frame.reset_index(drop=True)
sorted_top_100_data_frame.to_csv("./csv/top-100-all.csv", index=False)
sorted_top_100_data_frame
# Out:
#                                       university         country  rank_qs  \
# 0                             Harvard University   United States      4.0
# 1          Massachusetts Institute of Technology   United States      1.0
# 2                        University of Cambridge  United Kingdom      2.0
# 3                           University of Oxford  United Kingdom      3.0
# 4                            Stanford University   United States      5.0
# ..                                           ...             ...      ...
# 145                     University of St Andrews  United Kingdom     96.0
# 146                           Nanjing University           China    101.0
# 147                    Freie Universitaet Berlin         Germany     98.0
# 148  Pohang University of Science and Technology     South Korea    100.0
# 149                       RWTH Aachen University         Germany    101.0
#
#      rank_shanghai  rank_times  rank_average
# ...

# %%
filtered_top_100_data_frame : pandas.DataFrame = sorted_top_100_data_frame[
    (sorted_top_100_data_frame["rank_qs"] < 101) & 
    (sorted_top_100_data_frame["rank_shanghai"] < 101) & 
    (sorted_top_100_data_frame["rank_times"] < 101)
]
filtered_top_100_data_frame.to_csv("./csv/top-100-filtered.csv", index=False)
filtered_top_100_data_frame
# Out:
#                                            university         country  \
# 0                                  Harvard University   United States
# 1               Massachusetts Institute of Technology   United States
# 2                             University of Cambridge  United Kingdom
# 3                                University of Oxford  United Kingdom
# 4                                 Stanford University   United States
# 5                  University of California, Berkeley   United States
# 6                  California Institute of Technology   United States
# 7                                Princeton University   United States
# 8                               University of Chicago   United States
# 9                                     Yale University   United States
# 10                            Imperial College London  United Kingdom
# 11                                         ETH Zurich     Switzerland
# ...

# %%
sorted_filtered_top_100_data_frame = filtered_top_100_data_frame.sort_values(by=['country', 'rank_average'], ascending=True)
sorted_filtered_top_100_data_frame.to_csv("./csv/top-100-filtered-countries.csv", index=False)
sorted_filtered_top_100_data_frame
# Out:
#                                            university         country  \
# 21                            University of Melbourne       Australia
# 36                               University of Sydney       Australia
# 37                           University of Queensland       Australia
# 44                      University of New South Wales       Australia
# 48                                  Monash University       Australia
# 50                     Australian National University       Australia
# 60                                          KU Leuven         Belgium
# 17                              University of Toronto          Canada
# 32                     University of British Columbia          Canada
# 42                                  McGill University          Canada
# 19                                Tsinghua University           China
# 20                                  Peking University           China
# ...

# %%
filtered_out_top_100_data_frame : pandas.DataFrame = sorted_top_100_data_frame[
    (sorted_top_100_data_frame["rank_qs"] == 101) | (sorted_top_100_data_frame["rank_shanghai"] == 101) | (sorted_top_100_data_frame["rank_times"] == 101)
]
HTML(filtered_out_top_100_data_frame.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>university</th>
#       <th>country</th>
#       <th>rank_qs</th>
#       <th>rank_shanghai</th>
#       <th>rank_times</th>
#       <th>rank_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>École Polytechnique Fédérale de Lausanne</td>
#       <td>Switzerland</td>
#       <td>36.0</td>
#       <td>101.0</td>
#       <td>41.0</td>
#       <td>59.33</td>
#     </tr>
#     <tr>
#       <td>Carnegie Mellon University</td>
#       <td>United States</td>
#       <td>52.0</td>
#       <td>101.0</td>
#       <td>28.0</td>
#       <td>60.33</td>
#     </tr>
#     <tr>
#       <td>London School of Economics and Political Science</td>
#       <td>United Kingdom</td>
#       <td>45.0</td>
#       <td>101.0</td>
#       <td>37.0</td>
#       <td>61.00</td>
#     </tr>
#     <tr>
#       <td>Washington University in St. Louis</td>
#       <td>United States</td>
# ...
