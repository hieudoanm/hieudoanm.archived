# %%
import pandas as pd

# %%
organizations_data_frame = pd.read_csv("./organizations.csv")
organizations_data_frame = organizations_data_frame.sort_values(by=['organization_code', 'organization', 'accession', 'name'])
organizations_data_frame.to_csv('./organizations.csv', index=False)
organizations_data_frame
# Out:
#     organization_code                                      organization code  \
# 0                  AL                                       Arab League  DZA
# 1                  AL                                       Arab League  BHR
# 2                  AL                                       Arab League  COM
# 3                  AL                                       Arab League  DJI
# 4                  AL                                       Arab League  EGY
# ..                ...                                               ...  ...
# 331             SAARC  South Asian Association for Regional Cooperation  IND
# 332             SAARC  South Asian Association for Regional Cooperation  MDV
# 333             SAARC  South Asian Association for Regional Cooperation  NPL
# 334             SAARC  South Asian Association for Regional Cooperation  PAK
# 335             SAARC  South Asian Association for Regional Cooperation  LKA
#
#           name accession withdrawal
# ...
