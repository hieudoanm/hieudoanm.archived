# %%
import pandas

# %%
chiefs_data_frame = pandas.read_csv("./chiefs-of-staff.csv")
chiefs_data_frame
# Out:
#     no                name        party             president
# 0    1       John Steelman   Democratic        Harry S Truman
# 1    2       Sherman Adams   Republican  Dwight D. Eisenhower
# 2    3      Wilton Persons   Republican  Dwight D. Eisenhower
# 3    -   Kenneth O'Donnell   Democratic       John F. Kennedy
# 4    -       Marvin Watson   Democratic     Lyndon B. Johnson
# 5    -      James R. Jones   Democratic     Lyndon B. Johnson
# 6    4      H. R. Haldeman   Republican         Richard Nixon
# 7    5      Alexander Haig   Republican         Richard Nixon
# 8    6     Donald Rumsfeld   Republican           Gerald Ford
# 9    7         Dick Cheney   Republican           Gerald Ford
# 10   8     Hamilton Jordan   Democratic          Jimmy Carter
# 11   9         Jack Watson   Democratic          Jimmy Carter
# 12  10         James Baker   Republican         Ronald Reagan
# 13  11        Donald Regan   Republican         Ronald Reagan
# ...

# %%
parties = chiefs_data_frame['party'].value_counts()
parties
# Out:
# party
# Republican     17
# Democratic     16
# Independent     1
# Name: count, dtype: int64

# %%
presidents = chiefs_data_frame['president'].value_counts()
presidents
# Out:
# president
# Ronald Reagan           4
# Bill Clinton            4
# Barack Obama            4
# George H. W. Bush       3
# Donald Trump            3
# Dwight D. Eisenhower    2
# Lyndon B. Johnson       2
# Richard Nixon           2
# Gerald Ford             2
# Jimmy Carter            2
# George W. Bush          2
# Joe Biden               2
# Harry S Truman          1
# John F. Kennedy         1
# Name: count, dtype: int64
