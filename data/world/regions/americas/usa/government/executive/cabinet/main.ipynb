# %%
import pandas as pd

# %%
secretaries_data_frame = pd.read_csv("./secretaries.csv")
sorted_secretaries_data_frame = secretaries_data_frame.sort_values(by=["department_no", "department", "head_no"])
sorted_secretaries_data_frame['department_no'] = sorted_secretaries_data_frame['department_no'].astype(int)
sorted_secretaries_data_frame['head_no'] = sorted_secretaries_data_frame['head_no'].astype(int)
sorted_secretaries_data_frame.to_csv("./secretaries.csv", index=False)
sorted_secretaries_data_frame
# Out:
#      department_no                       department  \
# 0                0                  Federal Reserve
# 1                0                  Federal Reserve
# 2                0                  Federal Reserve
# 3                0                  Federal Reserve
# 4                0                  Federal Reserve
# ..             ...                              ...
# 601             15  Department of Homeland Security
# 602             15  Department of Homeland Security
# 603             15  Department of Homeland Security
# 604             15  Department of Homeland Security
# 605             15  Department of Homeland Security
#
#                                head  head_no                name        party  \
# 0      Chair of the Federal Reserve        1      Charles Hamlin          NaN
# 1      Chair of the Federal Reserve        2     William Harding          NaN
# 2      Chair of the Federal Reserve        3   Daniel Crissinger          NaN
# 3      Chair of the Federal Reserve        4           Roy Young          NaN
# 4      Chair of the Federal Reserve        5        Eugene Meyer          NaN
# ..                              ...      ...                 ...          ...
# 601  Secretary of Homeland Security        3    Janet Napolitano   Democratic
# 602  Secretary of Homeland Security        4         Jeh Johnson   Democratic
# 603  Secretary of Homeland Security        5       John F. Kelly  Independent
# 604  Secretary of Homeland Security        6    Kirstjen Nielsen   Republican
# 605  Secretary of Homeland Security        7  Alejandro Mayorkas   Democratic
#
#     state          president  start_date    end_date  birth_country
# 0     NaN     Woodrow Wilson  1914-08-10  1916-08-09            NaN
# 1     NaN     Woodrow Wilson  1916-08-10  1922-08-09            NaN
# 2     NaN  Warren G. Harding  1923-05-01  1927-09-15            NaN
# 3     NaN    Calvin Coolidge  1927-10-04  1930-08-31            NaN
# 4     NaN     Herbert Hoover  1930-09-16  1933-05-10            NaN
# ..    ...                ...         ...         ...            ...
# 601   NaN       Barack Obama         NaN         NaN  United States
# 602   NaN       Barack Obama         NaN         NaN  United States
# 603   NaN       Donald Trump         NaN         NaN  United States
# 604   NaN       Donald Trump         NaN         NaN  United States
# 605   NaN          Joe Biden         NaN         NaN           Cuba
#
# [606 rows x 11 columns]

# %% [markdown]
# ## Departments

# %%
department_data_frame = sorted_secretaries_data_frame[sorted_secretaries_data_frame["department_no"] != 0]
department_data_frame = department_data_frame[["department_no", "department", "head"]]
department_data_frame = department_data_frame.drop_duplicates(["department_no", "department", "head"])
department_data_frame
# Out:
#      department_no                                   department  \
# 80               1                          Department of State
# 151              2                   Department of the Treasury
# 229              3                        Department of Defense
# 257              4                        Department of Justice
# 343              5                   Department of the Interior
# 397              6                    Department of Agriculture
# 429              7                       Department of Commerce
# 469              8                          Department of Labor
# 498              9      Department of Health and Human Services
# 523             10  Department of Housing and Urban Development
# 541             11                 Department of Transportation
# 560             12                         Department of Energy
# 576             13                      Department of Education
# 588             14               Department of Veterans Affairs
# 599             15              Department of Homeland Security
#
#                                            head
# 80                           Secretary of State
# 151                   Secretary of the Treasury
# 229                        Secretary of Defense
# 257                            Attorney General
# 343                   Secretary of the Interior
# 397                    Secretary of Agriculture
# 429                       Secretary of Commerce
# 469                          Secretary of Labor
# 498      Secretary of Health and Human Services
# 523  Secretary of Housing and Urban Development
# 541                 Secretary of Transportation
# 560                         Secretary of Energy
# 576                      Secretary of Education
# 588               Secretary of Veterans Affairs
# 599              Secretary of Homeland Security

# %% [markdown]
# ## Secretaries of State

# %%
state_data_frame = sorted_secretaries_data_frame[sorted_secretaries_data_frame["department"] == "Department of State"]
state_data_frame
# Out:
#      department_no           department                head  head_no  \
# 80               1  Department of State  Secretary of State        1
# 81               1  Department of State  Secretary of State        2
# 82               1  Department of State  Secretary of State        3
# 83               1  Department of State  Secretary of State        4
# 84               1  Department of State  Secretary of State        5
# ..             ...                  ...                 ...      ...
# 146              1  Department of State  Secretary of State       67
# 147              1  Department of State  Secretary of State       68
# 148              1  Department of State  Secretary of State       69
# 149              1  Department of State  Secretary of State       70
# 150              1  Department of State  Secretary of State       71
#
#                   name                  party state          president  \
# 80    Thomas Jefferson  Democratic-Republican   NaN  George Washington
# 81     Edmund Randolph             Federalist   NaN  George Washington
# 82   Timothy Pickering             Federalist   NaN  George Washington
# 83       John Marshall             Federalist   NaN         John Adams
# 84       James Madison  Democratic-Republican   NaN   Thomas Jefferson
# ..                 ...                    ...   ...                ...
# 146    Hillary Clinton             Democratic   NaN       Barack Obama
# 147         John Kerry             Democratic   NaN       Barack Obama
# 148      Rex Tillerson             Republican   NaN       Donald Trump
# 149        Mike Pompeo             Republican   NaN       Donald Trump
# 150     Antony Blinken             Democratic   NaN          Joe Biden
#
#     start_date end_date  birth_country
# 80         NaN      NaN  United States
# 81         NaN      NaN  United States
# 82         NaN      NaN  United States
# 83         NaN      NaN  United States
# 84         NaN      NaN  United States
# ..         ...      ...            ...
# 146        NaN      NaN  United States
# 147        NaN      NaN  United States
# 148        NaN      NaN  United States
# 149        NaN      NaN  United States
# 150        NaN      NaN  United States
#
# [71 rows x 11 columns]

# %%
foreign_borned_state_data_frame = state_data_frame[state_data_frame["birth_country"] != "United States"]
foreign_borned_state_data_frame
# Out:
#      department_no           department                head  head_no  \
# 135              1  Department of State  Secretary of State       56
# 143              1  Department of State  Secretary of State       64
#
#                    name       party state      president start_date end_date  \
# 135     Henry Kissinger  Republican   NaN  Richard Nixon        NaN      NaN
# 143  Madeleine Albright  Democratic   NaN   Bill Clinton        NaN      NaN
#
#       birth_country
# 135         Germany
# 143  Czech Republic

# %%
len(foreign_borned_state_data_frame) / len(state_data_frame) * 100
# Out:
# 2.8169014084507045
