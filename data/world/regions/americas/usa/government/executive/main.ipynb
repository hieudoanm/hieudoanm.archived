# %%
import pandas as pd

# %%
individuals_data_frame = pd.read_csv("./individuals.csv")
individuals_data_frame = individuals_data_frame.sort_values(by=["branch_no", "department_no", "department", "head_no"])
individuals_data_frame['department_no'] = individuals_data_frame['department_no'].astype(int)
# individuals_data_frame['head_no'] = individuals_data_frame['head_no'].astype(int)
individuals_data_frame.to_csv("./individuals.csv", index=False)
individuals_data_frame
# Out:
#      branch_no        branch  department_no  \
# 0            1  legistrative              2
# 1            1  legistrative              2
# 2            1  legistrative              2
# 3            1  legistrative              2
# 4            1  legistrative              2
# 5            1  legistrative              2
# 6            1  legistrative              2
# 7            1  legistrative              2
# 8            1  legistrative              2
# 9            1  legistrative              2
# 10           1  legistrative              2
# 11           1  legistrative              2
# 12           1  legistrative              2
# 13           1  legistrative              2
# 14           1  legistrative              2
# 15           1  legistrative              2
# 16           1  legistrative              2
# 17           1  legistrative              2
# 18           1  legistrative              2
# 19           1  legistrative              2
# ...

# %% [markdown]
# ## Individuals

# %%
unique_individuals_data_frame = individuals_data_frame[["name", "head", "department"]]
unique_individuals_data_frame = unique_individuals_data_frame.drop_duplicates(["name", "head", "department"])
unique_individuals_data_frame = unique_individuals_data_frame.sort_values(by = ["name"])
unique_individuals_data_frame
# Out:
#                                  name  \
# 484               A. Mitchell Palmer
# 211                        Aaron Burr
# 878                        Abe Fortas
# 272                    Abel P. Upshur
# 679               Abraham A. Ribicoff
# 915                   Abraham Lincoln
# 231                 Adlai Stevenson I
# 253                           Al Gore
# 141                    Alan Greenspan
# 719                      Alan S. Boyd
# 243                 Alben W. Barkley
# 548                    Albert B. Fall
# 332                   Albert Gallatin
# 514                 Alberto Gonzales
# 783                Alejandro Mayorkas
# 699                         Alex Azar
# 673                  Alexander Acosta
# 523            Alexander H. H. Stuart
# 316                    Alexander Haig
# 182                    Alexander Haig
# 329                Alexander Hamilton
# 334               Alexander J. Dallas
# 623              Alexander Trowbridge
# 669                     Alexis Herman
# ...

# %% [markdown]
# ## Legistrative

# %% [markdown]
# ### Speakers of the House of Representatives

# %%
legistrative_data_frame = individuals_data_frame[individuals_data_frame["branch"] == 'legistrative']
legistrative_data_frame
# Out:
#      branch_no        branch  department_no                department  \
# 0            1  legistrative              2  House of Representatives
# 1            1  legistrative              2  House of Representatives
# 2            1  legistrative              2  House of Representatives
# 3            1  legistrative              2  House of Representatives
# 4            1  legistrative              2  House of Representatives
# 5            1  legistrative              2  House of Representatives
# 6            1  legistrative              2  House of Representatives
# 7            1  legistrative              2  House of Representatives
# 8            1  legistrative              2  House of Representatives
# 9            1  legistrative              2  House of Representatives
# 10           1  legistrative              2  House of Representatives
# 11           1  legistrative              2  House of Representatives
# ...

# %%
speakers_data_frame = legistrative_data_frame[legistrative_data_frame["head"] == 'Speaker']

# %%
speakers = speakers_data_frame['name'].unique()
print(len(speakers))
speakers
# Out:
# 56
# array(['Frederick Muhlenberg', 'Jonathan Trumbull Jr.', 'Jonathan Dayton',
#        'Theodore Sedgwick', 'Nathaniel Macon', 'Joseph Bradley Varnum',
#        'Henry Clay', 'Langdon Cheves', 'John W. Taylor',
#        'Philip P. Barbour', 'Andrew Stevenson', 'John Bell',
#        'James K. Polk', 'Robert M. T. Hunter', 'John White',
#        'John Winston Jones', 'John Wesley Davis',
#        'Robert Charles Winthrop', 'Howell Cobb', 'Linn Boyd',
#        'Nathaniel P. Banks', 'James Lawrence Orr', 'William Pennington',
#        'Galusha A. Grow', 'Schuyler Colfax', 'Theodore M. Pomeroy',
#        'James G. Blaine', 'Michael C. Kerr', 'Samuel J. Randall',
#        'J. Warren Keifer', 'John G. Carlisle', 'Thomas Brackett Reed',
#        'Charles Frederick Crisp', 'David B. Henderson',
#        'Joseph Gurney Cannon', 'Champ Clark', 'Frederick H. Gillett',
#        'Nicholas Longworth', 'John Nance Garner', 'Henry Thomas Rainey',
# ...

# %%
states = speakers_data_frame['state'].unique()
print(len(states))
states
# Out:
# 24
# array(['Pennsylvania', 'Connecticut', 'New Jersey', 'Massachusetts',
#        'North Carolina', 'Kentucky', 'South Carolina', 'New York',
#        'Virginia', 'Tennessee', 'Indiana', 'Georgia', 'Maine', 'Ohio',
#        'Iowa', 'Illinois', 'Missouri', 'Texas', 'Alabama', 'Oklahoma',
#        'Washington', 'California', 'Wisconsin', 'Louisiana'], dtype=object)

# %% [markdown]
# ## Executive

# %% [markdown]
# ### Departments

# %%
department_data_frame = individuals_data_frame[individuals_data_frame["department_no"] != 0]
department_data_frame = department_data_frame[["department_no", "department", "head"]]
department_data_frame = department_data_frame.drop_duplicates(["department_no", "department", "head"])
department_data_frame
# Out:
#      department_no                                   department  \
# 0                2                     House of Representatives
# 129             -1                              Federal Reserve
# 145             -1           Securities and Exchange Commission
# 178             -1                                  White House
# 209              1                                  White House
# 258              3                          Department of State
# 329              4                   Department of the Treasury
# 407              5                        Department of Defense
# 435              6                        Department of Justice
# 521              7                   Department of the Interior
# 575              8                    Department of Agriculture
# 607              9                       Department of Commerce
# 647             10                          Department of Labor
# 676             11      Department of Health and Human Services
# ...

# %% [markdown]
# ### Secretaries of State

# %%
state_data_frame = individuals_data_frame[individuals_data_frame["department"] == "Department of State"]
state_data_frame
# Out:
#      branch_no     branch  department_no           department  \
# 258          2  executive              3  Department of State
# 259          2  executive              3  Department of State
# 260          2  executive              3  Department of State
# 261          2  executive              3  Department of State
# 262          2  executive              3  Department of State
# 263          2  executive              3  Department of State
# 264          2  executive              3  Department of State
# 265          2  executive              3  Department of State
# 266          2  executive              3  Department of State
# 267          2  executive              3  Department of State
# 268          2  executive              3  Department of State
# 269          2  executive              3  Department of State
# 270          2  executive              3  Department of State
# 271          2  executive              3  Department of State
# ...

# %%
foreign_borned_state_data_frame = state_data_frame[state_data_frame["birth_country"] != "United States"]
foreign_borned_state_data_frame
# Out:
#      branch_no     branch  department_no           department  \
# 313          2  executive              3  Department of State
# 321          2  executive              3  Department of State
#
#                    head  head_no                name full_name       party  \
# 313  Secretary of State     56.0     Henry Kissinger       NaN  Republican
# 321  Secretary of State     64.0  Madeleine Albright       NaN  Democratic
#
#     state district      president start_date end_date  birth_age birth_state  \
# 313   NaN      NaN  Richard Nixon        NaN      NaN        NaN         NaN
# 321   NaN      NaN   Bill Clinton        NaN      NaN        NaN         NaN
#
#       birth_country education
# 313         Germany  bachelor
# 321  Czech Republic  bachelor

# %%
len(foreign_borned_state_data_frame) / len(state_data_frame) * 100
# Out:
# 2.8169014084507045
