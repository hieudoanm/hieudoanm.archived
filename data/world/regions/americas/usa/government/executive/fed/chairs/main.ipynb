# %%
import pandas

# %%
chairs_data_frame = pandas.read_csv("./chairs.csv")
chairs_data_frame
# Out:
#     no               name       start         end     first_appointed_by
# 0    1     Charles Hamlin  1914-08-10  1916-08-09         Woodrow Wilson
# 1    2    William Harding  1916-08-10  1922-08-09         Woodrow Wilson
# 2    3  Daniel Crissinger  1923-05-01  1927-09-15      Warren G. Harding
# 3    4          Roy Young  1927-10-04  1930-08-31        Calvin Coolidge
# 4    5       Eugene Meyer  1930-09-16  1933-05-10         Herbert Hoover
# 5    6       Eugene Black  1933-05-19  1934-08-15  Franklin D. Roosevelt
# 6    7    Marriner Eccles  1934-11-15  1948-01-31  Franklin D. Roosevelt
# 7    8      Thomas McCabe  1948-04-15  1951-03-31        Harry S. Truman
# 8    9        Bill Martin  1951-04-02  1970-01-31        Harry S. Truman
# 9   10       Arthur Burns  1970-02-01  1978-01-31          Richard Nixon
# 10  11     William Miller  1978-03-08  1979-08-06           Jimmy Carter
# 11  12       Paul Volcker  1979-08-06  1987-08-11           Jimmy Carter
# ...

# %%
presidents = chairs_data_frame["first_appointed_by"].value_counts()
presidents
# Out:
# first_appointed_by
# Woodrow Wilson           2
# Franklin D. Roosevelt    2
# Harry S. Truman          2
# Jimmy Carter             2
# Warren G. Harding        1
# Calvin Coolidge          1
# Herbert Hoover           1
# Richard Nixon            1
# Ronald Reagan            1
# George W. Bush           1
# Barack Obama             1
# Donald Trump             1
# Name: count, dtype: int64
