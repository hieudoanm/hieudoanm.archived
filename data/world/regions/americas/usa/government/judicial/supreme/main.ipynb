# %%
import pandas

# %%
justices_data_frame = pandas.read_csv("./justices.csv")
justices_data_frame
# Out:
#      number                   name             state           position  \
# 0         1               John Jay          New York      Chief Justice
# 1         2          John Rutledge    South Carolina  Associate Justice
# 2         3        William Cushing     Massachusetts  Associate Justice
# 3         4           James Wilson      Pennsylvania  Associate Justice
# 4         5             John Blair          Virginia  Associate Justice
# ..      ...                    ...               ...                ...
# 111     112            Elena Kagan     Massachusetts  Associate Justice
# 112     113           Neil Gorsuch          Colorado  Associate Justice
# 113     114        Brett Kavanaugh          Maryland  Associate Justice
# 114     115      Amy Coney Barrett           Indiana  Associate Justice
# 115     116  Ketanji Brown Jackson  Washington, D.C.  Associate Justice
#
#              president        end
# 0    George Washington       none
# ...

# %%
presidents = justices_data_frame["president"].value_counts()
presidents
# Out:
# president
# George Washington        10
# Franklin D. Roosevelt     8
# Andrew Jackson            6
# William Howard Taft       5
# Dwight D. Eisenhower      5
# Abraham Lincoln           5
# Benjamin Harrison         4
# Ulysses S. Grant          4
# Warren G. Harding         4
# Richard Nixon             4
# Harry S. Truman           4
# Thomas Jefferson          4
# Grover Cleveland          4
# Woodrow Wilson            3
# Ronald Reagan             3
# Donald Trump              3
# Theodore Roosevelt        3
# Herbert Hoover            2
# John Adams                2
# Rutherford B. Hayes       2
# Chester A. Arthur         2
# Lyndon B. Johnson         2
# George H. W. Bush         2
# Bill Clinton              2
# James K. Polk             2
# George W. Bush            2
# Martin Van Buren          2
# Barack Obama              2
# James Madison             2
# John F. Kennedy           2
# Gerald Ford               1
# William McKinley          1
# ...

# %%
states = justices_data_frame["state"].value_counts()
states
# Out:
# state
# New York            15
# Massachusetts       10
# Ohio                 9
# Virginia             8
# Pennsylvania         6
# Maryland             6
# Tennessee            6
# New Jersey           5
# Kentucky             5
# California           4
# Illinois             4
# Georgia              4
# Alabama              3
# South Carolina       3
# Connecticut          3
# Michigan             2
# Colorado             2
# Indiana              2
# Arizona              2
# Minnesota            2
# Iowa                 2
# New Hampshire        2
# North Carolina       2
# Kansas               1
# Louisiana            1
# Wyoming              1
# Utah                 1
# Mississippi          1
# Texas                1
# Maine                1
# Missouri             1
# Washington, D.C.     1
# Name: count, dtype: int64
