# %% [markdown]
# # Miss Vietnam

# %%
import pandas

# %%
miss_vietnam_data_frame = pandas.read_csv("./miss-vietnam.csv")
miss_vietnam_data_frame = miss_vietnam_data_frame.sort_values(by = ["year", "prize"])
miss_vietnam_data_frame.to_csv("./miss-vietnam.csv", index=False)
miss_vietnam_data_frame["age"] = (miss_vietnam_data_frame["year"] - miss_vietnam_data_frame["birth_year"])
miss_vietnam_data_frame
# Out:
#     year                   name  birth_year  height         city  prize  age
# 0   1988        Bùi Bích Phương        1971    1.58       Hà Nội      1   17
# 1   1988         Nguyễn Thu Mai        1970     NaN       Hà Nội      2   18
# 2   1990        Nguyễn Diệu Hoa        1969    1.58       Hà Nội      1   21
# 3   1990          Trần Thu Hằng        1972     NaN       Hà Nội      2   18
# 4   1990           Trần Vân Anh        1970     NaN  Hồ Chí Minh      3   20
# 5   1992            Hà Kiều Anh        1976    1.74  Hồ Chí Minh      1   16
# 6   1992            Vi Thị Đông        1975     NaN       Hà Nội      2   17
# 7   1992     Nguyễn Minh Phương        1970     NaN  Tuyên Quang      3   22
# 8   1994        Nguyễn Thu Thủy        1976    1.72       Hà Nội      1   18
# 9   1994           Tô Hương Lan        1977     NaN  Tuyên Quang      2   17
# 10  1994          Trịnh Kim Chi        1975     NaN  Hồ Chí Minh      3   19
# ...

# %% [markdown]
# ## Winner

# %%
miss_vietname_winner_average_age = round(miss_vietnam_data_frame["age"].mean(), 2)
miss_vietname_winner_average_age
# Out:
# 19.49
