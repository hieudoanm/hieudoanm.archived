# %% [markdown]
# # Australian Football League

# %%
import pandas

# %% [markdown]
# ## Clubs

# %%
clubs_data_frame = pandas.read_csv("./clubs.csv")
clubs_data_frame = clubs_data_frame.sort_values(by = ['state', 'venue', 'name'])
clubs_data_frame.to_csv("./clubs.csv", index=False, header=True)
clubs_data_frame
# Out:
#                       name    moniker              state
# 0                   Sydney      Swans    New South Wales  \
# 1   Greater Western Sydney     Giants    New South Wales
# 2           Brisbane Bears      Bears         Queensland
# 3               Gold Coast       Suns         Queensland
# 4           Brisbane Lions      Lions         Queensland
# 5                 Adelaide      Crows    South Australia
# 6            Port Adelaide      Power    South Australia
# 7                  Fitzroy      Lions           Victoria
# 8                  Carlton      Blues           Victoria
# 9                 Essendon    Bombers           Victoria
# 10         North Melbourne  Kangaroos           Victoria
# 11                St Kilda     Saints           Victoria
# 12        Western Bulldogs   Bulldogs           Victoria
# 13                 Geelong       Cats           Victoria
# 14             Collingwood    Magpies           Victoria
# 15                Hawthorn      Hawks           Victoria
# 16               Melbourne     Demons           Victoria
# 17                Richmond     Tigers           Victoria
# 18              University   Students           Victoria
# 19               Fremantle    Dockers  Western Australia
# 20              West Coast     Eagles  Western Australia
#
#                         venue  active
# 0       Sydney Cricket Ground    True
# 1   Sydney Showground Stadium    True
# 2             Carrara Stadium   False
# 3             Carrara Stadium    True
# 4                   The Gabba    True
# 5               Adelaide Oval    True
# 6               Adelaide Oval    True
# 7       Brunswick Street Oval   False
# 8           Docklands Stadium    True
# 9           Docklands Stadium    True
# 10          Docklands Stadium    True
# 11          Docklands Stadium    True
# 12          Docklands Stadium    True
# 13              Kardinia Park    True
# 14   Melbourne Cricket Ground    True
# 15   Melbourne Cricket Ground    True
# 16   Melbourne Cricket Ground    True
# 17   Melbourne Cricket Ground    True
# 18   Melbourne Cricket Ground   False
# 19              Perth Stadium    True
# 20              Perth Stadium    True

# %%
active_clubs_data_frame = clubs_data_frame[clubs_data_frame['active']]
active_clubs_data_frame
# Out:
#                       name    moniker              state
# 0                   Sydney      Swans    New South Wales  \
# 1   Greater Western Sydney     Giants    New South Wales
# 3               Gold Coast       Suns         Queensland
# 4           Brisbane Lions      Lions         Queensland
# 5                 Adelaide      Crows    South Australia
# 6            Port Adelaide      Power    South Australia
# 8                  Carlton      Blues           Victoria
# 9                 Essendon    Bombers           Victoria
# 10         North Melbourne  Kangaroos           Victoria
# 11                St Kilda     Saints           Victoria
# 12        Western Bulldogs   Bulldogs           Victoria
# 13                 Geelong       Cats           Victoria
# 14             Collingwood    Magpies           Victoria
# 15                Hawthorn      Hawks           Victoria
# 16               Melbourne     Demons           Victoria
# 17                Richmond     Tigers           Victoria
# 19               Fremantle    Dockers  Western Australia
# 20              West Coast     Eagles  Western Australia
#
#                         venue  active
# 0       Sydney Cricket Ground    True
# 1   Sydney Showground Stadium    True
# 3             Carrara Stadium    True
# 4                   The Gabba    True
# 5               Adelaide Oval    True
# 6               Adelaide Oval    True
# 8           Docklands Stadium    True
# 9           Docklands Stadium    True
# 10          Docklands Stadium    True
# 11          Docklands Stadium    True
# 12          Docklands Stadium    True
# 13              Kardinia Park    True
# 14   Melbourne Cricket Ground    True
# 15   Melbourne Cricket Ground    True
# 16   Melbourne Cricket Ground    True
# 17   Melbourne Cricket Ground    True
# 19              Perth Stadium    True
# 20              Perth Stadium    True

# %%
states_series = active_clubs_data_frame['state'].value_counts()
states_series
# Out:
# state
# Victoria             10
# New South Wales       2
# Queensland            2
# South Australia       2
# Western Australia     2
# Name: count, dtype: int64

# %%
venue_series = active_clubs_data_frame['venue'].value_counts()
venue_series
# Out:
# venue
# Docklands Stadium            5
# Melbourne Cricket Ground     4
# Adelaide Oval                2
# Perth Stadium                2
# Sydney Cricket Ground        1
# Sydney Showground Stadium    1
# Carrara Stadium              1
# The Gabba                    1
# Kardinia Park                1
# Name: count, dtype: int64

# %% [markdown]
# ## Premiers

# %%
def build_match(series):
    premier = series.premier
    runner_up = series.runner_up
    clubs = [premier, runner_up]
    clubs.sort()
    return " vs ".join(clubs)

premiers_data_frame = pandas.read_csv("./premiers.csv")
premiers_data_frame["match"] = premiers_data_frame[["premier", "runner_up"]].apply(lambda series: build_match(series), axis =1)
premiers_data_frame
# Out:
#      season     premier      premier_state               runner_up
# 0      1897    Essendon           Victoria                 Geelong  \
# 1      1898     Fitzroy           Victoria                Essendon
# 2      1899     Fitzroy           Victoria            Sydney Swans
# 3      1900   Melbourne           Victoria                 Fitzroy
# 4      1901    Essendon           Victoria             Collingwood
# ..      ...         ...                ...                     ...
# 121    2018  West Coast  Western Australia             Collingwood
# 122    2019    Richmond           Victoria  Greater Western Sydney
# 123    2020    Richmond           Victoria                 Geelong
# 124    2021   Melbourne           Victoria        Western Bulldogs
# 125    2022     Geelong           Victoria            Sydney Swans
#
#      runner_up_state                               match
# 0           Victoria                 Essendon vs Geelong
# 1           Victoria                 Essendon vs Fitzroy
# 2    New South Wales             Fitzroy vs Sydney Swans
# 3           Victoria                Fitzroy vs Melbourne
# 4           Victoria             Collingwood vs Essendon
# ..               ...                                 ...
# 121         Victoria           Collingwood vs West Coast
# 122  New South Wales  Greater Western Sydney vs Richmond
# 123         Victoria                 Geelong vs Richmond
# 124         Victoria       Melbourne vs Western Bulldogs
# 125  New South Wales             Geelong vs Sydney Swans
#
# [126 rows x 6 columns]

# %%
premiers_series = premiers_data_frame['premier'].value_counts().sort_index(ascending=True).sort_values(ascending=False)
premiers_series
# Out:
# premier
# Carlton             16
# Essendon            16
# Collingwood         15
# Hawthorn            13
# Melbourne           13
# Richmond            13
# Geelong             12
# Fitzroy              8
# North Melbourne      4
# West Coast           4
# Brisbane Lions       3
# Sydney Swans         3
# Adelaide             2
# Western Bulldogs     2
# Port Adelaide        1
# St Kilda             1
# Name: count, dtype: int64

# %%
runners_up_series = premiers_data_frame['runner_up'].value_counts().sort_index(ascending=True).sort_values(ascending=False)
runners_up_series
# Out:
# runner_up
# Collingwood               27
# Essendon                  14
# Sydney Swans              13
# Carlton                   13
# Richmond                  12
# Geelong                   10
# Hawthorn                   6
# St Kilda                   6
# North Melbourne            5
# Melbourne                  5
# Fitzroy                    5
# West Coast                 3
# Western Bulldogs           2
# Brisbane Lions             1
# Port Adelaide              1
# Fremantle                  1
# Adelaide                   1
# Greater Western Sydney     1
# Name: count, dtype: int64

# %%
match_series = premiers_data_frame['match'].value_counts().sort_index(ascending=True).sort_values(ascending=False)
match_series
# Out:
# match
# Collingwood vs Melbourne              7
# Collingwood vs Geelong                6
# Essendon vs Melbourne                 6
# Carlton vs Collingwood                6
# Carlton vs Essendon                   6
# Collingwood vs Richmond               6
# Carlton vs Richmond                   6
# Geelong vs Hawthorn                   4
# Carlton vs Sydney Swans               4
# Collingwood vs Essendon               4
# Collingwood vs Fitzroy                4
# Geelong vs West Coast                 3
# Hawthorn vs North Melbourne           3
# Essendon vs Hawthorn                  3
# Collingwood vs Sydney Swans           3
# Geelong vs Richmond                   3
# Essendon vs Richmond                  3
# Carlton vs Fitzroy                    3
# Melbourne vs Western Bulldogs         2
# Essendon vs Geelong                   2
# Brisbane Lions vs Collingwood         2
# Carlton vs Hawthorn                   2
# Richmond vs Sydney Swans              2
# Hawthorn vs West Coast                2
# Essendon vs Fitzroy                   2
# Collingwood vs St Kilda               2
# North Melbourne vs Sydney Swans       1
# Hawthorn vs Western Bulldogs          1
# Hawthorn vs Sydney Swans              1
# Hawthorn vs St Kilda                  1
# North Melbourne vs Richmond           1
# Hawthorn vs Melbourne                 1
# Greater Western Sydney vs Richmond    1
# Sydney Swans vs West Coast            1
# Geelong vs Sydney Swans               1
# Geelong vs St Kilda                   1
# Melbourne vs Richmond                 1
# Adelaide vs North Melbourne           1
# Geelong vs Port Adelaide              1
# Fremantle vs Hawthorn                 1
# Adelaide vs St Kilda                  1
# Brisbane Lions vs Essendon            1
# Brisbane Lions vs Port Adelaide       1
# Carlton vs Geelong                    1
# Carlton vs North Melbourne            1
# Collingwood vs North Melbourne        1
# Collingwood vs West Coast             1
# Essendon vs North Melbourne           1
# Adelaide vs Richmond                  1
# Essendon vs St Kilda                  1
# Essendon vs Sydney Swans              1
# Fitzroy vs Melbourne                  1
# Fitzroy vs Richmond                   1
# Fitzroy vs St Kilda                   1
# Fitzroy vs Sydney Swans               1
# Sydney Swans vs Western Bulldogs      1
# Name: count, dtype: int64
