# %% [markdown]
# # LICENSES

# %%
import json
import requests
import pandas
from tqdm.notebook import tqdm as tqdm_notebook

# %%
BASE_URL = "https://api.github.com"

# %%
response = requests.get(f"{BASE_URL}/licenses")
if response.status_code != 200:
    licenses = response.json()
    licenses_data_frame = pandas.DataFrame(licenses)
licenses_data_frame
# Out:
#              key                                     name       spdx_id  \
# 0       agpl-3.0   GNU Affero General Public License v3.0      AGPL-3.0
# 1     apache-2.0                       Apache License 2.0    Apache-2.0
# 2   bsd-2-clause        BSD 2-Clause "Simplified" License  BSD-2-Clause
# 3   bsd-3-clause  BSD 3-Clause "New" or "Revised" License  BSD-3-Clause
# 4        bsl-1.0               Boost Software License 1.0       BSL-1.0
# 5        cc0-1.0     Creative Commons Zero v1.0 Universal       CC0-1.0
# 6        epl-2.0               Eclipse Public License 2.0       EPL-2.0
# 7        gpl-2.0          GNU General Public License v2.0       GPL-2.0
# 8        gpl-3.0          GNU General Public License v3.0       GPL-3.0
# 9       lgpl-2.1   GNU Lesser General Public License v2.1      LGPL-2.1
# 10           mit                              MIT License           MIT
# 11       mpl-2.0               Mozilla Public License 2.0       MPL-2.0
# 12     unlicense                            The Unlicense     Unlicense
#
#                                              url           node_id
# 0       https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 1     https://api.github.com/licenses/apache-2.0  MDc6TGljZW5zZTI=
# 2   https://api.github.com/licenses/bsd-2-clause  MDc6TGljZW5zZTQ=
# 3   https://api.github.com/licenses/bsd-3-clause  MDc6TGljZW5zZTU=
# 4        https://api.github.com/licenses/bsl-1.0  MDc6TGljZW5zZTI4
# 5        https://api.github.com/licenses/cc0-1.0  MDc6TGljZW5zZTY=
# 6        https://api.github.com/licenses/epl-2.0  MDc6TGljZW5zZTMy
# 7        https://api.github.com/licenses/gpl-2.0  MDc6TGljZW5zZTg=
# 8        https://api.github.com/licenses/gpl-3.0  MDc6TGljZW5zZTk=
# 9       https://api.github.com/licenses/lgpl-2.1  MDc6TGljZW5zZTEx
# 10           https://api.github.com/licenses/mit  MDc6TGljZW5zZTEz
# 11       https://api.github.com/licenses/mpl-2.0  MDc6TGljZW5zZTE0
# 12     https://api.github.com/licenses/unlicense  MDc6TGljZW5zZTE1

# %%
licenses = licenses_data_frame.to_dict("records")

for license in tqdm_notebook(licenses):
    key = license.get("key")
    response = requests.get(f"{BASE_URL}/licenses/{key}")
    if response.status_code == 200:
        license_details = response.json()
        body = license_details.get("body")
        spdx_id = license_details.get("spdx_id")
        file = open(f"./body/{spdx_id}.md",'w+')
        file.write(body)
        file.close()
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
