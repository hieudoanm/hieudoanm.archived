# %%
import pandas

# %%
speakers_data_frame = pandas.read_csv("./speakers.csv")
speakers_data_frame
# Out:
#     number                     name           state
# 0        1     Frederick Muhlenberg    Pennsylvania
# 1        2    Jonathan Trumbull Jr.     Connecticut
# 2        3          Jonathan Dayton      New Jersey
# 3        4        Theodore Sedgwick   Massachusetts
# 4        5          Nathaniel Macon  North Carolina
# 5        6    Joseph Bradley Varnum   Massachusetts
# 6        7               Henry Clay        Kentucky
# 7        8           Langdon Cheves  South Carolina
# 8        9           John W. Taylor        New York
# 9       10        Philip P. Barbour        Virginia
# 10      11         Andrew Stevenson        Virginia
# 11      12                John Bell       Tennessee
# 12      13            James K. Polk       Tennessee
# 13      14      Robert M. T. Hunter        Virginia
# 14      15               John White        Kentucky
# 15      16       John Winston Jones        Virginia
# 16      17        John Wesley Davis         Indiana
# ...

# %%
states = speakers_data_frame["state"].value_counts()
states
# Out:
# state
# Massachusetts     8
# Kentucky          4
# Virginia          4
# Pennsylvania      3
# Tennessee         3
# Texas             3
# Illinois          3
# Ohio              3
# Indiana           3
# Georgia           3
# New York          2
# Maine             2
# South Carolina    2
# New Jersey        2
# California        2
# Connecticut       1
# Iowa              1
# North Carolina    1
# Missouri          1
# Alabama           1
# Oklahoma          1
# Washington        1
# Wisconsin         1
# Name: count, dtype: int64
