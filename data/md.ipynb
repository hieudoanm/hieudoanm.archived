# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".ipynb"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    if num_lines < 100:
        print(path, num_lines)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
files_data_frame.reset_index()
# Out:
# 70
# ./oracle-of-bacon/number.ipynb 99
# ./world/regions/usa/government/legislative/main.ipynb 87
# ./sports/chess/chess.com/players/test.ipynb 58
# ./languages/open-weather-map/main.ipynb 67
# ./finance/stock/nasdaq/query.ipynb 34
#     index                                          file_path  num_lines
# 0      55                 ./finance/stock/nasdaq/query.ipynb         34
# 1      41        ./sports/chess/chess.com/players/test.ipynb         58
# 2      50            ./languages/open-weather-map/main.ipynb         67
# 3      20  ./world/regions/usa/government/legislative/mai...         87
# 4      11                     ./oracle-of-bacon/number.ipynb         99
# 5       7              ./technology/github/emojis/main.ipynb        108
# 6       6          ./technology/github/gitignores/main.ipynb        110
# 7      53                 ./languages/detection/detect.ipynb        111
# 8       8    ./technology/github/codes_of_conduct/main.ipynb        113
# 9      48                    ./languages/geo-text/main.ipynb        116
# 10     58  ./finance/stock/vnindex/dragon-capital/query.i...        134
# 11     45                      ./languages/quotes/main.ipynb        143
# 12     24               ./world/regions/usa/stock/main.ipynb        155
# 13     25         ./world/regions/australia/stock/main.ipynb        157
# 14     47                        ./languages/ntlk/main.ipynb        181
# 15     64  ./machine-learning/supervised/fashion-mnist/ma...        187
# 16     18                   ./world/organizations/main.ipynb        215
# 17     10                       ./oracle-of-bacon/main.ipynb        218
# 18     21  ./world/regions/usa/government/legislative/con...        222
# 19     69                      ./games/pokemon/analyse.ipynb        232
# 20     68                        ./games/pokemon/query.ipynb        240
# 21     62  ./machine-learning/supervised/text-classificat...        253
# 22     56            ./finance/stock/vnindex/vps/query.ipynb        259
# 23     40       ./sports/chess/chess.com/players/games.ipynb        269
# 24     29                          ./world/states/main.ipynb        276
# 25      4            ./technology/github/licenses/main.ipynb        277
# 26     27                           ./world/visas/main.ipynb        283
# 27     31                          ./sports/clubs/main.ipynb        288
# 28     51            ./languages/1000-most-common/main.ipynb        312
# 29     44                       ./languages/words/main.ipynb        318
# 30     19                     ./world/regions/usa/main.ipynb        327
# 31      3                                 ./nobel/main.ipynb        464
# 32     38                         ./sports/chess/games.ipynb        511
# 33     30               ./world/independence-days/main.ipynb        524
# 34     36                          ./sports/chess/main.ipynb        590
# 35      0                                         ./md.ipynb        615
# 36      1                                        ./csv.ipynb        683
# 37     61  ./machine-learning/supervised/employee-retenti...        721
# 38     46         ./languages/text-classification/main.ipynb        773
# 39     60  ./machine-learning/supervised/linear-regressio...        775
# 40     65  ./machine-learning/supervised/marketing-cost/m...        777
# 41     42     ./sports/chess/chess.com/players/analyse.ipynb        807
# 42     67  ./machine-learning/supervised/length-conversio...        964
# 43     23              ./world/regions/usa/states/main.ipynb        986
# 44      2                                 ./music/main.ipynb       1022
# 45     59  ./machine-learning/supervised/house-price-pred...       1122
# 46     66  ./machine-learning/supervised/linear-regressio...       1207
# 47     35                        ./sports/players/main.ipynb       1219
# 48      9                       ./technology/tlds/main.ipynb       1255
# 49     26                       ./world/timezones/main.ipynb       1258
# 50     39          ./sports/chess/lichess.org/openings.ipynb       1360
# 51     33  ./sports/football/clubs/league/standings/main....       1369
# 52     63  ./machine-learning/supervised/fuel-efficiency/...       1535
# 53      5           ./technology/github/languages/main.ipynb       1717
# 54     22  ./world/regions/usa/government/executive/usa.i...       1800
# 55     43                      ./sports/champions/main.ipynb       2202
# 56     32                  ./sports/football/full/main.ipynb       3060
# 57     12                ./education/universities/main.ipynb       3088
# 58     34                  ./sports/football/fifa/main.ipynb       3123
# 59     28                          ./world/cities/main.ipynb       3350
# 60     13    ./education/universities/rankings/top-200.ipynb       3700
# 61     54                         ./finance/forex/main.ipynb       4887
# 62     52                   ./languages/detection/main.ipynb       5252
# 63     37              ./sports/chess/analyse-openings.ipynb       6555
# 64     17                                 ./excel/main.ipynb       6610
# 65     15  ./education/universities/rankings/rankings-sha...      18912
# 66     49                     ./languages/popular/main.ipynb      20279
# 67     14  ./education/universities/rankings/rankings-qs....      34542
# 68     16  ./education/universities/rankings/rankings-tim...      41814
# 69     57          ./finance/stock/vnindex/vps/analyse.ipynb     119393
