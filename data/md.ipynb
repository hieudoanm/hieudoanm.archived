# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)

def get_csv_paths(directory):
    csv_paths = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                csv_paths.append(os.path.join(root, file))

    return csv_paths

def get_num_lines(directory):
    csv_file = open(directory, 'r')
    num_lines = sum(1 for _ in csv_file)
    return num_lines

# Replace 'your_directory_path' with the path of the directory you want to search
directory_path = '.'
csv_paths = get_csv_paths(directory_path)

print(len(csv_paths))

files = []

for path in csv_paths:
    num_lines = get_num_lines(path)
    if num_lines < 100:
        print(path, num_lines)
    files.append({
        "file_path": path,
        "num_lines": num_lines
    })

files_data_frame = pd.DataFrame(files)
files_data_frame = files_data_frame.sort_values(by = ["num_lines"])
files_data_frame.reset_index()
# Out:
# 17
# ./technology/github/licenses/body/BSD-2-Clause.md 24
# ./technology/github/licenses/body/Unlicense.md 24
# ./technology/github/licenses/body/BSD-3-Clause.md 28
# ./technology/github/licenses/body/BSL-1.0.md 23
# ./technology/github/licenses/body/MIT.md 21
# ./technology/github/codes_of_conduct/docs/Citizen Code Of Conduct.md 94
# ./machine-learning/README.md 27
#     index                                          file_path  num_lines
# 0      12           ./technology/github/licenses/body/MIT.md         21
# 1       7       ./technology/github/licenses/body/BSL-1.0.md         23
# 2       2  ./technology/github/licenses/body/BSD-2-Clause.md         24
# 3       5     ./technology/github/licenses/body/Unlicense.md         24
# 4      16                       ./machine-learning/README.md         27
# 5       6  ./technology/github/licenses/body/BSD-3-Clause.md         28
# 6      13  ./technology/github/codes_of_conduct/docs/Citi...         94
# 7       4       ./technology/github/licenses/body/CC0-1.0.md        121
# 8      14  ./technology/github/codes_of_conduct/docs/Cont...        128
# 9       8    ./technology/github/licenses/body/Apache-2.0.md        201
# 10      3       ./technology/github/licenses/body/EPL-2.0.md        277
# 11     10       ./technology/github/licenses/body/GPL-2.0.md        340
# 12      9       ./technology/github/licenses/body/MPL-2.0.md        378
# 13      0      ./technology/github/licenses/body/LGPL-2.1.md        505
# 14      1      ./technology/github/licenses/body/AGPL-3.0.md        661
# 15     11       ./technology/github/licenses/body/GPL-3.0.md        674
# 16     15                 ./education/universities/README.md       1730
