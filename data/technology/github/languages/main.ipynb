# %% [markdown]
# # Languages

# %%
import json
import pandas
import requests
import yaml

# %%
URL = "https://raw.githubusercontent.com/github/linguist/master/lib/linguist/languages.yml"

response = requests.get(URL)
response_yaml = response.text
languages = yaml.safe_load(response_yaml)

language_keys = list(languages.keys())

list_of_languages = []

for language_key in language_keys:
    value = languages[language_key]
    value["language"] = language_key
    list_of_languages.append(value)
  
languages_data_frame = pandas.DataFrame(list_of_languages)

# %%
types = languages_data_frame['type'].value_counts()
types
# Out:
# type
# programming    469
# data           159
# markup          60
# prose           18
# Name: count, dtype: int64

# %%
sorted_languages_data_frame = languages_data_frame.sort_values(by=["type", "ace_mode", "tm_scope", "language"])
sorted_languages_data_frame.to_csv("./csv/all-languages.csv", index=False, header=True)
sorted_languages_data_frame
# Out:
#       type    color                                         extensions  \
# 28    data  #d12127                              [.apacheconf, .vhost]
# 68    data      NaN                                       [.c-objdump]
# 113   data      NaN  [.cppobjdump, .c++-objdump, .c++objdump, .cpp-...
# 126   data      NaN                                       [.d-objdump]
# 409   data      NaN                                         [.objdump]
# ..     ...      ...                                                ...
# 377  prose      NaN                                            [.muse]
# 701  prose  #141414                 [.rst, .rest, .rest.txt, .rst.txt]
# 604  prose      NaN                            [.texinfo, .texi, .txi]
# 630  prose  #199f4b                                             [.txt]
# 607  prose  #ffe7ac                                         [.textile]
#
#                   tm_scope      ace_mode  language_id          language  \
# 28    source.apache-config   apache_conf           16        ApacheConf
# 68          objdump.x86asm  assembly_x86           44         C-ObjDump
# 113         objdump.x86asm  assembly_x86           70       Cpp-ObjDump
# 126         objdump.x86asm  assembly_x86           81         D-ObjDump
# 409         objdump.x86asm  assembly_x86          256           ObjDump
# ..                     ...           ...          ...               ...
# 377              text.muse          text    474864066              Muse
# 701  text.restructuredtext          text          419  reStructuredText
# 604           text.texinfo          text    988020015           Texinfo
# 630          text.vim-help          text    508563686     Vim Help File
# 607                   none       textile          373           Textile
#
#                      aliases codemirror_mode codemirror_mime_type  \
# 28           [aconf, apache]             NaN                  NaN
# 68                       NaN             NaN                  NaN
# 113            [c++-objdump]             NaN                  NaN
# 126                      NaN             NaN                  NaN
# 409                      NaN             NaN                  NaN
# ..                       ...             ...                  ...
# 377  [amusewiki, emacs muse]             NaN                  NaN
# 701                    [rst]             rst           text/x-rst
# 604                      NaN             NaN                  NaN
# 630          [help, vimhelp]             NaN                  NaN
# 607                      NaN         textile       text/x-textile
#
#     interpreters group                              filenames  wrap fs_name  \
# 28           NaN   NaN  [.htaccess, apache2.conf, httpd.conf]   NaN     NaN
# 68           NaN   NaN                                    NaN   NaN     NaN
# 113          NaN   NaN                                    NaN   NaN     NaN
# 126          NaN   NaN                                    NaN   NaN     NaN
# 409          NaN   NaN                                    NaN   NaN     NaN
# ..           ...   ...                                    ...   ...     ...
# 377          NaN   NaN                                    NaN  True     NaN
# 701          NaN   NaN                                    NaN  True     NaN
# 604   [makeinfo]   NaN                                    NaN  True     NaN
# 630          NaN   NaN                                    NaN   NaN     NaN
# 607          NaN   NaN                                    NaN  True     NaN
#
#     searchable
# 28         NaN
# 68         NaN
# 113        NaN
# 126        NaN
# 409        NaN
# ..         ...
# 377        NaN
# 701        NaN
# 604        NaN
# 630        NaN
# 607        NaN
#
# [706 rows x 16 columns]

# %%
minified_languages_data_frame = sorted_languages_data_frame[["type", "color", "ace_mode", "tm_scope", "language"]]
minified_languages_data_frame
# Out:
#       type    color      ace_mode               tm_scope          language
# 28    data  #d12127   apache_conf   source.apache-config        ApacheConf
# 68    data      NaN  assembly_x86         objdump.x86asm         C-ObjDump
# 113   data      NaN  assembly_x86         objdump.x86asm       Cpp-ObjDump
# 126   data      NaN  assembly_x86         objdump.x86asm         D-ObjDump
# 409   data      NaN  assembly_x86         objdump.x86asm           ObjDump
# ..     ...      ...           ...                    ...               ...
# 377  prose      NaN          text              text.muse              Muse
# 701  prose  #141414          text  text.restructuredtext  reStructuredText
# 604  prose      NaN          text           text.texinfo           Texinfo
# 630  prose  #199f4b          text          text.vim-help     Vim Help File
# 607  prose  #ffe7ac       textile                   none           Textile
#
# [706 rows x 5 columns]

# %%
colored_languages_data_frame = minified_languages_data_frame[minified_languages_data_frame['color'].notnull()]
colored_languages_data_frame.to_csv("./csv/colored-languages.csv", index=False, header=True)

# %%
programming_languages_data_frame = minified_languages_data_frame[minified_languages_data_frame['type'] == 'programming']
programming_languages_data_frame.to_csv("./csv/programming-languages.csv", index=False, header=True)

# %%
data_languages_data_frame = minified_languages_data_frame[minified_languages_data_frame['type'] == 'data']
data_languages_data_frame.to_csv("./csv/data-languages.csv", index=False, header=True)

# %%
markup_languages_data_frame = minified_languages_data_frame[minified_languages_data_frame['type'] == 'markup']
markup_languages_data_frame.to_csv("./csv/markup-languages.csv", index=False, header=True)

# %%
languages_json = json.dumps(list_of_languages, indent=2)
languages_json_file = open("./json/languages.json", "w+")
languages_json_file.write(languages_json)
languages_json
# Out:
# '[\n  {\n    "type": "programming",\n    "color": "#814CCC",\n    "extensions": [\n      ".bsl",\n      ".os"\n    ],\n    "tm_scope": "source.bsl",\n    "ace_mode": "text",\n    "language_id": 0,\n    "language": "1C Enterprise"\n  },\n  {\n    "type": "data",\n    "color": "#38761D",\n    "extensions": [\n      ".2da"\n    ],\n    "tm_scope": "source.2da",\n    "ace_mode": "text",\n    "language_id": 387204628,\n    "language": "2-Dimensional Array"\n  },\n  {\n    "type": "programming",\n    "color": "#004289",\n    "extensions": [\n      ".4dm"\n    ],\n    "tm_scope": "source.4dm",\n    "ace_mode": "text",\n    "language_id": 577529595,\n    "language": "4D"\n  },\n  {\n    "type": "programming",\n    "color": "#E8274B",\n    "extensions": [\n      ".abap"\n    ],\n    "tm_scope": "source.abap",\n    "ace_mode": "abap",\n    "language_id": 1,\n    "language": "ABAP"\n  },\n  {\n    "type": "programming",\n    "color": "#555e25",\n    "extensions": [\n      ".asddls"\n    ],\n    "tm_scope": "source.abapcds",\n    "language_id": 452681853,\n    "ace_mode": "text",\n    "language": "ABAP CDS"\n  },\n  {\n    "type": "data",\n    "ace_mode": "text",\n    "extensions": [\n      ".abnf"\n    ],\n    "tm_scope": "source.abnf",\n    "language_id": 429,\n    "language": "ABNF"\n  },\n  {\n    "type": "programming",\n    "color": "#B9D9FF",\n    "aliases": [\n      "ags"\n    ],\n    "extensions": [\n      ".asc",\n      ".ash"\n    ],\n    "tm_scope": "source.c++",\n    "ace_mode": "c_cpp",\n    "codemirror_mode": "clike",\n    "codemirror_mime_type": "text/x-c++src",\n    "language_id": 2,\n    "language": "AGS Script"\n  },\n  {\n    "type": "programming",\n    "color": "#34EB6B",\n    "tm_scope": "source.aidl",\n    "extensions": [\n      ".aidl"\n    ],\n    "ace_mode": "text",\n    "interpreters": [\n      "aidl"\n    ],\n    "language_id": 451700185,\n    "language": "AIDL"\n  },\n  {\n    "type": "programming",\n    "color": "#3AA2B5",\n    "extensions": [\n      ".al"\n    ],\n    "tm_scope": "source.al",\n    "ace_mode": "text",\n    "language_id": 658971832,\n    "language": "AL"\n  },\n  {\n    "type": "programming",\n    "color": "#E6EFBB",\n    "extensions": [\n      ".ampl",\n      ".mod"\n    ],\n    "tm_scope": "source.ampl",\n    "ace_mode": "text",\n    "language_id": 3,\n    "language": "AMPL"\n  },\n  {\n    "type": "programming",\n    "color": "#9DC3FF",\n    "extensions": [\n      ".g4"\n    ],\n    "tm_scope": "source.antlr",\n    "ace_mode": "text",\n    "language_id": 4,\n    "language": "ANTLR"\n  },\n  {\n    "type": "markup",\n    "color": "#2ACCA8",\n    "ace_mode": "markdown",\n    "extensions": [\n      ".apib"\n    ],\n    "tm_scope": "text.html.markdown.source.gfm.apib",\n    "language_id": 5,\n    "language": "API Blueprint"\n  },\n  {\n    "type": "programming",\n    "color": "#5A8164",\n    "extensions": [\n      ".apl",\n      ".dyalog"\n    ],\n    "interpreters": [\n      "apl",\n      "aplx",\n      "dyalog"\n    ],\n    "tm_scope": "source.apl",\n    "ace_mode": "text",\n    "codemirror_mode": "apl",\n    "codemirror_mime_type": "text/apl",\n    "language_id": 6,\n    "language": "APL"\n  },\n  {\n    "type": "programming",\n    "ace_mode": "text",\n    "extensions": [\n      ".asl",\n      ".dsl"\n    ],\n    "tm_scope": "source.asl",\n    "language_id": 124996147,\n    "language": "ASL"\n  },\n  {\n    "type": "data",\n    "extensions": [\n      ".asn",\n      ".asn1"\n    ],\n    "tm_scope": "source.asn",\n    "ace_mode": "text",\n    "codemirror_mode": "asn.1",\n    "codemirror_mime_type": "text/x-ttcn-asn",\n    "language_id": 7,\n    "language": "ASN.1"\n  },\n  {\n    "type": "programming",\n    "tm_scope": "text.html.asp",\n    "color": "#9400ff",\n    "aliases": [\n      "aspx",\n      "aspx-vb"\n    ],\n    "extensions": [\n      ".asax",\n      ".ascx",\n      ".ashx",\n      ".asmx",\n      ".aspx",\n      ".axd"\n    ],\n    "ace_mode": "text",\n    "codemirror_mode": "htmlemb ...
